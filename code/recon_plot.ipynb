# %% [markdown]
# # APWP Analysis

# %%
# standard modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from matplotlib.cm import get_cmap
import matplotlib.patches as patches
import os
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from scipy import stats
pd.set_option('display.max_rows',999)
pd.set_option('display.max_columns',999)

# pmagpy
import pmagpy.ipmag as ipmag
import pmagpy.pmag as pmag
import cartopy.crs as ccrs
import cartopy
import xml.etree.ElementTree as ET
import pygplates as pgp

lat_grid = [-80,-60,-30,0,30,60,80]
lon_grid = np.arange(-180,180+60,60)

# %% [markdown]
# ## Functions

# %%
def create_vgp_FeatureCollection(compilation):
    """
    Loop through poles and produce a pygplates FeatureCollection of multiple VGPs.
    
    Modified from code by Michael G. Tetley.
    
    Parameters
    ----------
    compilation : dataframe
        pole compilation
        
    Returns
    -------
    vpgFeatureCollection : FeatureCollection
        pygplates FeatureCollection of VGPs in compilation
    """
    poleLat = []
    poleLon = []
    poleName = []
    poleSiteLat = []
    poleSiteLon = []
    poleNominalAge = []
    poleA95 = []
    poleAgeLowerLimit = []
    poleAgeUpperLimit = []
    plateID = []

    count = 0

    for i in range(len(compilation)):

        if np.isfinite(compilation['slat'][i]) and np.isfinite(compilation['slon'][i]) and \
           np.isfinite(compilation['age lower'][i]) and np.isfinite(compilation['age upper'][i]):

            poleLat.append(compilation['plat'][i])
            poleLon.append(compilation['plon'][i])

            poleName.append(compilation['name'][i] + ' (' + compilation['grade'][i] + ')')
            poleSiteLat.append(compilation['slat'][i])
            poleSiteLon.append(compilation['slon'][i])
            poleNominalAge.append(compilation['age'][i])
            poleA95.append(compilation['a95'][i])

            poleAgeLowerLimit.append(compilation['age lower'][i])
            poleAgeUpperLimit.append(compilation['age upper'][i])

            plateID.append(compilation['plateID'][i])

            count = count + 1

        # Print if any of the isfinite tests fail
        else:

            print('Bad data for : {}'.format(compilation['name'][i]))


    # Create new GPlates Feature Collection
    vpgFeatureCollection = pgp.FeatureCollection()

    # Create new GPlates feature 'VirtualGeomagneticPole'.
    # Pole lat, pole lon, pole name, and reconstruction plate ID added within PointOnSphere method.
    # Inc, Dec, A95, Age and Sample site lat/lon values to added within 'other_properties' method.

    for j in range(count):

        vgpFeature = pgp.Feature.create_reconstructable_feature(
                     pgp.FeatureType.create_gpml('VirtualGeomagneticPole'),
                     pgp.PointOnSphere([np.float(poleLat[j]), np.float(poleLon[j])]),
                     name = poleName[j],
                     reconstruction_plate_id = int(plateID[j]),
                     other_properties = [(pgp.PropertyName.create_gpml('poleA95'),
                                          pgp.XsDouble(np.float64(poleA95[j]))),
                                         (pgp.PropertyName.create_gpml('averageAge'),
                                          pgp.XsDouble(np.float64(poleNominalAge[j]))),
                                         (pgp.PropertyName.create_gpml('averageSampleSitePosition'),
                                          pgp.GmlPoint(pgp.PointOnSphere([np.float(poleSiteLat[j]), 
                                                                          np.float(poleSiteLon[j])])))])

        # Add newly created feature to existing Feature Collection
        vpgFeatureCollection.add(vgpFeature)

    return vpgFeatureCollection

# %%
def create_vgp_gpml(vpgFeatureCollection, filename):
    """
    Create a .gpml for a FeatureCollection of VGPs.
    
    Modified from code by Michael G. Tetley.
    
    Parameters
    ----------
    vpgFeatureCollection : FeatureCollection
        pygplates FeatureCollection of VGPs in compilation
        
    filename : string
        path and name for output .gpml
    """
    # Generate GPML output file
    gpmlOutputFile = filename

    # Check for existing output file with same name and remove if found
    if os.path.isfile(filename):
        os.remove(filename)

    # Check to make sure vgpFeatureCollection (feature collection) is not empty before writing to file
    if len(vpgFeatureCollection) != 0:
        outputFeatureCollection = pgp.FeatureCollectionFileFormatRegistry()
        outputFeatureCollection.write(vpgFeatureCollection, filename)

    # Check if new file was created and confirm export
    if os.path.isfile(filename):
        print('Palaeomagnetic pole data successfully exported in GPML format.')

# %%
def get_craton_XYs(gpml, plateIDs):
    """
    Get XY coordinates of a plate polygon from a .gpml.
    
    Parameters
    ----------
    gpml : string
        Path to .gpml file.
        
    plateIDs : list
        Of plateIDs.
    """
    # namespace dictionary
    ns = {'gpml':'http://www.gplates.org/gplates',
          'gml':'http://www.opengis.net/gml'}
    
    # initial parse
    tree = ET.parse(gpml)
    root = tree.getroot()
    
    # storage
    Xs = []
    Ys = []
    
    # iterate through featureMembers
    for featureMember in root.findall('gml:featureMember',ns):
        
        # get child
        for child in featureMember:
            slice_ind = child.tag.find('}')
            child_root = 'gpml:' + child.tag[slice_ind+1:]
        
        # check plateID
        plateID_path = child_root + '/gpml:reconstructionPlateId/gpml:ConstantValue/gpml:value'
        feature_plateID = int(featureMember.find(plateID_path,ns).text)
        if feature_plateID in plateIDs:
            
            if featureMember.find(child_root + '/gpml:outlineOf', ns)!=None:
                polygon_root = child_root + '/gpml:outlineOf'
            elif featureMember.find(child_root + '/gpml:boundary', ns)!=None:
                polygon_root = child_root + '/gpml:boundary'
            elif featureMember.find(child_root + '/gpml:unclassifiedGeometry', ns)!=None:
                polygon_root = child_root + '/gpml:unclassifiedGeometry'
            elif featureMember.find(child_root + '/gpml:centerLineOf', ns)!=None:
                polygon_root = child_root + '/gpml:centerLineOf'
            else:
                raise Exception('polygon_root undefined.')
            
            # get coordinates
            posList_path = polygon_root + '/gpml:ConstantValue/gpml:value/gml:Polygon/gml:exterior/gml:LinearRing/gml:posList'
            for feature_posList in featureMember.findall(posList_path,ns):
                np_posList = np.fromstring(feature_posList.text, dtype=float, sep=' ')
            
                # split into lat and lon
                lat_inds = np.arange(0, len(np_posList), 2, dtype=int)
                lon_inds = np.arange(1, len(np_posList), 2, dtype=int)

                feature_lat = np_posList[lat_inds]
                feature_lon = np_posList[lon_inds]
            
                Xs.append(feature_lon)
                Ys.append(feature_lat)
            
    return Xs, Ys

# %%
def get_single_craton_XYs(gpml):
    """
    Get XY coordinates of a plate polygon from a .gpml.
    
    Parameters
    ----------
    gpml : string
        Path to .gpml file.
    """
    # namespace dictionary
    ns = {'gpml':'http://www.gplates.org/gplates',
          'gml':'http://www.opengis.net/gml'}
    
    # initial parse
    tree = ET.parse(gpml)
    root = tree.getroot()
    
    # storage
    Xs = []
    Ys = []
    
    # iterate through featureMembers
    featureMember = root.find('gml:featureMember',ns)
        
    # get child
    for child in featureMember:
        slice_ind = child.tag.find('}')
        child_root = 'gpml:' + child.tag[slice_ind+1:]

    if featureMember.find(child_root + '/gpml:outlineOf', ns)!=None:
        polygon_root = child_root + '/gpml:outlineOf'
    elif featureMember.find(child_root + '/gpml:boundary', ns)!=None:
        polygon_root = child_root + '/gpml:boundary'
    elif featureMember.find(child_root + '/gpml:unclassifiedGeometry', ns)!=None:
        polygon_root = child_root + '/gpml:unclassifiedGeometry'
    elif featureMember.find(child_root + '/gpml:centerLineOf', ns)!=None:
        polygon_root = child_root + '/gpml:centerLineOf'
    else:
        raise Exception('polygon_root undefined.')

    # get coordinates
    posList_path = polygon_root + '/gpml:ConstantValue/gpml:value/gml:Polygon/gml:exterior/gml:LinearRing/gml:posList'
    for feature_posList in featureMember.findall(posList_path,ns):
        np_posList = np.fromstring(feature_posList.text, dtype=float, sep=' ')

        # split into lat and lon
        lat_inds = np.arange(0, len(np_posList), 2, dtype=int)
        lon_inds = np.arange(1, len(np_posList), 2, dtype=int)

        feature_lat = np_posList[lat_inds]
        feature_lon = np_posList[lon_inds]

        Xs = feature_lon
        Ys = feature_lat
            
    return Xs, Ys

# %%
def craton_plot(ax, plateIDs, Eulers, edgecolor, facecolor, alpha, linewidth, reverse_draw=False):
    """
    Plot cratons with rotation.
    
    Parameters
    ----------
    ax : map axis
        On which to plot.
    
    plateIDs : list
        Of plateIDs.
        
    Eulers : list of lists
        Of Euler rotation parameters - if more than one given,
        the rotations will be additive.
    """
    # get cratons from .gpml
    gpml = './shapes_cratons.gpml'
    Xs, Ys = get_craton_XYs(gpml, plateIDs)
    
    # draw in reverse
    if reverse_draw:
        Xs = np.flip(Xs)
        Ys = np.flip(Ys)
    
    # rotate cratons
    rotated_Xs = []
    rotated_Ys = []
    for i in range(len(Xs)):
        rotated_X = np.array([])
        rotated_Y = np.array([])
        for j in range(len(Xs[i])):
            this_X = [Xs[i][j]]
            this_Y = [Ys[i][j]]
            for k in range(len(Eulers)):
                this_Y, this_X = pmag.pt_rot(Eulers[k], this_Y, this_X)
            rotated_X = np.append(rotated_X, this_X)
            rotated_Y = np.append(rotated_Y, this_Y)
        rotated_Xs.append(rotated_X)
        rotated_Ys.append(rotated_Y)
        
    # add cratons
    for i in range(len(rotated_Xs)):
        XY = np.stack([rotated_Xs[i][::-1],rotated_Ys[i][::-1]],axis=1)
        poly_edge = patches.Polygon(XY,
                                    edgecolor=edgecolor,facecolor='none',alpha=alpha,
                                    transform=ccrs.Geodetic(), linewidth=linewidth)
        poly_face = patches.Polygon(XY,
                                    edgecolor='none',facecolor=facecolor,alpha=alpha,
                                    transform=ccrs.Geodetic())
        ax.add_patch(poly_face)
        ax.add_patch(poly_edge)

# %%
def single_craton_plot(ax, gpml, Eulers, edgecolor, facecolor, alpha, linewidth):
    """
    Plot cratons with rotation.
    
    Parameters
    ----------
    ax : map axis
        On which to plot.
    
    gpml : string
        Path to .gpml file.
        
    Eulers : list of lists
        Of Euler rotation parameters - if more than one given,
        the rotations will be additive.
    """
    # get cratons from .gpml
    Xs, Ys = get_single_craton_XYs(gpml)
    
    # rotate craton
    rotated_Xs = np.array([])
    rotated_Ys = np.array([])
    for i in range(len(Xs)):
        this_X = [Xs[i]]
        this_Y = [Ys[i]]
        for j in range(len(Eulers)):
            this_Y, this_X = pmag.pt_rot(Eulers[j], this_Y, this_X)
        rotated_Xs = np.append(rotated_Xs, this_X)
        rotated_Ys = np.append(rotated_Ys, this_Y)
        
    # add craton
    #XY = np.stack([rotated_Xs[::-1],rotated_Ys[::-1]],axis=1)
    XY = np.stack([rotated_Xs,rotated_Ys],axis=1)
    print(XY.shape)
    poly_edge = patches.Polygon(XY,
                                edgecolor=edgecolor,facecolor='none',alpha=alpha,
                                transform=ccrs.Geodetic(), linewidth=linewidth)
    poly_face = patches.Polygon(XY,
                                edgecolor='none',facecolor=facecolor,alpha=alpha,
                                transform=ccrs.Geodetic())
    ax.add_patch(poly_face)
    ax.add_patch(poly_edge)

# %% [markdown]
# **Come back to this once matplotlib updates to 3.3.2:**

# %% [raw]
# ax = ipmag.make_orthographic_map(add_land=False, central_longitude=-90, central_latitude=40,
#                                  figsize=(8,8), grid_lines=False)
#
# lat_grid = [-80,-60,-30,0,30,60,80]
# lon_grid = np.arange(-180,180+60,60)
#
# single_craton_plot(ax, '../GPlates/Cratons/1000_Laurentia_Outline.gpml', [[0,0,0]], 'k', 'r', 1.0, 0.5)
#
# ax.gridlines(xlocs=lon_grid, ylocs=lat_grid, linewidth=0.5,
#              color='C7', linestyle='dotted', zorder=-1)
#
# plt.show()

# %%
def equi_filled(map_axis, centerlon, centerlat, radius, color, alpha=1.0, edge_alpha=1.0):
    """
    Modified from the ipmag function equi().
    """
    glon1 = centerlon
    glat1 = centerlat
    X = []
    Y = []
    for azimuth in range(0, 360):
        glon2, glat2, baz = ipmag.shoot(glon1, glat1, azimuth, radius)
        X.append(glon2)
        Y.append(glat2)
    X.append(X[0])
    Y.append(Y[0])
    
    X = X[::-1]
    Y = Y[::-1]
    
    XY = np.stack([X,Y],axis=1)
    
    circle_edge = patches.Polygon(XY,
                                  edgecolor=color,facecolor='none',alpha=edge_alpha,
                                  transform=ccrs.Geodetic())
    circle_face = patches.Polygon(XY,
                                  edgecolor='none',facecolor=color,alpha=alpha,
                                  transform=ccrs.Geodetic())
    
    map_axis.add_patch(circle_face)
    map_axis.add_patch(circle_edge)

# %%
def rotated_pole_plot(ax, plon, plat, a95, Eulers, marker, s, marker_color, a95_color, a95_alpha, a95_edge_alpha=1.0):
    """
    Plot paleomagnetic pole with rotation.
    """
    # rotate pole
    rotated_plat = plat
    rotated_plon = plon
    for i in range(len(Eulers)):
        rotated_plat, rotated_plon = pmag.pt_rot(Eulers[i], [rotated_plat], [rotated_plon])
        rotated_plat = rotated_plat[0]
        rotated_plon = rotated_plon[0]
    
    # degrees to km conversion
    a95_km = a95 * 111.32
    
    # pole
    ax.scatter(rotated_plon, rotated_plat, marker=marker,
               color=marker_color, edgecolors='k', s=s,
               label='__nolegend__', zorder=101, transform=ccrs.PlateCarree())
    
    # a95
    equi_filled(ax, rotated_plon, rotated_plat, a95_km, a95_color, alpha=a95_alpha, edge_alpha=a95_edge_alpha)

# %%
def rotated_point_plot(ax, plon, plat, Eulers, s, marker_color):
    """
    Plot point with rotation.
    """
    # rotate pole
    rotated_plat = plat
    rotated_plon = plon
    for i in range(len(Eulers)):
        rotated_plat, rotated_plon = pmag.pt_rot(Eulers[i], rotated_plat, rotated_plon)
        rotated_plat = rotated_plat
        rotated_plon = rotated_plon
    
    # pole
    ax.scatter(rotated_plon, rotated_plat,
               color=marker_color, s=s, edgecolor='none',
               label='__nolegend__', zorder=101, transform=ccrs.PlateCarree())

# %%
def APWP_plot(ax,
              plon_rot, plat_rot, a95_rot, age_rot,
              plon_fix, plat_fix, a95_fix, age_fix,
              Euler,
              label_rot, color_rot, marker_rot, s_rot,
              label_fix, color_fix, marker_fix, s_fix,
              age_lim=None, cmap='viridis'):
    """
    Plot apparent polar wander paths for two connected cratons.
    """
    # get vmin and vmax, and slice data if necessary
    if age_lim==None:
        vmin = np.min([age_rot.min(), age_fix.min()])
        vmax = np.max([age_rot.max(), age_fix.max()])
    else:
        vmin = age_lim[0]
        vmax = age_lim[1]
        
        rot_mask = (age_rot>=age_lim[0])&(age_rot<=age_lim[1])
        plon_rot = plon_rot[rot_mask]
        plat_rot = plat_rot[rot_mask]
        a95_rot = a95_rot[rot_mask]
        age_rot = age_rot[rot_mask]
        
        fix_mask = (age_fix>=age_lim[0])&(age_fix<=age_lim[1])
        plon_fix = plon_fix[fix_mask]
        plat_fix = plat_fix[fix_mask]
        a95_fix = a95_fix[fix_mask]
        age_fix = age_fix[fix_mask]
    
    # rotate poles
    rotated_plat = np.array([])
    rotated_plon = np.array([])
    
    for i in range(len(plon_rot)):
        this_plat, this_plon = pmag.pt_rot(Euler, [plat_rot[i]], [plon_rot[i]])
        rotated_plat = np.append(rotated_plat, this_plat[0])
        rotated_plon = np.append(rotated_plon, this_plon[0])
    
    # degrees to km conversion
    a95_rot_km = a95_rot * 111.32
    a95_fix_km = a95_fix * 111.32
    
    # colormap to age
    color_mapping = plt.cm.ScalarMappable(cmap=cmap, norm=plt.Normalize(vmin=vmin, vmax=vmax))
    colors_rot = color_mapping.to_rgba(age_rot).tolist()
    colors_fix = color_mapping.to_rgba(age_fix).tolist()
    
    # pole
    ax.scatter(plon_fix, plat_fix, marker=marker_fix,
               color=colors_fix, edgecolors='k', s=s_fix,
               label='__nolegend__', zorder=101, transform=ccrs.Geodetic())
    ax.scatter(rotated_plon, rotated_plat, marker=marker_rot,
               color=colors_rot, edgecolors='k', s=s_rot,
               label='__nolegend__', zorder=101, transform=ccrs.Geodetic())
    
    # a95
    for i in range(len(plon_fix)):
        equi_filled(ax, plon_fix[i], plat_fix[i], a95_fix_km[i], color_fix, alpha=0.3)
    for i in range(len(rotated_plon)):
        equi_filled(ax, rotated_plon[i], rotated_plat[i], a95_rot_km[i], color_rot, alpha=0.3)
        
    # create fake legend
    ax.scatter([], [], marker=marker_fix,
               color=color_fix, edgecolors='k', s=s_fix,
               label=label_fix, transform=ccrs.Geodetic())
    ax.scatter([], [], marker=marker_rot,
               color=color_rot, edgecolors='k', s=s_rot,
               label=label_rot, transform=ccrs.Geodetic())
    
    # colorbar
    color_mapping._A = []
    plt.colorbar(color_mapping, orientation='horizontal', shrink=0.8,
                 pad=0.05, label='age [Ma]')
    
    # prettify
    ax.legend(loc=4, fontsize=12)
    ax.set_title('{} rotated to {} - Euler : {}'.format(label_rot,label_fix,str(Euler)))
    
    plt.show()

# %%
SChina_color = '#2ecc71'
Laurentia_color = '#1e5b8d'
Svalbard_color = '#8ab6d4'
Australia_color = '#e74c3c'
India_color = '#f5c10e'
Rayner_color = '#ffe27e'
Siberia_color = '#3498db'
Antarctica_color = '#ff9f96'
etcetera_color = '#b2b3b2'

# %%
# fixed Eulers
Greenland_Laur_Euler = [67.5,-118.5,-13.8]
Svalbard_Laur_Euler = [-81.0,125.0,68.0]
Siberia_Laur_Euler = [77.0,98.0,137.0]
SChina_India_Euler = [6.7224,77.6921,67.9571]
SAus_Laur_Euler = [-30.2638,-19.1192,-131.7445]
NAus_SAus_Euler = [-20.0,135.0,-40.0]
Antarctica_SAus_Euler = [-3.91,37.9,30.86]
Rayner_India_Euler = [1.8434,-165.1696,-91.8395]

Scotland_Laur_Euler = [78.64,161.9,-32.0]
Amazonia_Laur_Euler = [11.97,-47.01,-110.66]
Parana_Amazonia_Euler = [0.67,103.22,-30.82]
RDLP_Amazonia_Euler = [0.67,103.22,-30.82]
Baltica_Laur_Euler = [75.8,-95.8,-59.2]
NChina_Laur_Euler = [52.9462,27.2366,61.9218]
Kalahari_Laur_Euler = [15.102,-25.2783,-157.5464]

# %% [markdown]
# #### 755

# %%
# time varying Eulers
Laur_Euler_720 = [-47.05,-2.16,156.4]
India_Euler_755 = [65.4126,103.9231,-29.3572]
TPW_Euler_755 = [-7.6,-178.33,-16.15]

# %%
ax = ipmag.make_orthographic_map(add_land=False, central_longitude=110, central_latitude=0,
                                 figsize=(8,8), grid_lines=False)

cratons_lw = 0.5
cratons_alpha = 1.0

# Laurentia
craton_plot(ax, [101], [Laur_Euler_755, TPW_Euler_755],
            'k', Laurentia_color, cratons_alpha, cratons_lw)

# Greenland
craton_plot(ax, [102], [Greenland_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Svalbard_color, cratons_alpha, cratons_lw)

# Svalbard
craton_plot(ax, [311], [Svalbard_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Svalbard_color, cratons_alpha, cratons_lw)

# Australia
craton_plot(ax, [801], [SAus_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Australia_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [8011], [NAus_SAus_Euler, SAus_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Australia_color, cratons_alpha, cratons_lw, reverse_draw=True)

# Antarctica
craton_plot(ax, [802], [Antarctica_SAus_Euler, SAus_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Antarctica_color, cratons_alpha, cratons_lw)

# India
craton_plot(ax, [501], [India_Euler_755, TPW_Euler_755],
            'k', India_color, cratons_alpha, cratons_lw)

# Rayner
craton_plot(ax, [803], [Rayner_India_Euler, India_Euler_755, TPW_Euler_755],
            'k', Rayner_color, cratons_alpha, cratons_lw)

# Siberia
craton_plot(ax, [401], [Siberia_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Siberia_color, cratons_alpha, cratons_lw, reverse_draw=True)

# South China
craton_plot(ax, [6024], [SChina_India_Euler, India_Euler_755, TPW_Euler_755],
            'k', SChina_color, cratons_alpha, cratons_lw)
craton_plot(ax, [6023], [SChina_India_Euler, India_Euler_755, TPW_Euler_755],
            'k', SChina_color, cratons_alpha, cratons_lw)
craton_plot(ax, [602], [SChina_India_Euler, India_Euler_755, TPW_Euler_755],
            'k', SChina_color, cratons_alpha, cratons_lw)

# etcetera blocks
craton_plot(ax, [303], [Scotland_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [201], [Amazonia_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [202], [Parana_Amazonia_Euler, Amazonia_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [203], [RDLP_Amazonia_Euler, Amazonia_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [302], [Baltica_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [601], [NChina_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [7011], [Kalahari_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)

### POLES

poles_alpha = 0.5
poles_markersize = 70

# # Australia
# df_slice = Australia[Australia['name']=='Mundine Well Dykes Combined']
# pole_color = color_mapping.to_rgba([df_slice['age'].iloc[0]]).tolist()
# rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
#                   [SAus_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
#                   'o', poles_markersize, pole_color, Australia_color, poles_alpha)

# # India
# df_slice = India[India['name']=='Malani Igneous Suite -Comb']
# pole_color = color_mapping.to_rgba([df_slice['age'].iloc[0]]).tolist()
# rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
#                   [India_Euler_755, TPW_Euler_755],
#                   'o', poles_markersize, pole_color, India_color, poles_alpha)

# # Siberia
# df_slice = Siberia[Siberia['name']=='Kitoi Cryogenian dykes']
# pole_color = color_mapping.to_rgba([df_slice['age'].iloc[0]]).tolist()
# rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
#                   [Siberia_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
#                   'o', poles_markersize, pole_color, Siberia_color, poles_alpha)

# # Laurentia
# df_slice = Laurentia[Laurentia['name']=='Carbon Canyon']
# pole_color = color_mapping.to_rgba([df_slice['age'].iloc[0]]).tolist()
# rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
#                   [Laur_Euler_755, TPW_Euler_755],
#                   'o', poles_markersize, pole_color, Laurentia_color, poles_alpha)

# # South China
# df_slice = SChina_site_06[SChina_site_06['name']=='Liantuo Formation - Jing et al. (2021) site mean (f=0.6)']
# pole_color = color_mapping.to_rgba([df_slice['age'].iloc[0]]).tolist()
# rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
#                   [SChina_India_Euler, India_Euler_755, TPW_Euler_755],
#                   'o', poles_markersize, pole_color, SChina_color, poles_alpha)
# df_slice = SChina_site_06[SChina_site_06['name']=='Liantuo Formation - site mean (f=0.6)']
# pole_color = color_mapping.to_rgba([df_slice['age'].iloc[0]]).tolist()
# rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
#                   [SChina_India_Euler, India_Euler_755, TPW_Euler_755],
#                   'o', poles_markersize, pole_color, SChina_color, poles_alpha)

ax.gridlines(xlocs=lon_grid, ylocs=lat_grid, linewidth=0.5,
             color='C7', linestyle='dotted', zorder=-1)

#plt.savefig('../Output/TPW_model_755.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## South China Poles

# %%
compilation_cols = ['name',
                    'terrane',
                    'age',
                    'age upper',
                    'age lower',
                    'plat',
                    'plon',
                    'a95',
                    'f',
                    'slat',
                    'slon',
                    'dec',
                    'inc',
                    'dir_a95',
                    'pole ref',
                    'age ref',
                    'grade',
                    'note',
                    'plateID']

# %%
SChina = pd.DataFrame(columns=compilation_cols)
i = 0

# %% [markdown]
# ### Banxi Group
#
# * These poles are developed in `Banxi_site_analysis.ipynb`.

# %%
SChina.loc[i, 'name']    = 'Banxi Group - site mean (f=1.0)'
SChina.loc[i, 'terrane'] = 'SChina'
SChina.loc[i, 'age']       = 813
SChina.loc[i, 'age upper'] = 813 + 3
SChina.loc[i, 'age lower'] = 813 - 3
SChina.loc[i, 'plat'] = 50.7
SChina.loc[i, 'plon'] = 100.0
SChina.loc[i, 'a95']  = 12.3
SChina.loc[i, 'f'] = 1.0
SChina.loc[i, 'slat'] = 27.91
SChina.loc[i, 'slon'] = 108.82
SChina.loc[i, 'dec']     = 346.7
SChina.loc[i, 'inc']     = 77.0
SChina.loc[i, 'dir_a95'] = 6.9
SChina.loc[i, 'pole ref'] = 'this study'
SChina.loc[i, 'age ref']  = 'this study'
SChina.loc[i, 'grade'] = 'NR'
SChina.loc[i, 'note']  = '-'
SChina.loc[i, 'plateID'] = 602
i = i + 1

# %%
SChina.loc[i, 'name']    = 'Banxi Group - site mean (f=0.6)'
SChina.loc[i, 'terrane'] = 'SChina'
SChina.loc[i, 'age']       = 813
SChina.loc[i, 'age upper'] = 813 + 3
SChina.loc[i, 'age lower'] = 813 - 3
SChina.loc[i, 'plat'] = 42.7
SChina.loc[i, 'plon'] = 104.0
SChina.loc[i, 'a95']  = 8.1
SChina.loc[i, 'f'] = 0.6
SChina.loc[i, 'slat'] = 27.91
SChina.loc[i, 'slon'] = 108.82
SChina.loc[i, 'dec']     = 346.8
SChina.loc[i, 'inc']     = 82.0
SChina.loc[i, 'dir_a95'] = 4.3
SChina.loc[i, 'pole ref'] = 'this study'
SChina.loc[i, 'age ref']  = 'this study'
SChina.loc[i, 'grade'] = 'NR'
SChina.loc[i, 'note']  = '-'
SChina.loc[i, 'plateID'] = 602
i = i + 1

# %%
SChina.loc[i, 'name']    = 'Banxi Group - specimen mean (f=1.0)'
SChina.loc[i, 'terrane'] = 'SChina'
SChina.loc[i, 'age']       = 813
SChina.loc[i, 'age upper'] = 813 + 3
SChina.loc[i, 'age lower'] = 813 - 3
SChina.loc[i, 'plat'] = 50.6
SChina.loc[i, 'plon'] = 107.1
SChina.loc[i, 'a95']  = 6.9
SChina.loc[i, 'f'] = 1.0
SChina.loc[i, 'slat'] = 27.91
SChina.loc[i, 'slon'] = 108.82
SChina.loc[i, 'dec']     = 358.3
SChina.loc[i, 'inc']     = 76.8
SChina.loc[i, 'dir_a95'] = 4.3
SChina.loc[i, 'pole ref'] = 'this study'
SChina.loc[i, 'age ref']  = 'this study'
SChina.loc[i, 'grade'] = 'NR'
SChina.loc[i, 'note']  = '-'
SChina.loc[i, 'plateID'] = 602
i = i + 1

# %%
SChina.loc[i, 'name']    = 'Banxi Group - specimen mean (f=0.6)'
SChina.loc[i, 'terrane'] = 'SChina'
SChina.loc[i, 'age']       = 813
SChina.loc[i, 'age upper'] = 813 + 3
SChina.loc[i, 'age lower'] = 813 - 3
SChina.loc[i, 'plat'] = 43.2
SChina.loc[i, 'plon'] = 108.1
SChina.loc[i, 'a95']  = np.sqrt(5.3*5.5)
SChina.loc[i, 'f'] = 0.6
SChina.loc[i, 'slat'] = 27.91
SChina.loc[i, 'slon'] = 108.82
SChina.loc[i, 'dec']     = 359.2
SChina.loc[i, 'inc']     = 81.5
SChina.loc[i, 'dir_a95'] = 2.8
SChina.loc[i, 'pole ref'] = 'this study'
SChina.loc[i, 'age ref']  = 'this study'
SChina.loc[i, 'grade'] = 'NR'
SChina.loc[i, 'note']  = '-'
SChina.loc[i, 'plateID'] = 602
i = i + 1

# %%
SChina.loc[i, 'name']    = 'Banxi Group - lower site mean (f=0.6)'
SChina.loc[i, 'terrane'] = 'SChina'
SChina.loc[i, 'age']       = 813
SChina.loc[i, 'age upper'] = 813 + 3
SChina.loc[i, 'age lower'] = 813 - 3
SChina.loc[i, 'plat'] = 42.0
SChina.loc[i, 'plon'] = 105.9
SChina.loc[i, 'a95']  = 10.4
SChina.loc[i, 'f'] = 0.6
SChina.loc[i, 'slat'] = 27.91
SChina.loc[i, 'slon'] = 108.82
SChina.loc[i, 'dec']     = 351.4
SChina.loc[i, 'inc']     = 82.6
SChina.loc[i, 'dir_a95'] = 5.5
SChina.loc[i, 'pole ref'] = 'this study'
SChina.loc[i, 'age ref']  = 'this study'
SChina.loc[i, 'grade'] = 'NR'
SChina.loc[i, 'note']  = '-'
SChina.loc[i, 'plateID'] = 602
i = i + 1

# %%
SChina.loc[i, 'name']    = 'Banxi Group - upper site mean (f=0.6)'
SChina.loc[i, 'terrane'] = 'SChina'
SChina.loc[i, 'age']       = 813
SChina.loc[i, 'age upper'] = 813 + 3
SChina.loc[i, 'age lower'] = 813 - 3
SChina.loc[i, 'plat'] = 44.7
SChina.loc[i, 'plon'] = 98.7
SChina.loc[i, 'a95']  = 16.5
SChina.loc[i, 'f'] = 0.6
SChina.loc[i, 'slat'] = 27.91
SChina.loc[i, 'slon'] = 108.82
SChina.loc[i, 'dec']     = 337.1
SChina.loc[i, 'inc']     = 80.4
SChina.loc[i, 'dir_a95'] = 8.6
SChina.loc[i, 'pole ref'] = 'this study'
SChina.loc[i, 'age ref']  = 'this study'
SChina.loc[i, 'grade'] = 'NR'
SChina.loc[i, 'note']  = '-'
SChina.loc[i, 'plateID'] = 602
i = i + 1

# %% [markdown]
# ### Yanbian Dikes
#
# * A 5 degree vertical axis rotation is applied to these data in the paper. They are not tilt-corrected (except for one) although they are located within a mobile belt.
# * Baked contact test, dike-tilt test, rock magnetism.
# * SIMS on dike.

# %%
SChina.loc[i, 'name']    = 'Yanbian Dikes Group A'
SChina.loc[i, 'terrane'] = 'SChina'
SChina.loc[i, 'age']       = 824
SChina.loc[i, 'age upper'] = 824 + 6
SChina.loc[i, 'age lower'] = 824 - 6
SChina.loc[i, 'plat'] = 45.1
SChina.loc[i, 'plon'] = 130.4
SChina.loc[i, 'a95']  = 19.0
SChina.loc[i, 'f'] = 1.0
SChina.loc[i, 'slat'] = 26.886
SChina.loc[i, 'slon'] = 101.546
SChina.loc[i, 'dec']     = np.nan
SChina.loc[i, 'inc']     = np.nan
SChina.loc[i, 'dir_a95'] = np.nan
SChina.loc[i, 'pole ref'] = 'Niu et al. (2016)'
SChina.loc[i, 'age ref']  = 'Niu et al. (2016)'
SChina.loc[i, 'grade'] = 'B'
SChina.loc[i, 'note']  = '-'
SChina.loc[i, 'plateID'] = 602
i = i + 1

# %% [markdown]
# ### Xiaofeng Dikes
#
# * Age from TIMS on tuffs.
# * Reversal test, regional geology.
# * Pole recalculated in Jing et al. (2019)
# * Specimen level data not available with publication.

# %%
SChina.loc[i, 'name']    = 'Xiaofeng Dikes - Li et al. (2004)'
SChina.loc[i, 'terrane'] = 'SChina'
SChina.loc[i, 'age']       = ((821.64 + 0.2) + (821.10 - 0.2))/2
SChina.loc[i, 'age upper'] = 821.64 + 0.2
SChina.loc[i, 'age lower'] = 821.10 - 0.2
SChina.loc[i, 'plat'] = 13.5
SChina.loc[i, 'plon'] = 91.0
SChina.loc[i, 'a95']  = np.sqrt(10.5*11.3)
SChina.loc[i, 'f'] = 1.0
SChina.loc[i, 'slat'] = 30.96
SChina.loc[i, 'slon'] = 111.23
SChina.loc[i, 'dec']     = 51.3+180
SChina.loc[i, 'inc']     = -(-76.6)
SChina.loc[i, 'dir_a95'] = 6.1
SChina.loc[i, 'pole ref'] = 'Li et al. (2004)'
SChina.loc[i, 'age ref']  = 'Wang et al. (2016)'
SChina.loc[i, 'grade'] = 'B'
SChina.loc[i, 'note']  = '-'
SChina.loc[i, 'plateID'] = 602
i = i + 1

SChina.loc[i, 'name']    = 'Xiaofeng Dikes - Jing et al. (2019)'
SChina.loc[i, 'terrane'] = 'SChina'
SChina.loc[i, 'age']       = ((821.64 + 0.2) + (821.10 - 0.2))/2
SChina.loc[i, 'age upper'] = 821.64 + 0.2
SChina.loc[i, 'age lower'] = 821.10 - 0.2
SChina.loc[i, 'plat'] = 26.1
SChina.loc[i, 'plon'] = 82.1
SChina.loc[i, 'a95']  = np.sqrt(14.0*15.2)
SChina.loc[i, 'f'] = 1.0
SChina.loc[i, 'slat'] = 30.96
SChina.loc[i, 'slon'] = 111.23
SChina.loc[i, 'dec']     = 86.5+180
SChina.loc[i, 'inc']     = -(-76.3)
SChina.loc[i, 'dir_a95'] = 8.2
SChina.loc[i, 'pole ref'] = 'Jing et al. (2019)'
SChina.loc[i, 'age ref']  = 'Wang et al. (2016)'
SChina.loc[i, 'grade'] = 'B'
SChina.loc[i, 'note']  = '-'
SChina.loc[i, 'plateID'] = 602
i = i + 1

# %% [markdown]
# ### Madiyi Formation
#
# * Inclination correction preferred by authors.
# * Reversal test.
# * SIMS on tuff.
# * Age updated with CA-ID-TIMS in this study.

# %% [markdown]
# Specimen mean, as reported in Xian et al. (2020):

# %%
SChina.loc[i, 'name']    = 'Madiyi Formation - specimen mean (f=1.0)'
SChina.loc[i, 'terrane'] = 'SChina'
SChina.loc[i, 'age']       = 804.9
SChina.loc[i, 'age upper'] = 804.9 + 0.36
SChina.loc[i, 'age lower'] = 804.9 - 0.36
SChina.loc[i, 'plat'] = 35.3
SChina.loc[i, 'plon'] = 67.9
SChina.loc[i, 'a95']  = np.sqrt(4.7*5.5)
SChina.loc[i, 'f'] = 1.0
SChina.loc[i, 'slat'] = 27.5
SChina.loc[i, 'slon'] = 109.6
SChina.loc[i, 'dec']     = 293.1
SChina.loc[i, 'inc']     = 69.9
SChina.loc[i, 'dir_a95'] = 3.2
SChina.loc[i, 'pole ref'] = 'Xian et al. (2020)'
SChina.loc[i, 'age ref']  = 'this study'
SChina.loc[i, 'grade'] = 'NR'
SChina.loc[i, 'note']  = '-'
SChina.loc[i, 'plateID'] = 602
i = i + 1

# %%
SChina.loc[i, 'name']    = 'Madiyi Formation - specimen mean (f=0.6)'
SChina.loc[i, 'terrane'] = 'SChina'
SChina.loc[i, 'age']       = 804.9
SChina.loc[i, 'age upper'] = 804.9 + 0.36
SChina.loc[i, 'age lower'] = 804.9 - 0.36
SChina.loc[i, 'plat'] = 34.3
SChina.loc[i, 'plon'] = 82.4
SChina.loc[i, 'a95']  = np.sqrt(3.9*3.7)
SChina.loc[i, 'f'] = 0.6
SChina.loc[i, 'slat'] = 27.5
SChina.loc[i, 'slon'] = 109.6
SChina.loc[i, 'dec']     = 293.0
SChina.loc[i, 'inc']     = 77.3
SChina.loc[i, 'dir_a95'] = 2.1
SChina.loc[i, 'pole ref'] = 'Xian et al. (2020)'
SChina.loc[i, 'age ref']  = 'this study'
SChina.loc[i, 'grade'] = 'NR'
SChina.loc[i, 'note']  = '-'
SChina.loc[i, 'plateID'] = 602
i = i + 1

# %% [markdown]
# Calculate our own site mean version of the pole:

# %%
Xian2020 = pd.read_csv('../Data/Xian2020a.csv')
Xian2020.columns
# Out:
# Index(['site', 'n', 'dec_geog', 'inc_geog', 'dec', 'inc', 'k', 'a95', 'plat',
#        'plon', 'dp', 'dm', 'polarity'],
#       dtype='object')

# %%
fignum = 1
plt.figure(num=fignum,figsize=(5,5))
ipmag.plot_net(fignum)
for j in range(len(Xian2020)):
    ipmag.plot_di_mean(Xian2020['dec'][j], Xian2020['inc'][j], Xian2020['a95'][j], color='C0')
plt.show()

# %%
Xian2020_inc_flipped = []
Xian2020_dec_flipped = []
Xian2020_a95_flipped = []

for j in range(len(Xian2020)):
    if Xian2020['inc'][j] < 0:
        Xian2020_inc_flipped.append(-Xian2020['inc'][j])
        Xian2020_dec_flipped.append(Xian2020['dec'][j]+180)
    else:
        Xian2020_inc_flipped.append(Xian2020['inc'][j])
        Xian2020_dec_flipped.append(Xian2020['dec'][j])
    Xian2020_a95_flipped.append(Xian2020['a95'][j])

Xian2020_site_mean_10 = ipmag.fisher_mean(Xian2020_dec_flipped,Xian2020_inc_flipped)

ipmag.print_direction_mean(Xian2020_site_mean_10)

fignum = 1
plt.figure(num=fignum,figsize=(5,5))
ipmag.plot_net(fignum)
for j in range(len(Xian2020)):
    ipmag.plot_di_mean(Xian2020_dec_flipped[j], Xian2020_inc_flipped[j], Xian2020_a95_flipped[j], color='C0')
ipmag.plot_di_mean(Xian2020_site_mean_10['dec'],
                   Xian2020_site_mean_10['inc'],
                   Xian2020_site_mean_10['alpha95'],
                   color='k')
plt.show()
# Out:
# Dec: 293.7  Inc: 69.0
# Number of directions in mean (n): 12
# Angular radius of 95% confidence (a_95): 5.8
# Precision parameter (k) estimate: 56.5

# %%
print('site mean VGP, f = 1.0 - (lon, lat, dp, dm)')
Madiyi_site_10_vgp = pmag.dia_vgp(Xian2020_site_mean_10['dec'],
                                  Xian2020_site_mean_10['inc'],
                                  Xian2020_site_mean_10['alpha95'],
                                  27.5,109.6)
Madiyi_site_10_vgp
# Out:
# site mean VGP, f = 1.0 - (lon, lat, dp, dm)
# (66.23702125862057, 35.707893358138506, 8.408037964380522, 9.89658126030523)

# %% [markdown]
# Convert to pole space prior to calculating the mean:

# %%
Madiyi_site_10_vgp_lats = []
Madiyi_site_10_vgp_lons = []
for n in range(len(Xian2020)):
    Madiyi_10_vgp = pmag.dia_vgp(Xian2020_dec_flipped[n], 
                                 Xian2020_inc_flipped[n], 
                                 Xian2020_a95_flipped[n],
                                 27.5,109.6)
    Madiyi_site_10_vgp_lons.append(Madiyi_10_vgp[0])
    Madiyi_site_10_vgp_lats.append(Madiyi_10_vgp[1])
Madiyi_site_10_vgp_mean_pole = ipmag.fisher_mean(Madiyi_site_10_vgp_lons,Madiyi_site_10_vgp_lats)
ipmag.print_pole_mean(Madiyi_site_10_vgp_mean_pole)

map_axis = ipmag.make_orthographic_map(figsize=(5,5),central_longitude=100,central_latitude=30)
ipmag.plot_vgp(map_axis,Madiyi_site_10_vgp_lons,Madiyi_site_10_vgp_lats)
ipmag.plot_pole(map_axis,Madiyi_site_10_vgp_mean_pole['dec'],
                Madiyi_site_10_vgp_mean_pole['inc'],
                Madiyi_site_10_vgp_mean_pole['alpha95'],marker='s')
# Out:
# Plon: 67.4  Plat: 35.9
# Number of directions in mean (n): 12
# Angular radius of 95% confidence (A_95): 9.3
# Precision parameter (k) estimate: 22.9

# %%
SChina.loc[i, 'name']    = 'Madiyi Formation - site mean (f=1.0)'
SChina.loc[i, 'terrane'] = 'SChina'
SChina.loc[i, 'age']       = 804.9
SChina.loc[i, 'age upper'] = 804.9 + 0.36
SChina.loc[i, 'age lower'] = 804.9 - 0.36
SChina.loc[i, 'plat'] = Madiyi_site_10_vgp_mean_pole['inc']
SChina.loc[i, 'plon'] = Madiyi_site_10_vgp_mean_pole['dec']
SChina.loc[i, 'a95']  = Madiyi_site_10_vgp_mean_pole['alpha95']
SChina.loc[i, 'f'] = 1.0
SChina.loc[i, 'slat'] = 27.5
SChina.loc[i, 'slon'] = 109.6
SChina.loc[i, 'dec']     = Xian2020_site_mean_10['dec']
SChina.loc[i, 'inc']     = Xian2020_site_mean_10['inc']
SChina.loc[i, 'dir_a95'] = Xian2020_site_mean_10['alpha95']
SChina.loc[i, 'pole ref'] = 'Xian et al. (2020)'
SChina.loc[i, 'age ref']  = 'this study'
SChina.loc[i, 'grade'] = 'NR'
SChina.loc[i, 'note']  = '-'
SChina.loc[i, 'plateID'] = 602
i = i + 1

# %% [markdown]
# Apply a per-site inclination correction:

# %%
Xian2020_inc_flipped_ic = ipmag.unsquish(Xian2020_inc_flipped, 0.6)

Xian2020_site_mean_06 = ipmag.fisher_mean(Xian2020_dec_flipped,Xian2020_inc_flipped_ic)

ipmag.print_direction_mean(Xian2020_site_mean_06)

fignum = 1
plt.figure(num=fignum,figsize=(5,5))
ipmag.plot_net(fignum)
for j in range(len(Xian2020)):
    ipmag.plot_di_mean(Xian2020_dec_flipped[j], Xian2020_inc_flipped_ic[j], Xian2020_a95_flipped[j], color='C0')
ipmag.plot_di_mean(Xian2020_site_mean_06['dec'],
                   Xian2020_site_mean_06['inc'],
                   Xian2020_site_mean_06['alpha95'],
                   color='k')
plt.show()
# Out:
# Dec: 293.6  Inc: 76.9
# Number of directions in mean (n): 12
# Angular radius of 95% confidence (a_95): 3.7
# Precision parameter (k) estimate: 135.5

# %%
print('site mean VGP, f = 0.6 - (lon, lat, dp, dm)')
Madiyi_site_06_vgp = pmag.dia_vgp(Xian2020_site_mean_06['dec'],
                                  Xian2020_site_mean_06['inc'],
                                  Xian2020_site_mean_06['alpha95'],
                                  27.5,109.6)
Madiyi_site_06_vgp
# Out:
# site mean VGP, f = 0.6 - (lon, lat, dp, dm)
# (81.52920387112, 34.63619151604563, 6.4819258816260925, 6.964679231756815)

# %% [markdown]
# Convert to pole space prior to calculating the mean:

# %%
Madiyi_site_06_vgp_lats = []
Madiyi_site_06_vgp_lons = []
for n in range(len(Xian2020)):
    Madiyi_06_vgp = pmag.dia_vgp(Xian2020_dec_flipped[n], 
                                 Xian2020_inc_flipped_ic[n], 
                                 Xian2020_a95_flipped[n],
                                 27.5,109.6)
    Madiyi_site_06_vgp_lons.append(Madiyi_06_vgp[0])
    Madiyi_site_06_vgp_lats.append(Madiyi_06_vgp[1])
Madiyi_site_06_vgp_mean_pole = ipmag.fisher_mean(Madiyi_site_06_vgp_lons,Madiyi_site_06_vgp_lats)
ipmag.print_pole_mean(Madiyi_site_06_vgp_mean_pole)

map_axis = ipmag.make_orthographic_map(figsize=(5,5),central_longitude=100,central_latitude=30)
ipmag.plot_vgp(map_axis,Madiyi_site_06_vgp_lons,Madiyi_site_06_vgp_lats)
ipmag.plot_pole(map_axis,Madiyi_site_06_vgp_mean_pole['dec'],
                Madiyi_site_06_vgp_mean_pole['inc'],
                Madiyi_site_06_vgp_mean_pole['alpha95'],marker='s')
# Out:
# Plon: 82.0  Plat: 34.7
# Number of directions in mean (n): 12
# Angular radius of 95% confidence (A_95): 6.7
# Precision parameter (k) estimate: 42.9

# %%
SChina.loc[i, 'name']    = 'Madiyi Formation - site mean (f=0.6)'
SChina.loc[i, 'terrane'] = 'SChina'
SChina.loc[i, 'age']       = 804.9
SChina.loc[i, 'age upper'] = 804.9 + 0.36
SChina.loc[i, 'age lower'] = 804.9 - 0.36
SChina.loc[i, 'plat'] = Madiyi_site_06_vgp_mean_pole['inc']
SChina.loc[i, 'plon'] = Madiyi_site_06_vgp_mean_pole['dec']
SChina.loc[i, 'a95']  = Madiyi_site_06_vgp_mean_pole['alpha95']
SChina.loc[i, 'f'] = 0.6
SChina.loc[i, 'slat'] = 27.5
SChina.loc[i, 'slon'] = 109.6
SChina.loc[i, 'dec']     = Xian2020_site_mean_06['dec']
SChina.loc[i, 'inc']     = Xian2020_site_mean_06['inc']
SChina.loc[i, 'dir_a95'] = Xian2020_site_mean_06['alpha95']
SChina.loc[i, 'pole ref'] = 'Xian et al. (2020)'
SChina.loc[i, 'age ref']  = 'this study'
SChina.loc[i, 'grade'] = 'NR'
SChina.loc[i, 'note']  = '-'
SChina.loc[i, 'plateID'] = 602
i = i + 1

# %% [markdown]
# ### Chengjiang Formation
#
# * Fold test, reversal test.
# * SIMS on tuffaceous siltstone.

# %%
Chengjiang_sample_dec = 111.9+180
Chengjiang_sample_inc = -(-66.7)
Chengjiang_sample_a95 = 5.2
Chengjiang_sample_slat = 25.145
Chengjiang_sample_slon = 102.411

SChina.loc[i, 'name']    = 'Chengjiang Formation - specimen mean (f=1.0)'
SChina.loc[i, 'terrane'] = 'SChina'
SChina.loc[i, 'age']       = 799.5
SChina.loc[i, 'age upper'] = 799.5 + 8.4
SChina.loc[i, 'age lower'] = 799.5 - 8.4
SChina.loc[i, 'plat'] = 33.4
SChina.loc[i, 'plon'] = 56.1
SChina.loc[i, 'a95']  = np.sqrt(7.3*8.9)
SChina.loc[i, 'f'] = 1.0
SChina.loc[i, 'slat'] = Chengjiang_sample_slat
SChina.loc[i, 'slon'] = Chengjiang_sample_slon
SChina.loc[i, 'dec']     = Chengjiang_sample_dec
SChina.loc[i, 'inc']     = Chengjiang_sample_inc
SChina.loc[i, 'dir_a95'] = Chengjiang_sample_a95
SChina.loc[i, 'pole ref'] = 'Jing et al. (2019)'
SChina.loc[i, 'age ref']  = 'Jing et al. (2019)'
SChina.loc[i, 'grade'] = 'NR'
SChina.loc[i, 'note']  = '-'
SChina.loc[i, 'plateID'] = 602
i = i + 1

# %% [markdown]
# Do an inclination correction:

# %%
Chengjiang_sample_inc_unsquished = ipmag.unsquish([Chengjiang_sample_inc],0.6)[0]

Chengjiang_sample_vgp_unsquished = pmag.dia_vgp(Chengjiang_sample_dec,
                                                Chengjiang_sample_inc_unsquished,
                                                Chengjiang_sample_a95,
                                                Chengjiang_sample_slat,
                                                Chengjiang_sample_slon)

SChina.loc[i, 'name']    = 'Chengjiang Formation - specimen mean (f=0.6)'
SChina.loc[i, 'terrane'] = 'SChina'
SChina.loc[i, 'age']       = 799.5
SChina.loc[i, 'age upper'] = 799.5 + 8.4
SChina.loc[i, 'age lower'] = 799.5 - 8.4
SChina.loc[i, 'plat'] = Chengjiang_sample_vgp_unsquished[1]
SChina.loc[i, 'plon'] = Chengjiang_sample_vgp_unsquished[0]
SChina.loc[i, 'a95']  = np.sqrt(Chengjiang_sample_vgp_unsquished[2]*Chengjiang_sample_vgp_unsquished[3])
SChina.loc[i, 'f'] = 0.6
SChina.loc[i, 'slat'] = Chengjiang_sample_slat
SChina.loc[i, 'slon'] = Chengjiang_sample_slon
SChina.loc[i, 'dec']     = Chengjiang_sample_dec
SChina.loc[i, 'inc']     = Chengjiang_sample_inc_unsquished
SChina.loc[i, 'dir_a95'] = Chengjiang_sample_a95
SChina.loc[i, 'pole ref'] = 'Jing et al. (2019)'
SChina.loc[i, 'age ref']  = 'Jing et al. (2019)'
SChina.loc[i, 'grade'] = 'NR'
SChina.loc[i, 'note']  = 'Inclination correction calculated on mean direction only.'
SChina.loc[i, 'plateID'] = 602
i = i + 1

# %% [markdown]
# Calculate our own site mean version of the pole:

# %%
Jing2019 = pd.read_csv('../Data/Jing2019a.csv')
Jing2019.columns
# Out:
# Index(['site', 'component', 'n', 'dec_geog', 'inc_geog', 'dec', 'inc', 'k',
#        'a95', 'methods'],
#       dtype='object')

# %%
fignum = 1
plt.figure(num=fignum,figsize=(5,5))
ipmag.plot_net(fignum)
for j in range(len(Jing2019)):
    ipmag.plot_di_mean(Jing2019['dec'][j], Jing2019['inc'][j], Jing2019['a95'][j], color='C0')
plt.show()

# %%
Jing2019_inc_flipped = []
Jing2019_dec_flipped = []
Jing2019_a95_flipped = []

for j in range(len(Jing2019)):
    if Jing2019['inc'][j] < 0:
        Jing2019_inc_flipped.append(-Jing2019['inc'][j])
        Jing2019_dec_flipped.append(Jing2019['dec'][j]+180)
    else:
        Jing2019_inc_flipped.append(Jing2019['inc'][j])
        Jing2019_dec_flipped.append(Jing2019['dec'][j])
    Jing2019_a95_flipped.append(Jing2019['a95'][j])

Jing2019_site_mean_10 = ipmag.fisher_mean(Jing2019_dec_flipped,Jing2019_inc_flipped)

ipmag.print_direction_mean(Jing2019_site_mean_10)

fignum = 1
plt.figure(num=fignum,figsize=(5,5))
ipmag.plot_net(fignum)
for j in range(len(Jing2019)):
    ipmag.plot_di_mean(Jing2019_dec_flipped[j], Jing2019_inc_flipped[j], Jing2019_a95_flipped[j], color='C0')
ipmag.plot_di_mean(Jing2019_site_mean_10['dec'],
                   Jing2019_site_mean_10['inc'],
                   Jing2019_site_mean_10['alpha95'],
                   color='k')
plt.show()
# Out:
# Dec: 287.0  Inc: 69.2
# Number of directions in mean (n): 10
# Angular radius of 95% confidence (a_95): 6.9
# Precision parameter (k) estimate: 50.2

# %%
print('site mean VGP, f = 1.0 - (lon, lat, dp, dm)')
Chengjiang_site_10_vgp = pmag.dia_vgp(Jing2019_site_mean_10['dec'],
                                      Jing2019_site_mean_10['inc'],
                                      Jing2019_site_mean_10['alpha95'],
                                      25.145,102.411)
Chengjiang_site_10_vgp
# Out:
# site mean VGP, f = 1.0 - (lon, lat, dp, dm)
# (60.468640787495104, 29.910191732142124, 9.981480935519455, 11.72551538051991)

# %% [markdown]
# Convert to pole space prior to calculating the mean:

# %%
Chengjiang_site_10_vgp_lats = []
Chengjiang_site_10_vgp_lons = []
for n in range(len(Jing2019)):
    Chengjiang_10_vgp = pmag.dia_vgp(Jing2019_dec_flipped[n], 
                                 Jing2019_inc_flipped[n], 
                                 Jing2019_a95_flipped[n],
                                 25.145,102.411)
    Chengjiang_site_10_vgp_lons.append(Chengjiang_10_vgp[0])
    Chengjiang_site_10_vgp_lats.append(Chengjiang_10_vgp[1])
Chengjiang_site_10_vgp_mean_pole = ipmag.fisher_mean(Chengjiang_site_10_vgp_lons,Chengjiang_site_10_vgp_lats)
ipmag.print_pole_mean(Chengjiang_site_10_vgp_mean_pole)

map_axis = ipmag.make_orthographic_map(figsize=(5,5),central_longitude=100,central_latitude=30)
ipmag.plot_vgp(map_axis,Chengjiang_site_10_vgp_lons,Chengjiang_site_10_vgp_lats)
ipmag.plot_pole(map_axis,Chengjiang_site_10_vgp_mean_pole['dec'],
                Chengjiang_site_10_vgp_mean_pole['inc'],
                Chengjiang_site_10_vgp_mean_pole['alpha95'],marker='s')
# Out:
# Plon: 61.5  Plat: 29.4
# Number of directions in mean (n): 10
# Angular radius of 95% confidence (A_95): 10.7
# Precision parameter (k) estimate: 21.5

# %%
SChina.loc[i, 'name']    = 'Chengjiang Formation - site mean (f=1.0)'
SChina.loc[i, 'terrane'] = 'SChina'
SChina.loc[i, 'age']       = 799.5
SChina.loc[i, 'age upper'] = 799.5 + 8.4
SChina.loc[i, 'age lower'] = 799.5 - 8.4
SChina.loc[i, 'plat'] = Chengjiang_site_10_vgp_mean_pole['inc']
SChina.loc[i, 'plon'] = Chengjiang_site_10_vgp_mean_pole['dec']
SChina.loc[i, 'a95']  = Chengjiang_site_10_vgp_mean_pole['alpha95']
SChina.loc[i, 'f'] = 1.0
SChina.loc[i, 'slat'] = 25.145
SChina.loc[i, 'slon'] = 102.411
SChina.loc[i, 'dec']     = Jing2019_site_mean_10['dec']
SChina.loc[i, 'inc']     = Jing2019_site_mean_10['inc']
SChina.loc[i, 'dir_a95'] = Jing2019_site_mean_10['alpha95']
SChina.loc[i, 'pole ref'] = 'Jing et al. (2019)'
SChina.loc[i, 'age ref']  = 'Jing et al. (2019)'
SChina.loc[i, 'grade'] = 'NR'
SChina.loc[i, 'note']  = '-'
SChina.loc[i, 'plateID'] = 602
i = i + 1

# %% [markdown]
# Apply a per-site inclination correction:

# %%
Jing2019_inc_flipped_ic = ipmag.unsquish(Jing2019_inc_flipped, 0.6)

Jing2019_site_mean_06 = ipmag.fisher_mean(Jing2019_dec_flipped,Jing2019_inc_flipped_ic)

ipmag.print_direction_mean(Jing2019_site_mean_06)

fignum = 1
plt.figure(num=fignum,figsize=(5,5))
ipmag.plot_net(fignum)
for j in range(len(Jing2019)):
    ipmag.plot_di_mean(Jing2019_dec_flipped[j], Jing2019_inc_flipped_ic[j], Jing2019_a95_flipped[j], color='C0')
ipmag.plot_di_mean(Jing2019_site_mean_06['dec'],
                   Jing2019_site_mean_06['inc'],
                   Jing2019_site_mean_06['alpha95'],
                   color='k')
plt.show()
# Out:
# Dec: 287.5  Inc: 77.0
# Number of directions in mean (n): 10
# Angular radius of 95% confidence (a_95): 4.5
# Precision parameter (k) estimate: 116.6

# %%
print('site mean VGP, f = 0.6 - (lon, lat, dp, dm)')
Chengjiang_site_06_vgp = pmag.dia_vgp(Jing2019_site_mean_06['dec'],
                                      Jing2019_site_mean_06['inc'],
                                      Jing2019_site_mean_06['alpha95'],
                                      25.145,102.411)
Chengjiang_site_06_vgp
# Out:
# site mean VGP, f = 0.6 - (lon, lat, dp, dm)
# (74.87591425837131, 29.99061271175446, 7.795518818464973, 8.368132429674855)

# %% [markdown]
# Convert to pole space prior to calculating the mean:

# %%
Chengjiang_site_06_vgp_lats = []
Chengjiang_site_06_vgp_lons = []
for n in range(len(Jing2019)):
    Chengjiang_06_vgp = pmag.dia_vgp(Jing2019_dec_flipped[n], 
                                 Jing2019_inc_flipped_ic[n], 
                                 Jing2019_a95_flipped[n],
                                 25.145,102.411)
    Chengjiang_site_06_vgp_lons.append(Chengjiang_06_vgp[0])
    Chengjiang_site_06_vgp_lats.append(Chengjiang_06_vgp[1])
Chengjiang_site_06_vgp_mean_pole = ipmag.fisher_mean(Chengjiang_site_06_vgp_lons,Chengjiang_site_06_vgp_lats)
ipmag.print_pole_mean(Chengjiang_site_06_vgp_mean_pole)

map_axis = ipmag.make_orthographic_map(figsize=(5,5),central_longitude=100,central_latitude=30)
ipmag.plot_vgp(map_axis,Chengjiang_site_06_vgp_lons,Chengjiang_site_06_vgp_lats)
ipmag.plot_pole(map_axis,Chengjiang_site_06_vgp_mean_pole['dec'],
                Chengjiang_site_06_vgp_mean_pole['inc'],
                Chengjiang_site_06_vgp_mean_pole['alpha95'],marker='s')
# Out:
# Plon: 75.3  Plat: 29.7
# Number of directions in mean (n): 10
# Angular radius of 95% confidence (A_95): 7.9
# Precision parameter (k) estimate: 38.6

# %%
SChina.loc[i, 'name']    = 'Chengjiang Formation - site mean (f=0.6)'
SChina.loc[i, 'terrane'] = 'SChina'
SChina.loc[i, 'age']       = 799.5
SChina.loc[i, 'age upper'] = 799.5 + 8.4
SChina.loc[i, 'age lower'] = 799.5 - 8.4
SChina.loc[i, 'plat'] = Chengjiang_site_06_vgp[1]
SChina.loc[i, 'plon'] = Chengjiang_site_06_vgp[0]
SChina.loc[i, 'a95']  = np.sqrt(Chengjiang_site_06_vgp[2]*Chengjiang_site_06_vgp[3])
SChina.loc[i, 'f'] = 0.6
SChina.loc[i, 'slat'] = 25.145
SChina.loc[i, 'slon'] = 102.411
SChina.loc[i, 'dec']     = Jing2019_site_mean_06['dec']
SChina.loc[i, 'inc']     = Jing2019_site_mean_06['inc']
SChina.loc[i, 'dir_a95'] = Jing2019_site_mean_06['alpha95']
SChina.loc[i, 'pole ref'] = 'Jing et al. (2019)'
SChina.loc[i, 'age ref']  = 'Jing et al. (2019)'
SChina.loc[i, 'grade'] = 'NR'
SChina.loc[i, 'note']  = '-'
SChina.loc[i, 'plateID'] = 602
i = i + 1

# %% [markdown]
# ### Liantuo Formation
#
# * Three versions of the pole:
#     * Jing et al. (2015)
#     * grand mean pole of Evans et al. (2000) and Jing et al. (2015), similar to just the Jing et al. (2015) pole
#     * Jing et al. (2021)
# * Preliminary TIMS on tuff is 778 Ma - redated from 748 ± 12 Ma in Ma et al. (1984)
# * But Jing et al. (2015) prefers an age of ~720 Ma based on SIMS ages from the upper Liantuo Formation (Lan et al. 2015)
# * Age updated based on CA-ID-TIMS in this study.
#     * We prefer an age closer to the upper age constraint.

# %%
Liantuo_site_dec = 102.5
Liantuo_site_inc = 62.4
Liantuo_site_a95 = 3.7
Liantuo_site_slat = 30.819
Liantuo_site_slon = 111.069

SChina.loc[i, 'name']    = 'Liantuo Formation - Jing et al. (2015) site mean (f=1.0)'
SChina.loc[i, 'terrane'] = 'SChina'
SChina.loc[i, 'age']       = 779.52
SChina.loc[i, 'age upper'] = 779.52 + 0.26
SChina.loc[i, 'age lower'] = 779.52 - 0.26
SChina.loc[i, 'plat'] = 12.7
SChina.loc[i, 'plon'] = 157.4
SChina.loc[i, 'a95']  = np.sqrt(4.5*5.8)
SChina.loc[i, 'f'] = 1.0
SChina.loc[i, 'slat'] = Liantuo_site_slat
SChina.loc[i, 'slon'] = Liantuo_site_slon
SChina.loc[i, 'dec']     = Liantuo_site_dec
SChina.loc[i, 'inc']     = Liantuo_site_inc
SChina.loc[i, 'dir_a95'] = Liantuo_site_a95
SChina.loc[i, 'pole ref'] = 'Jing et al. (2015)'
SChina.loc[i, 'age ref']  = 'this study'
SChina.loc[i, 'grade'] = 'B'
SChina.loc[i, 'note']  = '-'
SChina.loc[i, 'plateID'] = 602
i = i + 1

# %% [markdown]
# Grand mean version of the pole:

# %%
Liantuo_GM_site_dec = np.nan
Liantuo_GM_site_inc = np.nan
Liantuo_GM_site_a95 = np.nan
Liantuo_GM_site_slat = 30.819
Liantuo_GM_site_slon = 111.069

SChina.loc[i, 'name']    = 'Liantuo Formation - grand mean (f=1.0)'
SChina.loc[i, 'terrane'] = 'SChina'
SChina.loc[i, 'age']       = 779.52
SChina.loc[i, 'age upper'] = 779.52 + 0.26
SChina.loc[i, 'age lower'] = 779.52 - 0.26
SChina.loc[i, 'plat'] = 13.2
SChina.loc[i, 'plon'] = 155.2
SChina.loc[i, 'a95']  = 5.3
SChina.loc[i, 'f'] = 1.0
SChina.loc[i, 'slat'] = Liantuo_GM_site_slat
SChina.loc[i, 'slon'] = Liantuo_GM_site_slon
SChina.loc[i, 'dec']     = Liantuo_GM_site_dec
SChina.loc[i, 'inc']     = Liantuo_GM_site_inc
SChina.loc[i, 'dir_a95'] = Liantuo_GM_site_a95
SChina.loc[i, 'pole ref'] = 'Evans et al. (2000), Jing et al. (2015)'
SChina.loc[i, 'age ref']  = 'this study'
SChina.loc[i, 'grade'] = 'B'
SChina.loc[i, 'note']  = '-'
SChina.loc[i, 'plateID'] = 602
i = i + 1

# %% [markdown]
# Recalculate pole with a per site inclination correction, and mean calculated after conversion to pole space:

# %%
Jing2015 = pd.read_csv('../Data/Jing2015a.csv')
Jing2015.columns
# Out:
# Index(['site', 'comp.', 'n', 'Dg', 'Ig', 'Ds', 'Is', 'k', 'a95'], dtype='object')

# %%
fignum = 1
plt.figure(num=fignum,figsize=(5,5))
ipmag.plot_net(fignum)
for j in range(len(Jing2015)):
    ipmag.plot_di_mean(Jing2015['Ds'][j], Jing2015['Is'][j], Jing2015['a95'][j], color='C0')
plt.show()

# %%
Jing2015_inc_flipped = []
Jing2015_dec_flipped = []
Jing2015_a95_flipped = []

for j in range(len(Jing2015)):
    if Jing2015['Is'][j] < 0:
        Jing2015_inc_flipped.append(-Jing2015['Is'][j])
        Jing2015_dec_flipped.append(Jing2015['Ds'][j]+180)
    else:
        Jing2015_inc_flipped.append(Jing2015['Is'][j])
        Jing2015_dec_flipped.append(Jing2015['Ds'][j])
    Jing2015_a95_flipped.append(Jing2015['a95'][j])

Jing2015_site_mean_10 = ipmag.fisher_mean(Jing2015_dec_flipped,Jing2015_inc_flipped)

ipmag.print_direction_mean(Jing2015_site_mean_10)

fignum = 1
plt.figure(num=fignum,figsize=(5,5))
ipmag.plot_net(fignum)
for j in range(len(Jing2015)):
    ipmag.plot_di_mean(Jing2015_dec_flipped[j], Jing2015_inc_flipped[j], Jing2015_a95_flipped[j], color='C0')
ipmag.plot_di_mean(Jing2015_site_mean_10['dec'],
                   Jing2015_site_mean_10['inc'],
                   Jing2015_site_mean_10['alpha95'],
                   color='k')
plt.show()
# Out:
# Dec: 102.5  Inc: 62.4
# Number of directions in mean (n): 14
# Angular radius of 95% confidence (a_95): 3.7
# Precision parameter (k) estimate: 115.4

# %%
Liantuo_site_10_vgp_lats = []
Liantuo_site_10_vgp_lons = []
for n in range(len(Jing2015)):
    Liantuo_10_vgp = pmag.dia_vgp(Jing2015_dec_flipped[n], 
                                  Jing2015_inc_flipped[n], 
                                  Jing2015_a95_flipped[n],
                                  Liantuo_site_slat, Liantuo_site_slon)
    Liantuo_site_10_vgp_lons.append(Liantuo_10_vgp[0])
    Liantuo_site_10_vgp_lats.append(Liantuo_10_vgp[1])
Liantuo_site_10_vgp_mean_pole = ipmag.fisher_mean(Liantuo_site_10_vgp_lons,Liantuo_site_10_vgp_lats)
ipmag.print_pole_mean(Liantuo_site_10_vgp_mean_pole)

map_axis = ipmag.make_orthographic_map(figsize=(5,5),central_longitude=100,central_latitude=30)
ipmag.plot_vgp(map_axis,Liantuo_site_10_vgp_lons,Liantuo_site_10_vgp_lats)
ipmag.plot_pole(map_axis,Liantuo_site_10_vgp_mean_pole['dec'],
                Liantuo_site_10_vgp_mean_pole['inc'],
                Liantuo_site_10_vgp_mean_pole['alpha95'],marker='s')
# Out:
# Plon: 157.1  Plat: 13.0
# Number of directions in mean (n): 14
# Angular radius of 95% confidence (A_95): 5.3
# Precision parameter (k) estimate: 58.0

# %%
SChina.loc[i, 'name']    = 'Liantuo Formation - site mean (f=1.0)'
SChina.loc[i, 'terrane'] = 'SChina'
SChina.loc[i, 'age']       = 775 # arbitrarily set age to slightly lower than tuff
SChina.loc[i, 'age upper'] = 779.52 + 0.26
SChina.loc[i, 'age lower'] = 779.52 - 10
SChina.loc[i, 'plat'] = Liantuo_site_10_vgp_mean_pole['inc']
SChina.loc[i, 'plon'] = Liantuo_site_10_vgp_mean_pole['dec']
SChina.loc[i, 'a95']  = Liantuo_site_10_vgp_mean_pole['alpha95']
SChina.loc[i, 'f'] = 1.0
SChina.loc[i, 'slat'] = Liantuo_site_slat
SChina.loc[i, 'slon'] = Liantuo_site_slon
SChina.loc[i, 'dec']     = Jing2015_site_mean_10['dec']
SChina.loc[i, 'inc']     = Jing2015_site_mean_10['inc']
SChina.loc[i, 'dir_a95'] = Jing2015_site_mean_10['alpha95']
SChina.loc[i, 'pole ref'] = 'Jing et al. (2015)'
SChina.loc[i, 'age ref']  = 'this study'
SChina.loc[i, 'grade'] = 'B'
SChina.loc[i, 'note']  = '-'
SChina.loc[i, 'plateID'] = 602
i = i + 1

# %%
Jing2015_inc_flipped_ic = ipmag.unsquish(Jing2015_inc_flipped, 0.6)

Jing2015_site_mean_06 = ipmag.fisher_mean(Jing2015_dec_flipped,Jing2015_inc_flipped_ic)

ipmag.print_direction_mean(Jing2015_site_mean_06)

fignum = 1
plt.figure(num=fignum,figsize=(5,5))
ipmag.plot_net(fignum)
for j in range(len(Jing2015)):
    ipmag.plot_di_mean(Jing2015_dec_flipped[j], Jing2015_inc_flipped_ic[j], Jing2015_a95_flipped[j], color='C0')
ipmag.plot_di_mean(Jing2015_site_mean_06['dec'],
                   Jing2015_site_mean_06['inc'],
                   Jing2015_site_mean_06['alpha95'],
                   color='k')
plt.show()
# Out:
# Dec: 102.6  Inc: 72.5
# Number of directions in mean (n): 14
# Angular radius of 95% confidence (a_95): 2.5
# Precision parameter (k) estimate: 251.9

# %%
Liantuo_site_06_vgp_lats = []
Liantuo_site_06_vgp_lons = []
for n in range(len(Jing2015)):
    Liantuo_06_vgp = pmag.dia_vgp(Jing2015_dec_flipped[n], 
                                 Jing2015_inc_flipped_ic[n], 
                                 Jing2015_a95_flipped[n],
                                 Liantuo_site_slat, Liantuo_site_slon)
    Liantuo_site_06_vgp_lons.append(Liantuo_06_vgp[0])
    Liantuo_site_06_vgp_lats.append(Liantuo_06_vgp[1])
Liantuo_site_06_vgp_mean_pole = ipmag.fisher_mean(Liantuo_site_06_vgp_lons,Liantuo_site_06_vgp_lats)
ipmag.print_pole_mean(Liantuo_site_06_vgp_mean_pole)

map_axis = ipmag.make_orthographic_map(figsize=(5,5),central_longitude=100,central_latitude=30)
ipmag.plot_vgp(map_axis,Liantuo_site_06_vgp_lons,Liantuo_site_06_vgp_lats)
ipmag.plot_pole(map_axis,Liantuo_site_06_vgp_mean_pole['dec'],
                Liantuo_site_06_vgp_mean_pole['inc'],
                Liantuo_site_06_vgp_mean_pole['alpha95'],marker='s')
# Out:
# Plon: 144.4  Plat: 19.6
# Number of directions in mean (n): 14
# Angular radius of 95% confidence (A_95): 4.2
# Precision parameter (k) estimate: 91.9

# %%
SChina.loc[i, 'name']    = 'Liantuo Formation - site mean (f=0.6)'
SChina.loc[i, 'terrane'] = 'SChina'
SChina.loc[i, 'age']       = 775 # arbitrarily set age to slightly lower than tuff
SChina.loc[i, 'age upper'] = 779.52 + 0.26
SChina.loc[i, 'age lower'] = 779.52 - 10
SChina.loc[i, 'plat'] = Liantuo_site_06_vgp_mean_pole['inc']
SChina.loc[i, 'plon'] = Liantuo_site_06_vgp_mean_pole['dec']
SChina.loc[i, 'a95']  = Liantuo_site_06_vgp_mean_pole['alpha95']
SChina.loc[i, 'f'] = 1.0
SChina.loc[i, 'slat'] = Liantuo_site_slat
SChina.loc[i, 'slon'] = Liantuo_site_slon
SChina.loc[i, 'dec']     = Jing2015_site_mean_06['dec']
SChina.loc[i, 'inc']     = Jing2015_site_mean_06['inc']
SChina.loc[i, 'dir_a95'] = Jing2015_site_mean_06['alpha95']
SChina.loc[i, 'pole ref'] = 'Jing et al. (2015)'
SChina.loc[i, 'age ref']  = 'this study'
SChina.loc[i, 'grade'] = 'B'
SChina.loc[i, 'note']  = '-'
SChina.loc[i, 'plateID'] = 602
i = i + 1

# %% [markdown]
# Jing et al. (2021) pole. Recalculate pole with a per site inclination correction, and mean calculated after conversion to pole space:

# %%
Jing2021 = pd.read_csv('../Data/Jing2021a.csv')
Jing2021.columns
# Out:
# Index(['site', 'n', 'Dg', 'Ig', 'Ds', 'Is', 'k', 'a95'], dtype='object')

# %%
fignum = 1
plt.figure(num=fignum,figsize=(5,5))
ipmag.plot_net(fignum)
for j in range(len(Jing2021)):
    ipmag.plot_di_mean(Jing2021['Ds'][j], Jing2021['Is'][j], Jing2021['a95'][j], color='C0')
plt.show()

# %%
Jing2021_inc_flipped = []
Jing2021_dec_flipped = []
Jing2021_a95_flipped = []

for j in range(len(Jing2021)):
    if Jing2021['Is'][j] < 0:
        Jing2021_inc_flipped.append(-Jing2021['Is'][j])
        Jing2021_dec_flipped.append(Jing2021['Ds'][j]+180)
    else:
        Jing2021_inc_flipped.append(Jing2021['Is'][j])
        Jing2021_dec_flipped.append(Jing2021['Ds'][j])
    Jing2021_a95_flipped.append(Jing2021['a95'][j])

Jing2021_site_mean_10 = ipmag.fisher_mean(Jing2021_dec_flipped,Jing2021_inc_flipped)

ipmag.print_direction_mean(Jing2021_site_mean_10)

fignum = 1
plt.figure(num=fignum,figsize=(5,5))
ipmag.plot_net(fignum)
for j in range(len(Jing2021)):
    ipmag.plot_di_mean(Jing2021_dec_flipped[j], Jing2021_inc_flipped[j], Jing2021_a95_flipped[j], color='C0')
ipmag.plot_di_mean(Jing2021_site_mean_10['dec'],
                   Jing2021_site_mean_10['inc'],
                   Jing2021_site_mean_10['alpha95'],
                   color='k')
plt.show()
# Out:
# Dec: 98.6  Inc: 70.3
# Number of directions in mean (n): 9
# Angular radius of 95% confidence (a_95): 5.8
# Precision parameter (k) estimate: 79.3

# %%
Liantuo_site_10_vgp_lats = []
Liantuo_site_10_vgp_lons = []
for n in range(len(Jing2021)):
    Liantuo_10_vgp = pmag.dia_vgp(Jing2021_dec_flipped[n], 
                                  Jing2021_inc_flipped[n], 
                                  Jing2021_a95_flipped[n],
                                  Liantuo_site_slat, Liantuo_site_slon)
    Liantuo_site_10_vgp_lons.append(Liantuo_10_vgp[0])
    Liantuo_site_10_vgp_lats.append(Liantuo_10_vgp[1])
Liantuo_site_10_vgp_mean_pole = ipmag.fisher_mean(Liantuo_site_10_vgp_lons,Liantuo_site_10_vgp_lats)
ipmag.print_pole_mean(Liantuo_site_10_vgp_mean_pole)

map_axis = ipmag.make_orthographic_map(figsize=(5,5),central_longitude=100,central_latitude=30)
ipmag.plot_vgp(map_axis,Liantuo_site_10_vgp_lons,Liantuo_site_10_vgp_lats)
ipmag.plot_pole(map_axis,Liantuo_site_10_vgp_mean_pole['dec'],
                Liantuo_site_10_vgp_mean_pole['inc'],
                Liantuo_site_10_vgp_mean_pole['alpha95'],marker='s')
# Out:
# Plon: 148.0  Plat: 20.6
# Number of directions in mean (n): 9
# Angular radius of 95% confidence (A_95): 8.8
# Precision parameter (k) estimate: 34.9

# %%
SChina.loc[i, 'name']    = 'Liantuo Formation - Jing et al. (2021) site mean (f=1.0)'
SChina.loc[i, 'terrane'] = 'SChina'
SChina.loc[i, 'age']       = 779.52
SChina.loc[i, 'age upper'] = 779.52 + 0.26
SChina.loc[i, 'age lower'] = 779.52 - 0.26
SChina.loc[i, 'plat'] = Liantuo_site_10_vgp_mean_pole['inc']
SChina.loc[i, 'plon'] = Liantuo_site_10_vgp_mean_pole['dec']
SChina.loc[i, 'a95']  = Liantuo_site_10_vgp_mean_pole['alpha95']
SChina.loc[i, 'f'] = 1.0
SChina.loc[i, 'slat'] = 30.801
SChina.loc[i, 'slon'] = 110.920
SChina.loc[i, 'dec']     = Jing2021_site_mean_10['dec']
SChina.loc[i, 'inc']     = Jing2021_site_mean_10['inc']
SChina.loc[i, 'dir_a95'] = Jing2021_site_mean_10['alpha95']
SChina.loc[i, 'pole ref'] = 'Jing et al. (2021)'
SChina.loc[i, 'age ref']  = 'this study'
SChina.loc[i, 'grade'] = 'B'
SChina.loc[i, 'note']  = '-'
SChina.loc[i, 'plateID'] = 602
i = i + 1

# %%
Jing2021_inc_flipped_ic = ipmag.unsquish(Jing2021_inc_flipped, 0.6)

Jing2021_site_mean_06 = ipmag.fisher_mean(Jing2021_dec_flipped,Jing2021_inc_flipped_ic)

ipmag.print_direction_mean(Jing2021_site_mean_06)

fignum = 1
plt.figure(num=fignum,figsize=(5,5))
ipmag.plot_net(fignum)
for j in range(len(Jing2021)):
    ipmag.plot_di_mean(Jing2021_dec_flipped[j], Jing2021_inc_flipped_ic[j], Jing2021_a95_flipped[j], color='C0')
ipmag.plot_di_mean(Jing2021_site_mean_06['dec'],
                   Jing2021_site_mean_06['inc'],
                   Jing2021_site_mean_06['alpha95'],
                   color='k')
plt.show()
# Out:
# Dec: 98.8  Inc: 77.7
# Number of directions in mean (n): 9
# Angular radius of 95% confidence (a_95): 3.8
# Precision parameter (k) estimate: 185.7

# %%
Liantuo_site_06_vgp_lats = []
Liantuo_site_06_vgp_lons = []
for n in range(len(Jing2021)):
    Liantuo_06_vgp = pmag.dia_vgp(Jing2021_dec_flipped[n], 
                                 Jing2021_inc_flipped_ic[n], 
                                 Jing2021_a95_flipped[n],
                                 Liantuo_site_slat, Liantuo_site_slon)
    Liantuo_site_06_vgp_lons.append(Liantuo_06_vgp[0])
    Liantuo_site_06_vgp_lats.append(Liantuo_06_vgp[1])
Liantuo_site_06_vgp_mean_pole = ipmag.fisher_mean(Liantuo_site_06_vgp_lons,Liantuo_site_06_vgp_lats)
ipmag.print_pole_mean(Liantuo_site_06_vgp_mean_pole)

map_axis = ipmag.make_orthographic_map(figsize=(5,5),central_longitude=100,central_latitude=30)
ipmag.plot_vgp(map_axis,Liantuo_site_06_vgp_lons,Liantuo_site_06_vgp_lats)
ipmag.plot_pole(map_axis,Liantuo_site_06_vgp_mean_pole['dec'],
                Liantuo_site_06_vgp_mean_pole['inc'],
                Liantuo_site_06_vgp_mean_pole['alpha95'],marker='s')
# Out:
# Plon: 136.4  Plat: 24.9
# Number of directions in mean (n): 9
# Angular radius of 95% confidence (A_95): 6.6
# Precision parameter (k) estimate: 61.1

# %%
SChina.loc[i, 'name']    = 'Liantuo Formation - Jing et al. (2021) site mean (f=0.6)'
SChina.loc[i, 'terrane'] = 'SChina'
SChina.loc[i, 'age']       = 779.52
SChina.loc[i, 'age upper'] = 779.52 + 0.26
SChina.loc[i, 'age lower'] = 779.52 - 0.26
SChina.loc[i, 'plat'] = Liantuo_site_06_vgp_mean_pole['inc']
SChina.loc[i, 'plon'] = Liantuo_site_06_vgp_mean_pole['dec']
SChina.loc[i, 'a95']  = Liantuo_site_06_vgp_mean_pole['alpha95']
SChina.loc[i, 'f'] = 1.0
SChina.loc[i, 'slat'] = 30.801
SChina.loc[i, 'slon'] = 110.920
SChina.loc[i, 'dec']     = Jing2021_site_mean_06['dec']
SChina.loc[i, 'inc']     = Jing2021_site_mean_06['inc']
SChina.loc[i, 'dir_a95'] = Jing2021_site_mean_06['alpha95']
SChina.loc[i, 'pole ref'] = 'Jing et al. (2021)'
SChina.loc[i, 'age ref']  = 'this study'
SChina.loc[i, 'grade'] = 'B'
SChina.loc[i, 'note']  = '-'
SChina.loc[i, 'plateID'] = 602
i = i + 1

# %% [markdown]
# Test for common mean between the Jing et al. (2021) and Jing et al. (2015) Liantuo poles:

# %%
Jing2021_di = ipmag.make_di_block(Jing2021_dec_flipped, Jing2021_inc_flipped_ic)
Jing2015_di = ipmag.make_di_block(Jing2015_dec_flipped, Jing2015_inc_flipped_ic)

# %%
ipmag.common_mean_bootstrap(Jing2015_di, Jing2021_di)

# %%
ipmag.common_mean_watson(Jing2015_di, Jing2021_di)
# Out:
# Results of Watson V test:
#
# Watson's V:           9.7
# Critical value of V:  6.8
# "Fail": Since V is greater than Vcrit, the two means can
# be distinguished at the 95% confidence level.
#
# M&M1990 classification:
#
# Angle between data set means: 5.3
# Critical angle for M&M1990:   4.5
# (0, 5.322957029118435, 4.456393766758785)

# %% [markdown]
# ### APWP

# %%
SChina.sort_values('age', ascending=False, inplace=True)
SChina = SChina[compilation_cols]
SChina.reset_index(inplace=True, drop=True)
SChina
# Out:
#                                                  name terrane     age  \
# 0                               Yanbian Dikes Group A  SChina     824
# 1                   Xiaofeng Dikes - Li et al. (2004)  SChina  821.37
# 2                 Xiaofeng Dikes - Jing et al. (2019)  SChina  821.37
# 3                     Banxi Group - site mean (f=1.0)  SChina     813
# 4                     Banxi Group - site mean (f=0.6)  SChina     813
# 5                 Banxi Group - specimen mean (f=1.0)  SChina     813
# 6                 Banxi Group - specimen mean (f=0.6)  SChina     813
# 7               Banxi Group - lower site mean (f=0.6)  SChina     813
# 8               Banxi Group - upper site mean (f=0.6)  SChina     813
# 9                Madiyi Formation - site mean (f=0.6)  SChina   804.9
# 10               Madiyi Formation - site mean (f=1.0)  SChina   804.9
# 11           Madiyi Formation - specimen mean (f=0.6)  SChina   804.9
# ...

# %%
SChina.to_csv('../Output/SChina-poles.csv',index=False)
SChina_vpgFeatureCollection = create_vgp_FeatureCollection(SChina)
create_vgp_gpml(SChina_vpgFeatureCollection, '../Output/SChina-poles.gpml')
# Out:
# Palaeomagnetic pole data successfully exported in GPML format.

# %% [markdown]
# Calculate paleolatitude:

# %%
# calculate age uncertainty as relative to the nominal age
SChina['age upper diff'] = SChina['age upper'] - SChina['age']
SChina['age lower diff'] = SChina['age'] - SChina['age lower']

# calculate implied paleolatitude of centroid point
SChina_centroid_lat = 27.91
SChina_centroid_lon = 108.82

SChina['centroid_lat'] = pd.Series()

for i in range(len(SChina)):
    lat = ipmag.lat_from_pole(SChina_centroid_lon, SChina_centroid_lat,
                              SChina['plon'][i], SChina['plat'][i])
    SChina['centroid_lat'][i] = lat

# %% [markdown]
# All the poles, colored by age:

# %%
def SChina_APWP_plot(df, vmin=None, vmax=None, title=None, savefig=None):
    
    lat_grid = [-80,-60,-30,0,30,60,80]
    lon_grid = np.arange(-180,180+60,60)

    ax = ipmag.make_orthographic_map(add_land=False, central_longitude=115, central_latitude=45,
                                     figsize=(7,7), grid_lines=False)
    
    ax.add_feature(cartopy.feature.LAND,
                   facecolor='#eeeeee', edgecolor='none')
    
    if vmin==None:
        vmin = np.min(df['age'])
    if vmax==None:
        vmax = np.max(df['age'])

    color_mapping = plt.cm.ScalarMappable(cmap='viridis',
                                          norm=plt.Normalize(vmin=vmin,
                                                             vmax=vmax))
    colors = color_mapping.to_rgba(df['age'].tolist()).tolist()

    for i in range(len(df)):
        rotated_pole_plot(ax, df['plon'][i], df['plat'][i], df['a95'][i], [[0,0,0]],
                          'o', 20, 'C7', colors[i], 0.5)

    ax.gridlines(xlocs=lon_grid, ylocs=lat_grid, linewidth=0.5,
                 color='C7', linestyle='dotted', zorder=-1)
    
    if title!=None:
        ax.set_title(title)

    color_mapping._A = []
    cbar = plt.colorbar(color_mapping, orientation='horizontal', shrink=0.8,
                        pad=0.05, label='age [Ma]')
    cbar.ax.invert_xaxis()

    if savefig!=None:
        plt.savefig(savefig, bbox_inches='tight')
        
    plt.show()

# %%
SChina_APWP_plot(SChina, title='all poles - f = 1.0')

# %% [markdown]
# Directions at the Banxi Group site:

# %%
# approximately the mean coordinates of all sites on the E side of the mountains
slat = 27.91
slon = 108.82

# convert pole position to a direction at our Banxi sites
decs = np.array([])
incs = np.array([])
for i in range(len(SChina.index)):
    dec, inc = pmag.vgp_di(SChina['plat'][i], SChina['plon'][i], slat, slon)
    decs = np.append(decs, dec)
    incs = np.append(incs, inc)

# add to dataframe
SChina['Banxi_dec'] = np.round(decs,1)
SChina['Banxi_inc'] = np.round(incs,1)

color_mapping = plt.cm.ScalarMappable(cmap='viridis',
                                      norm=plt.Normalize(vmin=np.min(SChina['age']),
                                                         vmax=np.max(SChina['age'])))
colors = color_mapping.to_rgba(SChina['age'].tolist()).tolist()

fignum = 1
plt.figure(num=fignum,figsize=(5,5))
ipmag.plot_net(fignum)

for i in range(len(decs)):
    ipmag.plot_di(dec=decs[i],inc=incs[i],color=colors[i],markersize=40)
    
color_mapping._A = []
cbar = plt.colorbar(color_mapping, orientation='horizontal', shrink=0.8,
                    pad=0.05, label='age [Ma]')
cbar.ax.invert_xaxis()

plt.show()

# %% [markdown]
# Pull out some subsets of the data:

# %%
select_poles = ['Yanbian Dikes Group A',
                'Xiaofeng Dikes - Li et al. (2004)',
                'Banxi Group - specimen mean (f=1.0)',
                'Madiyi Formation - specimen mean (f=1.0)']

SChina_spec_10 = SChina[SChina['name'].isin(select_poles)]
SChina_spec_10.reset_index(drop=True, inplace=True)

# %%
select_poles = ['Xiaofeng Dikes - Jing et al. (2019)',
                'Banxi Group - site mean (f=1.0)',
                'Madiyi Formation - site mean (f=1.0)',
                'Chengjiang Formation - site mean (f=1.0)',
                'Liantuo Formation - Jing et al. (2021) site mean (f=1.0)',
                'Liantuo Formation - site mean (f=1.0)']

SChina_site_10 = SChina[SChina['name'].isin(select_poles)]
SChina_site_10.reset_index(drop=True, inplace=True)

# %%
select_poles = ['Xiaofeng Dikes - Jing et al. (2019)',
                'Banxi Group - site mean (f=0.6)',
                'Madiyi Formation - site mean (f=0.6)',
                'Chengjiang Formation - site mean (f=0.6)',
                'Liantuo Formation - Jing et al. (2021) site mean (f=0.6)',
                'Liantuo Formation - site mean (f=0.6)']

SChina_site_06 = SChina[SChina['name'].isin(select_poles)]
SChina_site_06.reset_index(drop=True, inplace=True)

# %%
vmin = 775
vmax = 824

# %% [markdown]
# **NOTE: Liantuo and Chengjiang Formation poles are not reported at the specimen level, so data shown for that formation are site means in all of these figures.**

# %%
lat_grid = [-80,-60,-30,0,30,60,80]
lon_grid = np.arange(-180,180+60,60)

ax = ipmag.make_orthographic_map(add_land=False, central_longitude=115, central_latitude=45,
                                 figsize=(7,7), grid_lines=False)

ax.add_feature(cartopy.feature.LAND,
               facecolor='#eeeeee', edgecolor='none')

color_mapping = plt.cm.ScalarMappable(cmap='viridis',
                                      norm=plt.Normalize(vmin=vmin,
                                                         vmax=vmax))
    
# poles that we aren't discarding
df = SChina_site_10
colors = color_mapping.to_rgba(df['age'].tolist()).tolist()
for i in range(len(df)):
    rotated_pole_plot(ax, df['plon'][i], df['plat'][i], df['a95'][i], [[0,0,0]],
                      'o', 20, 'C7', colors[i], 0.5, a95_edge_alpha=1.0)
    
# poles that we are discarding
df = SChina_spec_10
colors = color_mapping.to_rgba(df['age'].tolist()).tolist()
for i in range(len(df)):
    rotated_pole_plot(ax, df['plon'][i], df['plat'][i], df['a95'][i], [[0,0,0]],
                      'o', 20, 'C7', colors[i], 0.2, a95_edge_alpha=0.4)

ax.gridlines(xlocs=lon_grid, ylocs=lat_grid, linewidth=0.5,
             color='C7', linestyle='dotted', zorder=-1)

ax.set_title('all - f = 1.0')

color_mapping._A = []
cbar = plt.colorbar(color_mapping, orientation='horizontal', shrink=0.8,
                    pad=0.05, label='age [Ma]')
cbar.ax.invert_xaxis()

plt.show()

# %%
#SChina_APWP_plot(SChina_spec_10, vmin=vmin, vmax=vmax,
#                 title='bad - f = 1.0', savefig='../Output/SChina_APWP_f_10_all.pdf')
SChina_APWP_plot(SChina_spec_10, vmin=vmin, vmax=vmax,
                 title='bad - f = 1.0')

# %%
#SChina_APWP_plot(SChina_site_10, vmin=vmin, vmax=vmax,
#                 title='good - f = 1.0', savefig='../Output/SChina_APWP_f_10.pdf')
SChina_APWP_plot(SChina_site_10, vmin=vmin, vmax=vmax,
                 title='good - f = 1.0')

# %%
#SChina_APWP_plot(SChina_site_06, vmin=vmin, vmax=vmax,
#                 title='good - f = 0.6', savefig='../Output/SChina_APWP_f_06.pdf')
SChina_APWP_plot(SChina_site_06, vmin=vmin, vmax=vmax,
                title='good - f = 0.6')

# %%
SChina_site_06.to_csv('../Output/SChina-clean-poles.csv',index=False)
SChina_clean_vpgFeatureCollection = create_vgp_FeatureCollection(SChina_site_06)
create_vgp_gpml(SChina_clean_vpgFeatureCollection, '../Output/SChina-clean-poles.gpml')
# Out:
# Palaeomagnetic pole data successfully exported in GPML format.

# %% [markdown]
# APWP to minimize movement of SChina:

# %%
# rotate SChina to India
SChina_India_Euler = [5.4029, 76.6389, 62.2534]

# India rotations
India_Eulers = [[-30.8534, -56.4493, 68.595],
                [-27.8028, -54.65, 64.3143],
                [-27.3533, -60.0955, 71.0936],
                [-31.0633, -64.6471, 81.9334],
                [-60.193, -44.2136, 61.8704],
                [-68.2634,-26.6226,60.2405]]

# %%
ax = ipmag.make_orthographic_map(add_land=False, central_longitude=135, central_latitude=60,
                                 figsize=(8,8), grid_lines=False)

lat_grid = [-80,-60,-30,0,30,60,80]
lon_grid = np.arange(-180,180+60,60)

color_mapping = plt.cm.ScalarMappable(cmap='viridis',norm=plt.Normalize(vmin=vmin,vmax=vmax))
pole_colors = color_mapping.to_rgba(SChina_site_06['age'].tolist()).tolist()

for i in range(len(SChina_site_06)):
    rotated_pole_plot(ax, SChina_site_06['plon'][i], SChina_site_06['plat'][i], SChina_site_06['a95'][i],
                      [SChina_India_Euler,India_Eulers[i]],
                      'o', 20, 'C7', pole_colors[i], 0.25)

for i in range(len(India_Eulers)):
    craton_plot(ax, [6024], [SChina_India_Euler,India_Eulers[i]], 'k', pole_colors[i], 1.0, 0.5)
    craton_plot(ax, [6023], [SChina_India_Euler,India_Eulers[i]], 'k', pole_colors[i], 1.0, 0.5)
    craton_plot(ax, [602], [SChina_India_Euler,India_Eulers[i]], 'k', pole_colors[i], 1.0, 0.5)
    
ax.gridlines(xlocs=lon_grid, ylocs=lat_grid, linewidth=0.5,
             color='C7', linestyle='dotted', zorder=-1)
    
color_mapping._A = []
cbar = plt.colorbar(color_mapping, orientation='horizontal', shrink=0.8,
                    pad=0.05, label='age [Ma]')
cbar.ax.invert_xaxis()

#plt.savefig('../Output/SChina_reconstructed.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# APWP using the means:

# %%
# rotate SChina to India
SChina_India_Euler = [5.4029, 76.6389, 62.2534]

# India rotations
India_Eulers = [[-26.9891, -51.4312, 81.2282],
                [19.0345, -34.686, 52.5914],
                [-19.1912, -52.284, 72.4749],
                [-20.5987, -53.3701, 81.386],
                [-59.8448, -30.7082, 49.5606],
                [-66.0709, -10.8066, 48.7263]]

# %%
ax = ipmag.make_orthographic_map(add_land=False, central_longitude=135, central_latitude=60,
                                 figsize=(8,8), grid_lines=False)

lat_grid = [-80,-60,-30,0,30,60,80]
lon_grid = np.arange(-180,180+60,60)

color_mapping = plt.cm.ScalarMappable(cmap='viridis',norm=plt.Normalize(vmin=vmin,vmax=vmax))
pole_colors = color_mapping.to_rgba(SChina_site_06['age'].tolist()).tolist()

for i in range(len(SChina_site_06)):
    rotated_pole_plot(ax, SChina_site_06['plon'][i], SChina_site_06['plat'][i], SChina_site_06['a95'][i],
                      [SChina_India_Euler,India_Eulers[i]],
                      'o', 20, 'C7', pole_colors[i], 0.25)

for i in range(len(India_Eulers)):
    craton_plot(ax, [6024], [SChina_India_Euler,India_Eulers[i]], 'k', pole_colors[i], 1.0, 0.5)
    craton_plot(ax, [6023], [SChina_India_Euler,India_Eulers[i]], 'k', pole_colors[i], 1.0, 0.5)
    craton_plot(ax, [602], [SChina_India_Euler,India_Eulers[i]], 'k', pole_colors[i], 1.0, 0.5)
    
ax.gridlines(xlocs=lon_grid, ylocs=lat_grid, linewidth=0.5,
             color='C7', linestyle='dotted', zorder=-1)
    
color_mapping._A = []
cbar = plt.colorbar(color_mapping, orientation='horizontal', shrink=0.8,
                    pad=0.05, label='age [Ma]')
cbar.ax.invert_xaxis()

#plt.savefig('../Output/SChina_reconstructed_mean.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# APWP to maximize distance between Banxi and Madiyi poles:

# %%
# rotate SChina to India
SChina_India_Euler = [5.4029, 76.6389, 62.2534]

# India rotations
India_Eulers = [[-30.8534, -56.4493, 68.595],
                [17.2564, -37.9254, 43.9915],
                [6.0803, -32.6917, 74.6796],
                [4.1842, -31.2827, 83.2093],
                [-14.1187, -3.4719, 19.3636],
                [-20.0069, 16.2975, 17.2427]]

# %%
ax = ipmag.make_orthographic_map(add_land=False, central_longitude=135, central_latitude=60,
                                 figsize=(8,8), grid_lines=False)

lat_grid = [-80,-60,-30,0,30,60,80]
lon_grid = np.arange(-180,180+60,60)

color_mapping = plt.cm.ScalarMappable(cmap='viridis',norm=plt.Normalize(vmin=vmin,vmax=vmax))
pole_colors = color_mapping.to_rgba(SChina_site_06['age'].tolist()).tolist()

for i in range(len(SChina_site_06)):
    rotated_pole_plot(ax, SChina_site_06['plon'][i], SChina_site_06['plat'][i], SChina_site_06['a95'][i],
                      [SChina_India_Euler,India_Eulers[i]],
                      'o', 20, 'C7', pole_colors[i], 0.25)

for i in range(len(India_Eulers)):
    craton_plot(ax, [6024], [SChina_India_Euler,India_Eulers[i]], 'k', pole_colors[i], 1.0, 0.5)
    craton_plot(ax, [6023], [SChina_India_Euler,India_Eulers[i]], 'k', pole_colors[i], 1.0, 0.5)
    craton_plot(ax, [602], [SChina_India_Euler,India_Eulers[i]], 'k', pole_colors[i], 1.0, 0.5)
    
ax.gridlines(xlocs=lon_grid, ylocs=lat_grid, linewidth=0.5,
             color='C7', linestyle='dotted', zorder=-1)
    
color_mapping._A = []
cbar = plt.colorbar(color_mapping, orientation='horizontal', shrink=0.8,
                    pad=0.05, label='age [Ma]')
cbar.ax.invert_xaxis()

#plt.savefig('../Output/SChina_reconstructed_TPW.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Drift Rate

# %%
def great_circle_distance(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance between two points using the Haversine formula.
    
    Parameters
    ----------
    lon1 : float
        Longitude of point 1.
    lat1 : float
        Latitude of point 1.
    lon2 : float
        Longitude of point 2.
    lat2 : float
        Latitude of point 2.
        
    Returns
    -------
    dist : float
        Great circle distance in meters.
    """
    # mean Earth radius, in meters
    R = 6371e3
    
    # convert to radians
    lon1_rad = np.deg2rad(lon1)
    lat1_rad = np.deg2rad(lat1)
    lon2_rad = np.deg2rad(lon2)
    lat2_rad = np.deg2rad(lat2)
    
    # differences
    delta_lon = np.deg2rad(lon2 - lon1)
    delta_lat = np.deg2rad(lat2 - lat1)
    
    # haversine formula
    a = (np.sin(delta_lat/2)**2) + np.cos(lat1_rad)*np.cos(lat2_rad)*(np.sin(delta_lon/2)**2)
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1-a))
    dist = R * c
    
    return dist

# %%
def plate_rate_mc(pole1_plon, pole1_plat, pole1_kappa, pole1_N, pole1_age, pole1_MCages,
                  pole2_plon, pole2_plat, pole2_kappa, pole2_N, pole2_age, pole2_MCages,
                  ref_loc_lon, ref_loc_lat, samplesize=10000, random_seed=None):
    """
    Determine the latitudinal motion implied by a pair of poles and utilize
    the Monte Carlo sampling method of Swanson-Hysell (2014) to determine the
    associated uncertainty.
    
    Modified from PmagPy.

    Parameters:
    ------------
    plon : longitude of pole
    plat : latitude of pole
    kappa : Fisher precision parameter for VPGs in pole
    N : number of VGPs in pole
    age : age assigned to pole in Ma
    MCages : MC sampled age distribution - must have same length as samplesize
    ref_loc_lon : longitude of reference location
    ref_loc_lat : latitude of reference location
    samplesize : number of draws from pole and age distributions (default set to 10000)
    random_seed : set random seed for reproducible number generation (default is None)

    Returns
    --------
    rate : rate of latitudinal motion in cm/yr along with estimated 2.5 and 97.5
    percentile rate estimates
    """
    angle = pmag.angle([pole1_plon,pole1_plat],[pole2_plon,pole2_plat])
    print('angular difference between the means = {:.2f}'.format(angle[0]))
    
    ref_loc = [ref_loc_lon, ref_loc_lat]
    pole1 = (pole1_plon, pole1_plat)
    pole1_paleolat = 90 - pmag.angle(pole1, ref_loc)
    pole2 = (pole2_plon, pole2_plat)
    pole2_paleolat = 90 - pmag.angle(pole2, ref_loc)
    print('paleolatitude for ref_loc resulting from the mean of pole1 = {:.2f}'.format(pole1_paleolat[0]))
    print('paleolatitude for ref_loc resulting from the mean of pole2 = {:.2f}'.format(pole2_paleolat[0]))
    rate = (great_circle_distance(0,pole1_paleolat,0,pole2_paleolat)*1e2) / ((pole1_age-pole2_age)*1e6)
    print('rate of paleolatitudinal change implied by the means = {:.2f} cm/yr'.format(rate[0]))
    plate_rate = (great_circle_distance(pole1_plon,
                                        pole1_plat,
                                        pole2_plon,
                                        pole2_plat)*1e2) / ((pole1_age-pole2_age)*1e6)
    print('plate velocity implied by the means = {:.2f} cm/yr'.format(plate_rate))

    if random_seed != None:
        np.random.seed(random_seed)

    pole1_MCpoles = []
    pole1_MCpole_lat = []
    pole1_MCpole_long = []
    pole1_MCpaleolat = []
    for n in range(samplesize):
        vgp_samples = []
        for vgp in range(pole1_N):
            # pmag.dev returns a direction from a fisher distribution with
            # specified kappa
            direction_atN = pmag.fshdev(pole1_kappa)
            # this direction is centered at latitude of 90 degrees and needs to be rotated
            # to be centered on the mean pole position
            tilt_direction = pole1_plon
            tilt_amount = 90 - pole1_plat
            direction = pmag.dotilt(direction_atN[0], direction_atN[1], tilt_direction, tilt_amount)
            vgp_samples.append([direction[0], direction[1], 1.])
        mean = pmag.fisher_mean(vgp_samples)
        mean_pole_position = (mean['dec'], mean['inc'])
        pole1_MCpoles.append([mean['dec'], mean['inc'], 1.])
        pole1_MCpole_lat.append(mean['inc'])
        pole1_MCpole_long.append(mean['dec'])
        paleolat = 90 - pmag.angle(mean_pole_position, ref_loc)
        pole1_MCpaleolat.append(paleolat[0])

    pole2_MCpoles = []
    pole2_MCpole_lat = []
    pole2_MCpole_long = []
    pole2_MCpaleolat = []
    for n in range(samplesize):
        vgp_samples = []
        for vgp in range(pole2_N):
            # pmag.dev returns a direction from a fisher distribution with
            # specified kappa
            direction_atN = pmag.fshdev(pole2_kappa)
            # this direction is centered at latitude of 90 degrees and needs to be rotated
            # to be centered on the mean pole position
            tilt_direction = pole2_plon
            tilt_amount = 90 - pole2_plat
            direction = pmag.dotilt(
                direction_atN[0], direction_atN[1], tilt_direction, tilt_amount)
            vgp_samples.append([direction[0], direction[1], 1.])
        mean = pmag.fisher_mean(vgp_samples)
        mean_pole_position = (mean['dec'], mean['inc'])
        pole2_MCpoles.append([mean['dec'], mean['inc'], 1.])
        pole2_MCpole_lat.append(mean['inc'])
        pole2_MCpole_long.append(mean['dec'])
        paleolat = 90 - pmag.angle(mean_pole_position, ref_loc)
        pole2_MCpaleolat.append(paleolat[0])

    # calculating the change in paleolatitude and angle between the Monte Carlo pairs
    MC_angular_degrees = []
    MC_angular_degrees_per_myr = []
    MC_angular_cm_per_yr = []
    MC_paleolat_degrees = []
    MC_paleolat_degrees_per_myr = []
    MC_paleolat_cm_per_yr = []

    for n in range(samplesize):
        angular_degrees = pmag.angle([pole1_MCpole_long[n],pole1_MCpole_lat[n]],
                                     [pole2_MCpole_long[n],pole2_MCpole_lat[n]])
        MC_angular_degrees.append(angular_degrees[0])
        
        paleolat_degrees = pole1_MCpaleolat[n] - pole2_MCpaleolat[n]
        MC_paleolat_degrees.append(paleolat_degrees)
        
        Delta_Myr = pole1_MCages[n] - pole2_MCages[n]
        
        angular_degrees_per_myr = angular_degrees[0] / Delta_Myr
        MC_angular_degrees_per_myr.append(angular_degrees_per_myr)
        
        angular_cm_per_yr = (great_circle_distance(pole1_MCpole_long[n],
                                                   pole1_MCpole_lat[n],
                                                   pole2_MCpole_long[n],
                                                   pole2_MCpole_lat[n])*1e2) / (Delta_Myr*1e6)
        MC_angular_cm_per_yr.append(angular_cm_per_yr)
        
        paleolat_degrees_per_myr = paleolat_degrees / Delta_Myr
        MC_paleolat_degrees_per_myr.append(paleolat_degrees_per_myr)
        
        paleolat_cm_per_yr = (great_circle_distance(0,paleolat_degrees,0,0)*1e2) / (Delta_Myr*1e6)
        MC_paleolat_cm_per_yr.append(paleolat_cm_per_yr)

    perc_02_5 = stats.scoreatpercentile(MC_paleolat_cm_per_yr, 2.5)
    perc_50_0 = stats.scoreatpercentile(MC_paleolat_cm_per_yr, 50)
    perc_97_5 = stats.scoreatpercentile(MC_paleolat_cm_per_yr, 97.5)
    
    output = pd.DataFrame({'pole1_MC_ages':pole1_MCages,
                           'pole2_MC_ages':pole2_MCages,
                           'pole1_MC_plat':pole1_MCpole_lat,
                           'pole1_MC_plon':pole1_MCpole_long,
                           'pole1_MC_paleolat':pole1_MCpaleolat,
                           'pole2_MC_plat':pole2_MCpole_lat,
                           'pole2_MC_plon':pole2_MCpole_long,
                           'pole2_MC_paleolat':pole2_MCpaleolat,
                           'angular_degrees':MC_angular_degrees,
                           'angular_degrees_per_myr':MC_angular_degrees_per_myr,
                           'angular_cm_per_yr':MC_angular_cm_per_yr,
                           'paleolat_degrees':MC_paleolat_degrees,
                           'paleolat_degrees_per_myr':MC_paleolat_degrees_per_myr,
                           'paleolat_cm_per_yr':MC_paleolat_cm_per_yr,})
    
    return output

samplesize=10000

# %% [markdown]
# Between Xiaofeng Dikes and Banxi Group:

# %%
np.random.seed(2020)

pole1_slice = SChina[SChina['name']=='Xiaofeng Dikes - Jing et al. (2019)']
pole2_slice = SChina[SChina['name']=='Banxi Group - site mean (f=0.6)']

pole1_plon = pole1_slice['plon'].iloc[0]
pole1_plat = pole1_slice['plat'].iloc[0]
pole1_kappa = 35.3
pole1_N = 10
pole1_age = pole1_slice['age'].iloc[0]
pole1_age_error = pole1_slice['age upper'].iloc[0] - pole1_slice['age'].iloc[0]
pole1_MCages = np.random.normal(pole1_age, pole1_age_error, samplesize)

pole2_plon = pole2_slice['plon'].iloc[0]
pole2_plat = pole2_slice['plat'].iloc[0]
pole2_kappa = 23.0
pole2_N = 15
pole2_age = pole2_slice['age'].iloc[0]
pole2_age_lower = pole2_slice['age upper'].iloc[0]
pole2_age_upper = pole2_slice['age lower'].iloc[0]
pole2_MCages = np.random.uniform(pole2_age_upper, pole2_age_lower, samplesize)

XF_BX = plate_rate_mc(pole1_plon,pole1_plat,pole1_kappa,pole1_N,pole1_age,pole1_MCages,
                      pole2_plon,pole2_plat,pole2_kappa,pole2_N,pole2_age,pole2_MCages,
                      108.82,27.91,
                      samplesize=samplesize, random_seed=2020)
# Out:
# angular difference between the means = 24.40
# paleolatitude for ref_loc resulting from the mean of pole1 = 66.17
# paleolatitude for ref_loc resulting from the mean of pole2 = 74.70
# rate of paleolatitudinal change implied by the means = 11.33 cm/yr
# plate velocity implied by the means = 32.41 cm/yr

# %% [markdown]
# Between Banxi Group and Madiyi Formation:

# %%
np.random.seed(2020)

pole1_slice = SChina[SChina['name']=='Banxi Group - site mean (f=0.6)']
pole2_slice = SChina[SChina['name']=='Madiyi Formation - site mean (f=0.6)']

pole1_plon = pole1_slice['plon'].iloc[0]
pole1_plat = pole1_slice['plat'].iloc[0]
pole1_kappa = 23.0
pole1_N = 15
pole1_age = pole1_slice['age'].iloc[0]
pole1_age_lower = pole1_slice['age upper'].iloc[0]
pole1_age_upper = pole1_slice['age lower'].iloc[0]
pole1_MCages = np.random.uniform(pole1_age_upper, pole1_age_lower, samplesize)

pole2_plon = pole2_slice['plon'].iloc[0]
pole2_plat = pole2_slice['plat'].iloc[0]
pole2_kappa = Madiyi_site_06_vgp_mean_pole['k']
pole2_N = 12
pole2_age = pole2_slice['age'].iloc[0]
pole2_age_error = (pole2_slice['age upper'].iloc[0] - pole2_slice['age'].iloc[0])/2
pole2_MCages = np.random.normal(pole2_age, pole2_age_error, samplesize)

BX_MY = plate_rate_mc(pole1_plon,pole1_plat,pole1_kappa,pole1_N,pole1_age,pole1_MCages,
                      pole2_plon,pole2_plat,pole2_kappa,pole2_N,pole2_age,pole2_MCages,
                      108.82,27.91,
                      samplesize=samplesize, random_seed=2020)
# Out:
# angular difference between the means = 18.86
# paleolatitude for ref_loc resulting from the mean of pole1 = 74.70
# paleolatitude for ref_loc resulting from the mean of pole2 = 66.20
# rate of paleolatitudinal change implied by the means = 11.67 cm/yr
# plate velocity implied by the means = 25.90 cm/yr

# %% [markdown]
# Between lower Banxi Group and the Madiyi Formation:

# %%
np.random.seed(2020)

pole1_slice = SChina[SChina['name']=='Banxi Group - lower site mean (f=0.6)']
pole2_slice = SChina[SChina['name']=='Madiyi Formation - site mean (f=0.6)']

pole1_plon = pole1_slice['plon'].iloc[0]
pole1_plat = pole1_slice['plat'].iloc[0]
pole1_kappa = 20.1
pole1_N = 11
pole1_age = pole1_slice['age'].iloc[0]
pole1_age_lower = pole1_slice['age upper'].iloc[0]
pole1_age_upper = pole1_slice['age lower'].iloc[0]
pole1_MCages = np.random.uniform(pole1_age_upper, pole1_age_lower, samplesize)

pole2_plon = pole2_slice['plon'].iloc[0]
pole2_plat = pole2_slice['plat'].iloc[0]
pole2_kappa = Madiyi_site_06_vgp_mean_pole['k']
pole2_N = 12
pole2_age = pole2_slice['age'].iloc[0]
pole2_age_error = (pole2_slice['age upper'].iloc[0] - pole2_slice['age'].iloc[0])/2
pole2_MCages = np.random.normal(pole2_age, pole2_age_error, samplesize)

LB_MY = plate_rate_mc(pole1_plon,pole1_plat,pole1_kappa,pole1_N,pole1_age,pole1_MCages,
                      pole2_plon,pole2_plat,pole2_kappa,pole2_N,pole2_age,pole2_MCages,
                      108.82,27.91,
                      samplesize=samplesize, random_seed=2020)
# Out:
# angular difference between the means = 20.03
# paleolatitude for ref_loc resulting from the mean of pole1 = 75.71
# paleolatitude for ref_loc resulting from the mean of pole2 = 66.20
# rate of paleolatitudinal change implied by the means = 13.05 cm/yr
# plate velocity implied by the means = 27.49 cm/yr

# %% [markdown]
# Between Madiyi Formation and Liantuo Formation:

# %%
np.random.seed(2020)

pole1_slice = SChina[SChina['name']=='Madiyi Formation - site mean (f=0.6)']
pole2_slice = SChina[SChina['name']=='Liantuo Formation - site mean (f=0.6)']

pole1_plon = pole1_slice['plon'].iloc[0]
pole1_plat = pole1_slice['plat'].iloc[0]
pole1_kappa = Madiyi_site_06_vgp_mean_pole['k']
pole1_N = 12
pole1_age = pole1_slice['age'].iloc[0]
pole1_age_error = (pole1_slice['age upper'].iloc[0] - pole1_slice['age'].iloc[0])/2
pole1_MCages = np.random.normal(pole1_age, pole1_age_error, samplesize)

pole2_plon = pole2_slice['plon'].iloc[0]
pole2_plat = pole2_slice['plat'].iloc[0]
pole2_kappa = Liantuo_site_06_vgp_mean_pole['k']
pole2_N = 14
pole2_age = pole2_slice['age'].iloc[0]
pole2_age_lower = 780
pole2_age_upper = 770
pole2_MCages = np.random.uniform(pole2_age_upper, pole2_age_lower, samplesize)

MY_LT = plate_rate_mc(pole1_plon,pole1_plat,pole1_kappa,pole1_N,pole1_age,pole1_MCages,
                      pole2_plon,pole2_plat,pole2_kappa,pole2_N,pole2_age,pole2_MCages,
                      108.82,27.91,
                      samplesize=samplesize, random_seed=2020)
# Out:
# angular difference between the means = 56.60
# paleolatitude for ref_loc resulting from the mean of pole1 = 66.20
# paleolatitude for ref_loc resulting from the mean of pole2 = 56.55
# rate of paleolatitudinal change implied by the means = 3.59 cm/yr
# plate velocity implied by the means = 21.05 cm/yr

# %% [markdown]
# Between Lower Grus. and Upper Grus. poles from Svalbard:
#
# Note that we do not apply an inclination correction to these poles, because they are derived from platform carbonates.
#
# First, estimate age of poles using the thermal subsidence model in Maloof et al. (2016):
#
# * Lower Grus. paleomagnetic data derived from within ~70m below boundary G1
# * Upper Grus. paleomagnetic data derived from within ~25m above boundary G1
# * Svan. paleomagnetic data derived from within ~200-350m above boundary S1
# * In this section, Akademikerbreen Group is ~2050m thick, and from chemostratigraphic correlation the top is ~750 Ma, with generous uncertainty of ~740-760 Ma
# * G1 at 810 Ma, ~550m into the Akademikerbreen
# * S1 at 795 Ma, ~850m into the Akademikerbreen

# %%
y_sr = 4e3 #m
y_st = 2e3 #m
y_c = 35e3 #m
y_l = 100e3 #m
rho_sr = 2060 #kg/m3
rho_st = 2500 #kg/m3
rho_c = 2700 #kg/m3
rho_m = 3300 #kg/m3
T_0 = 0 #C
T_m = 1333 #C
alpha = 3.28e-5 #1/C
kappa = 1e-6 # m2/s

T_c = ((T_m-T_0)/2) * (y_c/y_l)
T_sc = 0.5 * (T_m + (y_c/y_l)*(T_m-T_0))
rho_sc = 2950 #kg/m3

t_total = 150 #m.y.
my_s = 1e6*365.25*24*60*60
t = np.linspace(0, t_total*my_s, 500) #s

rho_c_T = rho_c * (1 - alpha*T_c)
rho_sc_T = rho_sc * (1 - alpha*T_sc)
rho_m_T = rho_m * (1 - alpha*T_m)

#beta = (rho_c_T*y_c + rho_sc_T*(y_l-y_c) - rho_m_T*y_l) / \
#       (rho_c_T*y_c + rho_sc_T*(y_l-y_c) - rho_sr*y_sr + rho_m_T*(y_sr-y_l))

beta = 1.35

E_0 = (4*y_l*rho_m*alpha*T_m) / ((np.pi**2)*(rho_m-rho_st))

tau = (y_l**2) / ((np.pi**2)*kappa)

S = E_0 * (beta/np.pi) * np.sin(np.pi/beta) * (1-(np.e**(-t/tau)))

# %%
fig, ax = plt.subplots(figsize=(8,5))

def error_box(ax, x, y, xerror, yerror):
    rect = patches.Rectangle((x-xerror,y-yerror),
                             xerror*2,yerror*2,
                             facecolor='C7',zorder=-999,alpha=1)
    ax.add_patch(rect)
    
def pole_box(ax, ymin, ymax, c):
    rect = patches.Rectangle((700,ymin),
                             850-700,ymax-ymin,
                             facecolor=c,zorder=-999,alpha=0.5)
    ax.add_patch(rect)

t_G1 = 810
t_G1_uncertainty = 2
t_S1 = 795
t_S1_uncertainty = 2
t_top = 750
t_top_uncertainty = 10

h_G1 = 550
h_G1_uncertainty = 50
h_S1 = 850
h_S1_uncertainty = 50
h_top = 2050
h_top_uncertainty = 50

error_box(ax, t_G1, h_G1, t_G1_uncertainty, h_G1_uncertainty)
error_box(ax, t_S1, h_S1, t_S1_uncertainty, h_S1_uncertainty)
error_box(ax, t_top, h_top, t_top_uncertainty, h_top_uncertainty)

color_mapping = plt.cm.ScalarMappable(cmap='cool')
colors = color_mapping.to_rgba([0.25,0.50,0.75]).tolist()

pole_box(ax, h_G1-h_G1_uncertainty-70, h_G1, colors[0])
pole_box(ax, h_G1, h_G1+h_G1_uncertainty+25, colors[1])
pole_box(ax, h_S1+200, h_S1+350, colors[2])

t_start = 819
t_Ma = -(t/my_s)+t_start
ax.plot(t_Ma, S, lw=3, c='C1')

ax.set_xlim(850,700)
ax.set_ylim(2500,0)

ax.set_xlabel('age [Ma]')
ax.set_ylabel('subsidence [m]')

ax.grid(ls='--', c='C7')

plt.show(fig)

# %%
LG_age_lower = np.interp(h_G1-70, S, t_Ma)
UG_age_upper = np.interp(h_G1+25, S, t_Ma)

print('LG_age_lower = {:.2f} Ma'.format(LG_age_lower))
print('UG_age_upper = {:.2f} Ma'.format(UG_age_upper))
# Out:
# LG_age_lower = 811.43 Ma
# UG_age_upper = 809.69 Ma

# %%
np.random.seed(2020)

# Lower Grus.
pole1_plon = 204.9
pole1_plat = 19.6
pole1_kappa = 39.9
pole1_N = 4
pole1_age = (815+810.5)/2
pole1_age_lower = 815
pole1_age_upper = 810.5
pole1_MCages = np.random.uniform(pole1_age_upper, pole1_age_lower, samplesize)

# Upper Grus.
pole2_plon = 72.6+180
pole2_plat = -1.1
pole2_kappa = 84.2
pole2_N = 5
pole1_age = (809.5+805)/2
pole2_age_lower = 809.5
pole2_age_upper = 805
pole2_MCages = np.random.uniform(pole2_age_upper, pole2_age_lower, samplesize)

print('pole1_age_lower = {:.2f} Ma'.format(pole1_age_lower))
print('pole1_age_upper = {:.2f} Ma'.format(pole1_age_upper))
print('pole2_age_lower = {:.2f} Ma'.format(pole2_age_lower))
print('pole2_age_upper = {:.2f} Ma'.format(pole2_age_upper))

LG_UG = plate_rate_mc(pole1_plon,pole1_plat,pole1_kappa,pole1_N,pole1_age,pole1_MCages,
                      pole2_plon,pole2_plat,pole2_kappa,pole2_N,pole2_age,pole2_MCages,
                      18.5,79.0,
                      samplesize=samplesize, random_seed=2020)
# Out:
# pole1_age_lower = 815.00 Ma
# pole1_age_upper = 810.50 Ma
# pole2_age_lower = 809.50 Ma
# pole2_age_upper = 805.00 Ma
# angular difference between the means = 51.14
# paleolatitude for ref_loc resulting from the mean of pole1 = 8.66
# paleolatitude for ref_loc resulting from the mean of pole2 = -7.51
# rate of paleolatitudinal change implied by the means = 5.58 cm/yr
# plate velocity implied by the means = 17.63 cm/yr

# %% [markdown]
# Plots:

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(8,3), sharey=True)

bins = np.linspace(np.min([BX_MY['pole1_MC_ages'],BX_MY['pole2_MC_ages']]),
                   np.max([BX_MY['pole1_MC_ages'],BX_MY['pole2_MC_ages']]),
                   50)
ax[0].hist(BX_MY['pole1_MC_ages'], color='C0', alpha=0.75, bins=bins)
ax[0].hist(BX_MY['pole2_MC_ages'], color='C1', alpha=0.75, bins=bins)
ax[0].set_xlabel('age [Ma]')
ax[0].invert_xaxis()

bins = np.linspace(np.min([LG_UG['pole1_MC_ages'],LG_UG['pole2_MC_ages']]),
                   np.max([LG_UG['pole1_MC_ages'],LG_UG['pole2_MC_ages']]),
                   50)
ax[1].hist(LG_UG['pole1_MC_ages'], color='C0', alpha=0.75, bins=bins)
ax[1].hist(LG_UG['pole2_MC_ages'], color='C1', alpha=0.75, bins=bins)
ax[1].set_xlabel('age [Ma]')
ax[1].invert_xaxis()

plt.show(fig)

# %%
lat_grid = [-80,-60,-30,0,30,60,80]
lon_grid = np.arange(-180,180+60,60)

ax = ipmag.make_orthographic_map(add_land=False, central_longitude=115, central_latitude=45,
                                 figsize=(7,7), grid_lines=False)

ax.add_feature(cartopy.feature.LAND, zorder=-99,
               facecolor='#dddddd', edgecolor='none')

ipmag.plot_vgp(ax, BX_MY['pole1_MC_plon'], BX_MY['pole1_MC_plat'], color='#008d3c', edge='none', markersize=1)
ipmag.plot_vgp(ax, BX_MY['pole2_MC_plon'], BX_MY['pole2_MC_plat'], color='#99ccaf', edge='none', markersize=1)

ax.scatter(108.82,27.91,transform=ccrs.PlateCarree(), c='k')

ax.gridlines(xlocs=lon_grid, ylocs=lat_grid, linewidth=0.5,
             color='C7', linestyle='dotted', zorder=-1)

ax.set_title('Banxi to Madiyi')

#plt.savefig('../Output/TPW_MC_SChina.pdf', bbox_inches='tight')
plt.show(fig)

# %%
lat_grid = [-80,-60,-30,0,30,60,80]
lon_grid = np.arange(-180,180+60,60)

ax = ipmag.make_orthographic_map(add_land=False, central_longitude=240, central_latitude=20,
                                 figsize=(7,7), grid_lines=False)

ax.add_feature(cartopy.feature.LAND, zorder=-99,
               facecolor='#dddddd', edgecolor='none')

ipmag.plot_vgp(ax, LG_UG['pole1_MC_plon'], LG_UG['pole1_MC_plat'], color='#55a0d4', edge='none', markersize=1)
ipmag.plot_vgp(ax, LG_UG['pole2_MC_plon'], LG_UG['pole2_MC_plat'], color='#c0ccd4', edge='none', markersize=1)

ax.scatter(18.5,79.0,transform=ccrs.PlateCarree(), c='k')

ax.gridlines(xlocs=lon_grid, ylocs=lat_grid, linewidth=0.5,
             color='C7', linestyle='dotted', zorder=-1)

ax.set_title('Lower Grus. to Upper Grus.')

#plt.savefig('../Output/TPW_MC_Svalbard.pdf', bbox_inches='tight')
plt.show(fig)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,5))

ax[0].scatter(BX_MY['pole1_MC_ages'], BX_MY['pole1_MC_paleolat'], s=1, c='C0', alpha=0.5)
ax[0].scatter(BX_MY['pole2_MC_ages'], BX_MY['pole2_MC_paleolat'], s=1, c='C1', alpha=0.5)
ax[0].plot([BX_MY['pole1_MC_ages'],BX_MY['pole2_MC_ages']],
           [BX_MY['pole1_MC_paleolat'],BX_MY['pole2_MC_paleolat']],
           c='C7', linewidth=0.1, zorder=-99, alpha=0.5)

ax[1].scatter(LG_UG['pole1_MC_ages'], LG_UG['pole1_MC_paleolat'], s=1, c='C0', alpha=0.5)
ax[1].scatter(LG_UG['pole2_MC_ages'], LG_UG['pole2_MC_paleolat'], s=1, c='C1', alpha=0.5)
ax[1].plot([LG_UG['pole1_MC_ages'],LG_UG['pole2_MC_ages']],
           [LG_UG['pole1_MC_paleolat'],LG_UG['pole2_MC_paleolat']],
           c='C7', linewidth=0.1, zorder=-99, alpha=0.5)

ax[0].set_xlabel('age [Ma]')
ax[1].set_xlabel('age [Ma]')
ax[0].set_ylabel('paleolatitude')
ax[1].set_ylabel('paleolatitude')
ax[0].invert_xaxis()
ax[1].invert_xaxis()

plt.show()

# %%
BX_MY_angular_degrees_02_5 = stats.scoreatpercentile(BX_MY['angular_degrees'], 2.5)
BX_MY_angular_degrees_50_0 = stats.scoreatpercentile(BX_MY['angular_degrees'], 50)
BX_MY_angular_degrees_97_5 = stats.scoreatpercentile(BX_MY['angular_degrees'], 97.5)

LG_UG_angular_degrees_02_5 = stats.scoreatpercentile(LG_UG['angular_degrees'], 2.5)
LG_UG_angular_degrees_50_0 = stats.scoreatpercentile(LG_UG['angular_degrees'], 50)
LG_UG_angular_degrees_97_5 = stats.scoreatpercentile(LG_UG['angular_degrees'], 97.5)

print('BX_MY angular degrees 02.5% = {:.2f}'.format(BX_MY_angular_degrees_02_5))
print('BX_MY angular degrees 50.0% = {:.2f}'.format(BX_MY_angular_degrees_50_0))
print('BX_MY angular degrees 97.5% = {:.2f}'.format(BX_MY_angular_degrees_97_5))
print('')
print('LG_UG angular degrees 02.5% = {:.2f}'.format(LG_UG_angular_degrees_02_5))
print('LG_UG angular degrees 50.0% = {:.2f}'.format(LG_UG_angular_degrees_50_0))
print('LG_UG angular degrees 97.5% = {:.2f}'.format(LG_UG_angular_degrees_97_5))
# Out:
# BX_MY angular degrees 02.5% = 11.39
# BX_MY angular degrees 50.0% = 19.26
# BX_MY angular degrees 97.5% = 26.86
#
# LG_UG angular degrees 02.5% = 40.50
# LG_UG angular degrees 50.0% = 51.27
# LG_UG angular degrees 97.5% = 61.86

# %%
fig, ax = plt.subplots(figsize=(7,4))

bins = np.linspace(np.min([BX_MY['angular_degrees'],LG_UG['angular_degrees']]),
                   np.max([BX_MY['angular_degrees'],LG_UG['angular_degrees']]),
                   100)
ax.hist(BX_MY['angular_degrees'], color='C0', alpha=0.75, bins=bins, label='Banxi to Madiyi')
ax.hist(LG_UG['angular_degrees'], color='C1', alpha=0.75, bins=bins, label='Lower Grus. to Upper Grus.')

ax.legend()
ax.set_xlabel('angular difference')

plt.show(fig)

# %% [markdown]
# As per [math](https://math.stackexchange.com/questions/40224/probability-of-a-point-taken-from-a-certain-normal-distribution-will-be-greater):

# %%
LG_UG_angular_mean = np.mean(LG_UG['angular_degrees'])
LG_UG_angular_std = np.std(LG_UG['angular_degrees'])

BX_MY_angular_mean = np.mean(BX_MY['angular_degrees'])
BX_MY_angular_std = np.std(BX_MY['angular_degrees'])

p_angular_overlap = 1-(stats.norm.cdf(-(BX_MY_angular_mean-LG_UG_angular_mean)/\
                                      np.sqrt(BX_MY_angular_std**2 + LG_UG_angular_std**2)))

print('joint probability that BX_MY is greater than LG_UG = {:.1e}%'.format(p_angular_overlap*100))
# Out:
# joint probability that BX_MY is greater than LG_UG = 8.5e-05%

# %%
fig, ax = plt.subplots(figsize=(7,4))

bins = np.linspace(np.min([LB_MY['angular_degrees'],LG_UG['angular_degrees']]),
                   np.max([LB_MY['angular_degrees'],LG_UG['angular_degrees']]),
                   100)
ax.hist(LB_MY['angular_degrees'], color='C0', alpha=0.75, bins=bins, label='Lower Banxi to Madiyi')
ax.hist(LG_UG['angular_degrees'], color='C1', alpha=0.75, bins=bins, label='Lower Grus. to Upper Grus.')

ax.legend()
ax.set_xlabel('angular difference')

plt.show(fig)

# %%
LG_UG_angular_mean = np.mean(LG_UG['angular_degrees'])
LG_UG_angular_std = np.std(LG_UG['angular_degrees'])

LB_MY_angular_mean = np.mean(LB_MY['angular_degrees'])
LB_MY_angular_std = np.std(LB_MY['angular_degrees'])

p_angular_overlap = 1-(stats.norm.cdf(-(LB_MY_angular_mean-LG_UG_angular_mean)/\
                                      np.sqrt(LB_MY_angular_std**2 + LG_UG_angular_std**2)))

print('joint probability that LB_MY is greater than LG_UG = {:.1e}%'.format(p_angular_overlap*100))
# Out:
# joint probability that LB_MY is greater than LG_UG = 7.7e-04%

# %%
fig, ax = plt.subplots(figsize=(7,4))

bins = np.linspace(np.min([BX_MY['angular_degrees_per_myr'],LG_UG['angular_degrees_per_myr']]),
                   np.min([np.max([BX_MY['angular_degrees_per_myr'],LG_UG['angular_degrees_per_myr']]),500]),
                   100)
ax.hist(BX_MY['angular_degrees_per_myr'], color='C0', alpha=0.75, bins=bins, label='Banxi to Madiyi')
ax.hist(LG_UG['angular_degrees_per_myr'], color='C1', alpha=0.75, bins=bins, label='Lower Grus. to Upper Grus.')

ax.legend()
ax.set_xlabel('degrees/m.y.')

plt.show(fig)

# %%
BX_MY_angular_cm_per_yr_02_5 = stats.scoreatpercentile(BX_MY['angular_cm_per_yr'], 2.5)
BX_MY_angular_cm_per_yr_50_0 = stats.scoreatpercentile(BX_MY['angular_cm_per_yr'], 50)
BX_MY_angular_cm_per_yr_97_5 = stats.scoreatpercentile(BX_MY['angular_cm_per_yr'], 97.5)

LG_UG_angular_cm_per_yr_02_5 = stats.scoreatpercentile(LG_UG['angular_cm_per_yr'], 2.5)
LG_UG_angular_cm_per_yr_50_0 = stats.scoreatpercentile(LG_UG['angular_cm_per_yr'], 50)
LG_UG_angular_cm_per_yr_97_5 = stats.scoreatpercentile(LG_UG['angular_cm_per_yr'], 97.5)

print('BX_MY angular cm/yr 02.5% = {:.2f}'.format(BX_MY_angular_cm_per_yr_02_5))
print('BX_MY angular cm/yr 50.0% = {:.2f}'.format(BX_MY_angular_cm_per_yr_50_0))
print('BX_MY angular cm/yr 97.5% = {:.2f}'.format(BX_MY_angular_cm_per_yr_97_5))
print('')
print('LG_UG angular cm/yr 02.5% = {:.2f}'.format(LG_UG_angular_cm_per_yr_02_5))
print('LG_UG angular cm/yr 50.0% = {:.2f}'.format(LG_UG_angular_cm_per_yr_50_0))
print('LG_UG angular cm/yr 97.5% = {:.2f}'.format(LG_UG_angular_cm_per_yr_97_5))
# Out:
# BX_MY angular cm/yr 02.5% = 14.28
# BX_MY angular cm/yr 50.0% = 26.49
# BX_MY angular cm/yr 97.5% = 47.96
#
# LG_UG angular cm/yr 02.5% = 59.80
# LG_UG angular cm/yr 50.0% = 103.68
# LG_UG angular cm/yr 97.5% = 283.88

# %%
fig, ax = plt.subplots(figsize=(7,4))

bins = np.linspace(np.min([BX_MY['angular_cm_per_yr'],LG_UG['angular_cm_per_yr']]),
                   np.min([np.max([BX_MY['angular_cm_per_yr'],LG_UG['angular_cm_per_yr']]),1000]),
                   200)
ax.hist(BX_MY['angular_cm_per_yr'], color='C0', alpha=0.75, bins=bins, label='Banxi to Madiyi')
ax.hist(LG_UG['angular_cm_per_yr'], color='C1', alpha=0.75, bins=bins, label='Lower Grus. to Upper Grus.')
ax.hist(MY_LT['angular_cm_per_yr'], color='C2', alpha=0.75, bins=bins, label='Madiyi to Liantuo')

ax.axvline(20, c='C7', ls='--')

ax.legend()
ax.set_xlabel('cm/yr')
ax.set_xlim(0,200)

plt.show(fig)

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(5,8))

bins = np.linspace(np.min([BX_MY['pole1_MC_ages'],BX_MY['pole2_MC_ages']]),
                   np.max([BX_MY['pole1_MC_ages'],BX_MY['pole2_MC_ages']]),
                   100)
ax[0].hist(BX_MY['pole1_MC_ages'], color='#008d3c', alpha=1.0, bins=bins, label='Banxi')
ax[0].hist(BX_MY['pole2_MC_ages'], color='#99ccaf', alpha=1.0, bins=bins, label='Madiyi')
ax[0].set_xlabel('age [Ma]', fontweight='bold')
ax[0].set_xticks(np.arange(802,818+2,2))
ax[0].set_xlim(818,802)
#ax[0].legend()

bins = np.linspace(np.min([BX_MY['angular_degrees'],LG_UG['angular_degrees']]),
                   np.max([BX_MY['angular_degrees'],LG_UG['angular_degrees']]),
                   100)
ax[1].hist(BX_MY['angular_degrees'], color=SChina_color, alpha=1.0, bins=bins, label='Banxi to Madiyi')
ax[1].hist(LG_UG['angular_degrees'], color=Svalbard_color, alpha=1.0, bins=bins, label='Lower Grus. to Upper Grus.')
#ax[1].legend()
ax[1].set_xlabel('angular difference [$^{\circ}$]', fontweight='bold')

bins = np.linspace(np.min([BX_MY['angular_cm_per_yr'],LG_UG['angular_cm_per_yr']]),
                   np.max([BX_MY['angular_cm_per_yr'],LG_UG['angular_cm_per_yr']]),
                   300)
ax[2].hist(BX_MY['angular_cm_per_yr'], color=SChina_color, alpha=1.0, bins=bins, label='Banxi to Madiyi')
ax[2].hist(LG_UG['angular_cm_per_yr'], color=Svalbard_color, alpha=1.0, bins=bins, label='Lower Grus. to Upper Grus.')
ax[2].axvline(20, c='C7', ls='--')
ax[2].set_xlim(0,200)
#ax[2].legend()
ax[2].set_xlabel('plate velocity [cm/yr]', fontweight='bold')

for i in range(3):
    ax[i].set_yticks([])
    ax[i].spines['right'].set_visible(False)
    ax[i].spines['left'].set_visible(False)
    ax[i].spines['top'].set_visible(False)

fig.tight_layout()
#plt.savefig('../Output/TPW_MC.pdf', bbox_inches='tight')
plt.show(fig)

# %% [markdown]
# ## Other Poles

# %%
pole_path = '../../../Rodinia_Model/Torsvik-extended/poles/raw-data/'

# %% [markdown]
# ### Laurentia

# %% [markdown]
# #### Compilation

# %%
Laurentia = pd.DataFrame(columns=compilation_cols)

# %%
SwansonHysell_preprint = pd.read_csv(pole_path+'Swanson-Hysell_preprint.csv')
SwansonHysell_preprint.columns
# Out:
# Index(['terrane', 'unit name', 'Nordic rating', 'slon', 'slat', 'plon', 'plat',
#        'a95', 'age', 'pole reference'],
#       dtype='object')

# %% [markdown]
# Clean up the age column:

# %%
SwansonHysell_preprint_age_nominal = []
SwansonHysell_preprint_age_upper = []
SwansonHysell_preprint_age_lower = []

for age in SwansonHysell_preprint['age']:
    age_split = age.split('$')
    age_nominal = np.float(age_split[0])
    age_split_upper_lower = age_split[1].split('}')
    age_split_upper = age_split_upper_lower[0].split('+')[1]
    age_split_lower = age_split_upper_lower[1].split('-')[1]
    age_upper = np.float(age_split_upper)
    age_lower = np.float(age_split_lower)
    
    SwansonHysell_preprint_age_nominal.append(age_nominal)
    SwansonHysell_preprint_age_upper.append(age_nominal + age_upper)
    SwansonHysell_preprint_age_lower.append(age_nominal - age_lower)

# %% [markdown]
# Assign columns:

# %%
Laurentia['name'] = SwansonHysell_preprint['unit name']
Laurentia['terrane'] = SwansonHysell_preprint['terrane']
Laurentia['age'] = SwansonHysell_preprint_age_nominal
Laurentia['age upper'] = SwansonHysell_preprint_age_upper
Laurentia['age lower'] = SwansonHysell_preprint_age_lower
Laurentia['plat'] = SwansonHysell_preprint['plat']
Laurentia['plon'] = SwansonHysell_preprint['plon']
Laurentia['a95'] = SwansonHysell_preprint['a95']
#Laurentia['f']
Laurentia['slat'] = SwansonHysell_preprint['slat']
Laurentia['slon'] = SwansonHysell_preprint['slon']
#Laurentia['dec']
#Laurentia['inc']
#Laurentia['dir_a95']
Laurentia['pole ref'] = SwansonHysell_preprint['pole reference']
#Laurentia['age ref']
Laurentia['grade'] = SwansonHysell_preprint['Nordic rating']
#Laurentia['note']
#Laurentia['plateID']

# %% [markdown]
# Add Adirondack poles:

# %%
i = len(Laurentia)

Laurentia.loc[i, 'name']    = 'Adirondack fayalite granite'
Laurentia.loc[i, 'terrane'] = 'Laurentia'
Laurentia.loc[i, 'age']       = 990
Laurentia.loc[i, 'age upper'] = 990 + 20
Laurentia.loc[i, 'age lower'] = 990 - 20
Laurentia.loc[i, 'plat'] = -28.4
Laurentia.loc[i, 'plon'] = 132.7
Laurentia.loc[i, 'a95']  = 6.9
Laurentia.loc[i, 'f'] = np.nan
Laurentia.loc[i, 'slat'] = 44.0
Laurentia.loc[i, 'slon'] = 285.5
Laurentia.loc[i, 'dec']     = np.nan
Laurentia.loc[i, 'inc']     = np.nan
Laurentia.loc[i, 'dir_a95'] = np.nan
Laurentia.loc[i, 'pole ref'] = 'Brown et al. (2012)'
Laurentia.loc[i, 'age ref']  = '-'
Laurentia.loc[i, 'grade'] = 'NR'
Laurentia.loc[i, 'note']  = '-'
Laurentia.loc[i, 'plateID'] = 101
i = i + 1

Laurentia.loc[i, 'name']    = 'Adirondack metamorphic anorthosites'
Laurentia.loc[i, 'terrane'] = 'Laurentia'
Laurentia.loc[i, 'age']       = 970
Laurentia.loc[i, 'age upper'] = 970 + 20
Laurentia.loc[i, 'age lower'] = 970 - 20
Laurentia.loc[i, 'plat'] = -25.1
Laurentia.loc[i, 'plon'] = 149.0
Laurentia.loc[i, 'a95']  = 11.6
Laurentia.loc[i, 'f'] = np.nan
Laurentia.loc[i, 'slat'] = 44.0
Laurentia.loc[i, 'slon'] = 286.0
Laurentia.loc[i, 'dec']     = np.nan
Laurentia.loc[i, 'inc']     = np.nan
Laurentia.loc[i, 'dir_a95'] = np.nan
Laurentia.loc[i, 'pole ref'] = 'Brown et al. (2012)'
Laurentia.loc[i, 'age ref']  = '-'
Laurentia.loc[i, 'grade'] = 'NR'
Laurentia.loc[i, 'note']  = '-'
Laurentia.loc[i, 'plateID'] = 101
i = i + 1

Laurentia.loc[i, 'name']    = 'Adirondack Microcline gneiss'
Laurentia.loc[i, 'terrane'] = 'Laurentia'
Laurentia.loc[i, 'age']       = 960
Laurentia.loc[i, 'age upper'] = 960 + 20
Laurentia.loc[i, 'age lower'] = 960 - 20
Laurentia.loc[i, 'plat'] = -18.4
Laurentia.loc[i, 'plon'] = 151.1
Laurentia.loc[i, 'a95']  = 10.5
Laurentia.loc[i, 'f'] = np.nan
Laurentia.loc[i, 'slat'] = 44.0
Laurentia.loc[i, 'slon'] = 285.0
Laurentia.loc[i, 'dec']     = np.nan
Laurentia.loc[i, 'inc']     = np.nan
Laurentia.loc[i, 'dir_a95'] = np.nan
Laurentia.loc[i, 'pole ref'] = 'Brown et al. (2012)'
Laurentia.loc[i, 'age ref']  = '-'
Laurentia.loc[i, 'grade'] = 'NR'
Laurentia.loc[i, 'note']  = '-'
Laurentia.loc[i, 'plateID'] = 101
i = i + 1

# %% [markdown]
# Assign plateIDs:

# %%
# 101 for most poles
Laurentia['plateID'] = 101

# other poles
Laurentia.loc[Laurentia['name']=='Torridon Group','plateID'] = 303
Laurentia.loc[Laurentia['name']=='Lower Grusdievbreen Formation','plateID'] = 311
Laurentia.loc[Laurentia['name']=='Upper Grusdievbreen Formation','plateID'] = 311
Laurentia.loc[Laurentia['name']=='Svanbergfjellet Formation','plateID'] = 311

# %% [markdown]
# Flip polarity of some poles:

# %%
flip_poles = ['Long Range Dykes','Baie des Moutons complex','Callander Alkaline Complex','Catoctin Basalts','Sept-Iles layered intrusion']
for i in Laurentia.index:
    if Laurentia['name'][i] in flip_poles:
        Laurentia.loc[i,'dec'] = (Laurentia['dec'][i] + 180) % 360
        Laurentia.loc[i,'inc'] = -Laurentia['inc'][i]
        Laurentia.loc[i,'plat'] = -Laurentia['plat'][i]
        Laurentia.loc[i,'plon'] = (Laurentia['plon'][i] + 180) % 360

# %% [markdown]
# Update age:

# %%
# very close to the BSS
Laurentia.loc[Laurentia['name']=='Lower Grusdievbreen Formation','age upper'] = 820
Laurentia.loc[Laurentia['name']=='Lower Grusdievbreen Formation','age lower'] = 810
Laurentia.loc[Laurentia['name']=='Lower Grusdievbreen Formation','age'] = (820+810)/2

# within the BSS
Laurentia.loc[Laurentia['name']=='Upper Grusdievbreen Formation','age upper'] = 810
Laurentia.loc[Laurentia['name']=='Upper Grusdievbreen Formation','age lower'] = 795
Laurentia.loc[Laurentia['name']=='Upper Grusdievbreen Formation','age'] = (810+795)/2

# after the BSS
Laurentia.loc[Laurentia['name']=='Svanbergfjellet Formation','age upper'] = 790
Laurentia.loc[Laurentia['name']=='Svanbergfjellet Formation','age lower'] = 780
Laurentia.loc[Laurentia['name']=='Svanbergfjellet Formation','age'] = ((790+780)/2)

# %% [markdown]
# Apply inclination correction (f=0.6) to sedimentary poles:

# %%
Laurentia.loc[Laurentia['name']=='Uinta Mountain Group','f'] = 0.6
Laurentia.loc[Laurentia['name']=='Uinta Mountain Group','plat'] = 1.2
Laurentia.loc[Laurentia['name']=='Uinta Mountain Group','plon'] = 161.8
Laurentia.loc[Laurentia['name']=='Uinta Mountain Group','a95'] = 4.7

# %% [markdown]
# #### Summary

# %%
Laurentia.sort_values('age', ascending=False, inplace=True)
Laurentia = Laurentia[compilation_cols]
Laurentia.reset_index(inplace=True, drop=True)
Laurentia
# Out:
#                                                   name  \
# 0                              Stillwater Complex - C2
# 1                         Otto Stock dykes and aureole
# 2                                         Defeat Suite
# 3                           Ptarmigan-Mistassini dykes
# 4                                   Matachewan dykes R
# 5                                   Matachewan dykes N
# 6                                         Malley dykes
# 7                                     Senneterre dykes
# 8                                   Nipissing N1 sills
# 9                                         Dogrib dykes
# 10                                   Biscotasing dykes
# 11   Rabbit Creek, Powder River, and South Path Dykes
# 12                                         Indin dykes
# 13                                    Marathon dykes N
# 14                                    Marathon dykes R
# 15                                  Cauchon Lake dykes
# ...

# %%
Laurentia.to_csv('../Output/Laurentia-poles.csv',index=False)
Laurentia_vpgFeatureCollection = create_vgp_FeatureCollection(Laurentia)
create_vgp_gpml(Laurentia_vpgFeatureCollection, '../Output/Laurentia-poles.gpml')
# Out:
# Palaeomagnetic pole data successfully exported in GPML format.

# %% [markdown]
# #### Paleolatitude

# %%
# 107 : Baffin
Euler_107 = [-69.79, 101.72, 5.98]

# 303 : Northern Highlands (Scotland)
Euler_303 = [71.41, 152.6, -23.68]

# 311 : East Svalbard
Euler_311 = [-81.0, 125.0, 68.0]

# %%
Laurentia['corrected_plon'] = pd.Series()
Laurentia['corrected_plat'] = pd.Series()

for i in range(len(Laurentia)):
    if Laurentia['plateID'][i] == 101:
        Laurentia['corrected_plat'][i] = Laurentia['plat'][i]
        Laurentia['corrected_plon'][i] = Laurentia['plon'][i]
    elif Laurentia['plateID'][i] == 107:
        plat, plon = pmag.pt_rot(Euler_107, [Laurentia['plat'][i]], [Laurentia['plon'][i]])
        Laurentia['corrected_plat'][i] = plat[0]
        Laurentia['corrected_plon'][i] = plon[0]
    elif Laurentia['plateID'][i] == 303:
        plat, plon = pmag.pt_rot(Euler_303, [Laurentia['plat'][i]], [Laurentia['plon'][i]])
        Laurentia['corrected_plat'][i] = plat[0]
        Laurentia['corrected_plon'][i] = plon[0]
    elif Laurentia['plateID'][i] == 311:
        plat, plon = pmag.pt_rot(Euler_311, [Laurentia['plat'][i]], [Laurentia['plon'][i]])
        Laurentia['corrected_plat'][i] = plat[0]
        Laurentia['corrected_plon'][i] = plon[0]

# %%
# calculate age uncertainty as relative to the nominal age
Laurentia['age upper diff'] = Laurentia['age upper'] - Laurentia['age']
Laurentia['age lower diff'] = Laurentia['age'] - Laurentia['age lower']

# calculate implied paleolatitude of centroid point
Laurentia_centroid_lat = 46.8
Laurentia_centroid_lon = 267.9

Laurentia['centroid_lat'] = pd.Series()

for i in range(len(Laurentia)):
    lat = ipmag.lat_from_pole(Laurentia_centroid_lon, Laurentia_centroid_lat,
                              Laurentia['corrected_plon'][i], Laurentia['corrected_plat'][i])
    Laurentia['centroid_lat'][i] = lat

# %% [markdown]
# ### India

# %% [markdown]
# #### Compilation

# %%
India = pd.DataFrame(columns=compilation_cols)

# %%
Leirubakki_India = pd.read_csv(pole_path+'Leirubakki-India.csv')
Leirubakki_India.columns
# Out:
# Index(['Terrane', 'POLENAME', 'SLAT', 'SLON', 'DEC', 'INC', 'PLAT', 'PLON',
#        'DP', 'DM', 'A95', 'f', 'INCf', 'PLATf', 'PLONf', 'DPf', 'DMf', 'A95f',
#        'Grade', 'nominal age', 'lomagage', 'himagage', 'POLE AUTHORS', 'YEAR'],
#       dtype='object')

# %% [markdown]
# Clean up the pole references column:

# %%
Leirubakki_India_pole_ref = []

for i in range(len(Leirubakki_India)):
    pole_ref = str(Leirubakki_India['POLE AUTHORS'][i]) + ' (' + str(Leirubakki_India['YEAR'][i]) + ')'
    Leirubakki_India_pole_ref.append(pole_ref)

# %% [markdown]
# Assign columns:

# %%
India['name'] = Leirubakki_India['POLENAME']
India['terrane'] = Leirubakki_India['Terrane']
India['age'] = Leirubakki_India['nominal age']
India['age upper'] = Leirubakki_India['himagage']
India['age lower'] = Leirubakki_India['lomagage']
India['plat'] = Leirubakki_India['PLAT']
India['plon'] = Leirubakki_India['PLON']
India['a95'] = Leirubakki_India['A95']
#India['f']
India['slat'] = Leirubakki_India['SLAT']
India['slon'] = Leirubakki_India['SLON']
India['dec'] = Leirubakki_India['DEC']
India['inc'] = Leirubakki_India['INC']
#India['dir_a95']
India['pole ref'] = Leirubakki_India_pole_ref
#India['age ref']
India['grade'] = Leirubakki_India['Grade']
#India['note']
India['plateID'] = 501

# %% [markdown]
# Update age of the Malani Igneous Suite:

# %%
India.loc[India['name']=='Malani Igneous Suite -Comb','age'] = 752
India.loc[India['name']=='Malani Igneous Suite -Comb','age upper'] = 752 + 18
India.loc[India['name']=='Malani Igneous Suite -Comb','age lower'] = 752 - 18

# %% [markdown]
# #### Summary

# %%
India.sort_values('age', ascending=False, inplace=True)
India = India[compilation_cols]
India.reset_index(inplace=True, drop=True)
India
# Out:
#                              name               terrane   age  age upper  \
# 0            Newer Dolerites-2760       India-Singhbhum  2762       2764
# 1     Dharwar Dykes Combined 2.37         India-Dharwar  2367       2368
# 2     Dharwar-Dykes Combined 2.21         India-Dharwar  2216       2225
# 3     Dharwar-Dykes Combined 2.18         India-Dharwar  2177       2182
# 4              Dharwar-Dykes 2.08         India-Dharwar  2082       2083
# 5      Bundelkhand NW-SE Combined     India-Bundelkhand  1979       1982
# 6           Bastar Dykes-Combined  India-Dharwar+Bastar  1887       1892
# 7     Dharwar Dykes Combined 1.88  India-Dharwar+Bastar  1885       1888
# 8                    Lakhna Dykes           India-South  1466       1469
# 9   Harohalli Alkaline Dykes - AN           India-South  1192       1202
# 10                   Mahoba Dykes           India-North  1113       1120
# 11     Majhgawan Kimberlite Comb.           India-North  1074       1087
# ...

# %%
India.to_csv('../Output/India-poles.csv',index=False)
India_vpgFeatureCollection = create_vgp_FeatureCollection(India)
create_vgp_gpml(India_vpgFeatureCollection, '../Output/India-poles.gpml')
# Out:
# Palaeomagnetic pole data successfully exported in GPML format.

# %% [markdown]
# #### Paleolatitude

# %%
# calculate age uncertainty as relative to the nominal age
India['age upper diff'] = India['age upper'] - India['age']
India['age lower diff'] = India['age'] - India['age lower']

# calculate implied paleolatitude of centroid point
India_centroid_lat = 21.5
India_centroid_lon = 80.0

India['centroid_lat'] = pd.Series()

for i in range(len(India)):
    lat = ipmag.lat_from_pole(India_centroid_lon, India_centroid_lat,
                              India['plon'][i], India['plat'][i])
    India['centroid_lat'][i] = lat

# %% [markdown]
# ### Australia

# %% [markdown]
# #### Compilation

# %%
Australia = pd.DataFrame(columns=compilation_cols)

# %%
Leirubakki_Australia = pd.read_csv(pole_path+'Leirubakki-Australia.csv')
Leirubakki_Australia.columns
# Out:
# Index(['Terrane', 'POLENAME', 'SLAT', 'SLON', 'DEC', 'INC', 'PLAT', 'PLON',
#        'DP', 'DM', 'A95', 'f', 'INCf', 'PLATf', 'PLONf', 'DPf', 'DMf', 'A95f',
#        'Grade', 'nominal age', 'lomagage', 'himagage', 'ROCKNAME',
#        'POLE AUTHORS', 'YEAR'],
#       dtype='object')

# %% [markdown]
# Clean up the pole references column:

# %%
Leirubakki_Australia_pole_ref = []

for i in range(len(Leirubakki_Australia)):
    pole_ref = str(Leirubakki_Australia['POLE AUTHORS'][i]) + ' (' + str(Leirubakki_Australia['YEAR'][i]) + ')'
    Leirubakki_Australia_pole_ref.append(pole_ref)

# %% [markdown]
# Assign columns:

# %%
Australia['name'] = Leirubakki_Australia['POLENAME']
Australia['terrane'] = Leirubakki_Australia['Terrane']
Australia['age'] = Leirubakki_Australia['nominal age']
Australia['age upper'] = Leirubakki_Australia['himagage']
Australia['age lower'] = Leirubakki_Australia['lomagage']
Australia['plat'] = Leirubakki_Australia['PLAT']
Australia['plon'] = Leirubakki_Australia['PLON']
Australia['a95'] = Leirubakki_Australia['A95']
#Australia['f']
Australia['slat'] = Leirubakki_Australia['SLAT']
Australia['slon'] = Leirubakki_Australia['SLON']
Australia['dec'] = Leirubakki_Australia['DEC']
Australia['inc'] = Leirubakki_Australia['INC']
#Australia['dir_a95']
Australia['pole ref'] = Leirubakki_Australia_pole_ref
#Australia['age ref']
Australia['grade'] = Leirubakki_Australia['Grade']
#Australia['note']
#Australia['plateID']

# %% [markdown]
# Assign plateIDs:

# %%
# 801 for most poles
Australia['plateID'] = 801

# other poles
Australia.loc[Australia['name']=='Cap Dolomite, Walsh Tillite','plateID'] = 8011
Australia.loc[Australia['name']=='Lower Arumbera and Upper Pertatataka Formations','plateID'] = 8011
Australia.loc[Australia['name']=="Johnny's Creek siltstones",'plateID'] = 8011
Australia.loc[Australia['name']=='Mt.Isa Dolerite Dykes (IAR)','plateID'] = 8011
Australia.loc[Australia['name']=='Alcurra dykes+sills','plateID'] = 8011

# %% [markdown]
# Update age:

# %%
Australia.loc[Australia['name']=='Lancer borehole, Browne Formation','age lower'] = 810
Australia.loc[Australia['name']=='Lancer borehole, Browne Formation','age'] = (900+810)/2

Australia.loc[Australia['name']=="Johnny's Creek siltstones",'age upper'] = 795
Australia.loc[Australia['name']=="Johnny's Creek siltstones",'age'] = ((795+730)/2)-1

# %% [markdown]
# Apply inclination correction (f=0.6) to sedimentary poles:

# %%
Australia.loc[Australia['name']=="Johnny's Creek siltstones",'f'] = 0.6
Australia.loc[Australia['name']=="Johnny's Creek siltstones",'plat'] = -(-7.1)
Australia.loc[Australia['name']=="Johnny's Creek siltstones",'plon'] = 272.6 - 180
Australia.loc[Australia['name']=="Johnny's Creek siltstones",'a95'] = 14.7
Australia.loc[Australia['name']=="Johnny's Creek siltstones",'inc'] = -58.7

Australia.loc[Australia['name']=='Lancer borehole, Browne Formation','f'] = 0.6
Australia.loc[Australia['name']=='Lancer borehole, Browne Formation','plat'] = -(-34.3)
Australia.loc[Australia['name']=='Lancer borehole, Browne Formation','plon'] = 318 - 180
Australia.loc[Australia['name']=='Lancer borehole, Browne Formation','a95'] = 8.4
Australia.loc[Australia['name']=='Lancer borehole, Browne Formation','inc'] = -48.1

# %% [markdown]
# #### Summary

# %%
Australia.sort_values('age', ascending=False, inplace=True)
Australia = Australia[compilation_cols]
Australia.reset_index(inplace=True, drop=True)
Australia
# Out:
#                                                name              terrane  \
# 0                                  Duffer Formation  Australia-W-Pilbara
# 1                        Black Range Dolerite Suite  Australia-W-Pilbara
# 2                  Pilbara Flood Basalts, Package 1  Australia-W-Pilbara
# 3                                  Mount Roe Basalt  Australia-W-Pilbara
# 4                  Pilbara Flood Basalts, Package 2  Australia-W-Pilbara
# 5                              Mount Jope Volcanics  Australia-W-Pilbara
# 6               Pilbara Flood Basalts, Packages 4-7  Australia-W-Pilbara
# 7              Pilbara Flood Basalts, Packages 8-10  Australia-W-Pilbara
# 8                          Widgiemooltha dyke suite  Australia-W-Yilgarn
# 9                              Erayinia mafic dykes  Australia-W-Yilgarn
# 10                                  Frere Formation  Australia-W-Yilgarn
# 11                         Elgee-Pentecost combined          Australia-N
# ...

# %%
Australia.to_csv('../Output/Australia-poles.csv',index=False)
Australia_vpgFeatureCollection = create_vgp_FeatureCollection(Australia)
create_vgp_gpml(Australia_vpgFeatureCollection, '../Output/Australia-poles.gpml')
# Out:
# Palaeomagnetic pole data successfully exported in GPML format.

# %% [markdown]
# #### Paleolatitude

# %%
# 8011 : North Australia
Euler_8011 = [-20.0, 135.0, -40.0]

# %%
Australia['corrected_plon'] = pd.Series()
Australia['corrected_plat'] = pd.Series()

for i in range(len(Australia)):
    if Australia['plateID'][i] == 801:
        Australia['corrected_plat'][i] = Australia['plat'][i]
        Australia['corrected_plon'][i] = Australia['plon'][i]
    elif Australia['plateID'][i] == 8011:
        plat, plon = pmag.pt_rot(Euler_8011, [Australia['plat'][i]], [Australia['plon'][i]])
        Australia['corrected_plat'][i] = plat[0]
        Australia['corrected_plon'][i] = plon[0]

# %%
# calculate age uncertainty as relative to the nominal age
Australia['age upper diff'] = Australia['age upper'] - Australia['age']
Australia['age lower diff'] = Australia['age'] - Australia['age lower']

# calculate implied paleolatitude of centroid point
Australia_centroid_lat = -26.2
Australia_centroid_lon = 131.7

Australia['centroid_lat'] = pd.Series()

for i in range(len(Australia)):
    lat = ipmag.lat_from_pole(Australia_centroid_lon, Australia_centroid_lat,
                              Australia['corrected_plon'][i], Australia['corrected_plat'][i])
    Australia['centroid_lat'][i] = lat

# %% [markdown]
# ### Siberia

# %% [markdown]
# #### Compilation

# %%
Siberia = pd.DataFrame(columns=compilation_cols)

# %%
Leirubakki_Siberia = pd.read_csv(pole_path+'Leirubakki-Siberia.csv')
Leirubakki_Siberia.columns
# Out:
# Index(['Terrane', 'POLENAME', 'SLAT', 'SLON', 'DEC', 'INC', 'PLAT', 'PLON',
#        'DP', 'DM', 'A95', 'f', 'INCf', 'PLATf', 'PLONf', 'DPf', 'DMf', 'A95f',
#        'Grade', 'nominal age', 'lomagage', 'himagage', 'ROCKNAME',
#        'POLE AUTHORS', 'YEAR'],
#       dtype='object')

# %% [markdown]
# Clean up the pole references column:

# %%
Leirubakki_Siberia_pole_ref = []

for i in range(len(Leirubakki_Siberia)):
    pole_ref = str(Leirubakki_Siberia['POLE AUTHORS'][i]) + ' (' + str(Leirubakki_Siberia['YEAR'][i]) + ')'
    Leirubakki_Siberia_pole_ref.append(pole_ref)

# %% [markdown]
# Assign columns:

# %%
Siberia['name'] = Leirubakki_Siberia['POLENAME']
Siberia['terrane'] = Leirubakki_Siberia['Terrane']
Siberia['age'] = Leirubakki_Siberia['nominal age']
Siberia['age upper'] = Leirubakki_Siberia['himagage']
Siberia['age lower'] = Leirubakki_Siberia['lomagage']
Siberia['plat'] = Leirubakki_Siberia['PLAT']
Siberia['plon'] = Leirubakki_Siberia['PLON']
Siberia['a95'] = Leirubakki_Siberia['A95']
#Siberia['f']
Siberia['slat'] = Leirubakki_Siberia['SLAT']
Siberia['slon'] = Leirubakki_Siberia['SLON']
Siberia['dec'] = Leirubakki_Siberia['DEC']
Siberia['inc'] = Leirubakki_Siberia['INC']
#Siberia['dir_a95']
Siberia['pole ref'] = Leirubakki_Siberia_pole_ref
#Siberia['age ref']
Siberia['grade'] = Leirubakki_Siberia['Grade']
#Siberia['note']
#Siberia['plateID'] = 401

# %% [markdown]
# Assign plateIDs:

# %%
# 403 for most poles
Siberia['plateID'] = 403

# other poles
Siberia.loc[Siberia['name']=='Linok Formation','plateID'] = 401
Siberia.loc[Siberia['name']=='Kartochka Formation','plateID'] = 401
Siberia.loc[Siberia['name']=='Kitoi Cryogenian dykes','plateID'] = 401

# %% [markdown]
# #### Summary

# %%
Siberia.sort_values('age', ascending=False, inplace=True)
Siberia = Siberia[compilation_cols]
Siberia.reset_index(inplace=True, drop=True)
Siberia
# Out:
#                                                  name               terrane  \
# 0   Lower Akitkan Khibelen group (Malaya Kosa form...  Siberia-west-Akitkan
# 1                                 Upper Akitkan Group  Siberia-west-Akitkan
# 2                              Shumikhinsk Granitoids   Siberia-west-Tungus
# 3                                   Elgetey Formation    Siberia-east-Aldan
# 4                                       Ulkan granite    Siberia-east-Aldan
# 5                              West Anabar Intrusions          Siberia-west
# 6                                      Kuonamka Dykes          Siberia-west
# 7                             North Anabar Intrusions          Siberia-west
# 8                         Sololi-Kyutingde intrusions          Siberia-west
# 9                                     Linok Formation          Siberia-west
# 10                                Kartochka Formation          Siberia-west
# ...

# %%
Siberia.to_csv('../Output/Siberia-poles.csv',index=False)
Siberia_vpgFeatureCollection = create_vgp_FeatureCollection(Siberia)
create_vgp_gpml(Siberia_vpgFeatureCollection, '../Output/Siberia-poles.gpml')
# Out:
# Palaeomagnetic pole data successfully exported in GPML format.

# %% [markdown]
# #### Paleolatitude

# %%
# 403 : Anabar
Euler_403 = [60.0, 115.0, 25.0]

# %%
Siberia['corrected_plon'] = pd.Series()
Siberia['corrected_plat'] = pd.Series()

for i in range(len(Siberia)):
    if Siberia['plateID'][i] == 401:
        Siberia['corrected_plat'][i] = Siberia['plat'][i]
        Siberia['corrected_plon'][i] = Siberia['plon'][i]
    elif Siberia['plateID'][i] == 403:
        plat, plon = pmag.pt_rot(Euler_403, [Siberia['plat'][i]], [Siberia['plon'][i]])
        Siberia['corrected_plat'][i] = plat[0]
        Siberia['corrected_plon'][i] = plon[0]

# %%
# calculate age uncertainty as relative to the nominal age
Siberia['age upper diff'] = Siberia['age upper'] - Siberia['age']
Siberia['age lower diff'] = Siberia['age'] - Siberia['age lower']

# calculate implied paleolatitude of centroid point
Siberia_centroid_lat = 64.0
Siberia_centroid_lon = 112.0

Siberia['centroid_lat'] = pd.Series()

for i in range(len(Siberia)):
    lat = ipmag.lat_from_pole(Siberia_centroid_lon, Siberia_centroid_lat,
                              Siberia['corrected_plon'][i], Siberia['corrected_plat'][i])
    Siberia['centroid_lat'][i] = lat

# %% [markdown]
# ## Paleolatitude

# %%
Laurentia_Laurentia = Laurentia[Laurentia['terrane']=='Laurentia']
Laurentia_Svalbard = Laurentia[Laurentia['terrane']=='Laurentia-Svalbard']

# %%
fig, ax = plt.subplots(figsize=(10,4))

xlim = [900, 700]

# Laurentia
df_slice = Laurentia_Laurentia[(Laurentia_Laurentia['age']<xlim[0]) & (Laurentia_Laurentia['age']>xlim[1])]
ax.errorbar(df_slice['age'], df_slice['centroid_lat'],
            yerr=df_slice['a95'], xerr=[df_slice['age lower diff'], df_slice['age upper diff']],
            fmt='none', color=Laurentia_color, label='Laurentia')
df_slice = Laurentia_Laurentia[(Laurentia_Laurentia['age']<xlim[0]) & (Laurentia_Laurentia['age']>xlim[1]) & (Laurentia_Laurentia['grade']=='A')]
ax.scatter(df_slice['age'], df_slice['centroid_lat'], color=Laurentia_color, label='__nolegend__', zorder=99)

# Svalbard
df_slice = Laurentia_Svalbard[(Laurentia_Svalbard['age']<xlim[0]) & (Laurentia_Svalbard['age']>xlim[1])]
ax.errorbar(df_slice['age'], df_slice['centroid_lat'],
            yerr=df_slice['a95'], xerr=[df_slice['age lower diff'], df_slice['age upper diff']],
            fmt='none', color=Svalbard_color, label='Laurentia (Svalbard poles)')
df_slice = Laurentia_Svalbard[(Laurentia_Svalbard['age']<xlim[0]) & (Laurentia_Svalbard['age']>xlim[1]) & (Laurentia_Svalbard['grade']=='A')]
ax.scatter(df_slice['age'], df_slice['centroid_lat'], color=Svalbard_color, label='__nolegend__', zorder=99)

# Siberia
df_slice = Siberia[(Siberia['age']<xlim[0]) & (Siberia['age']>xlim[1])]
ax.errorbar(df_slice['age'], df_slice['centroid_lat'],
            yerr=df_slice['a95'], xerr=[df_slice['age lower diff'], df_slice['age upper diff']],
            fmt='none', color=Siberia_color, label='Siberia')
df_slice = Siberia[(Siberia['age']<xlim[0]) & (Siberia['age']>xlim[1]) & (Siberia['grade']=='A')]
ax.scatter(df_slice['age'], df_slice['centroid_lat'], color=Siberia_color, label='__nolegend__', zorder=99)

# Australia
df_slice = Australia[(Australia['age']<xlim[0]) & (Australia['age']>xlim[1])]
ax.errorbar(df_slice['age'], df_slice['centroid_lat'],
            yerr=df_slice['a95'], xerr=[df_slice['age lower diff'], df_slice['age upper diff']],
            fmt='none', color=Australia_color, label='Australia')
df_slice = Australia[(Australia['age']<xlim[0]) & (Australia['age']>xlim[1]) & (Australia['grade']=='A')]
ax.scatter(df_slice['age'], df_slice['centroid_lat'], color=Australia_color, label='__nolegend__', zorder=99)

# India
df_slice = India[(India['age']<xlim[0]) & (India['age']>xlim[1])]
ax.errorbar(df_slice['age'], df_slice['centroid_lat'],
            yerr=df_slice['a95'], xerr=[df_slice['age lower diff'], df_slice['age upper diff']],
            fmt='none', color=India_color, label='India')
df_slice = India[(India['age']<xlim[0]) & (India['age']>xlim[1]) & (India['grade']=='A')]
ax.scatter(df_slice['age'], df_slice['centroid_lat'], color=India_color, label='__nolegend__', zorder=99)

# SChina
df_slice = SChina_site_06[(SChina_site_06['age']<xlim[0]) & (SChina_site_06['age']>xlim[1])]
ax.errorbar(df_slice['age'], df_slice['centroid_lat'],
            yerr=df_slice['a95'], xerr=[df_slice['age lower diff'], df_slice['age upper diff']],
            fmt='none', color=SChina_color, label='South China')

# Liantuo arrow
#df_slice = SChina_site_06[SChina_site_06['name']=='Liantuo Formation - Jing et al. (2021) site mean (f=0.6)']
#ax.errorbar(df_slice['age'], df_slice['centroid_lat'],
#            xerr=np.array([[10],[0]]),
#            fmt='none', color=SChina_color, label='__nolegend__')

# Bitter Springs
rect = patches.Rectangle((795,-90),
                         810-795,
                         180,
                         facecolor='C7',zorder=-999,alpha=0.2)
ax.add_patch(rect)

ax.set_ylim(-30,90)
ax.set_yticks(np.arange(-30,90+30,30))
ax.set_xlim(xlim)
ax.set_ylabel('centroid\npaleolatitude [$^{\circ}$]')
ax.grid(ls='--')
ax.set_xlabel('age [Ma]')
ax.legend(loc='upper left', framealpha=1)

#plt.savefig('../Output/centroid_paleolatitudes.pdf', bbox_inches='tight')
plt.show(fig)

# %% [markdown]
# ## Reconstructions

# %% [markdown]
# ### Monte Carlo

# %%
Svalbard_Euler  = [-31.0588, -10.2454, 203.93]

# %%
ax = ipmag.make_orthographic_map(add_land=False, central_longitude=115, central_latitude=10,
                                 figsize=(7,7), grid_lines=False)

lat_grid = [-80,-60,-30,0,30,60,80]
lon_grid = np.arange(-180,180+60,60)

### CRATONS

cratons_alpha = 0.5

# Svalbard
craton_plot(ax, [311], [Svalbard_Euler], 'k', Svalbard_color, cratons_alpha, 0.5)

# South China
craton_plot(ax, [6024], [[0,0,0]], 'k', SChina_color, cratons_alpha, 0.5)
craton_plot(ax, [6023], [[0,0,0]], 'k', SChina_color, cratons_alpha, 0.5)
craton_plot(ax, [602], [[0,0,0]], 'k', SChina_color, cratons_alpha, 0.5)

### POLES

# Svalbard
rotated_point_plot(ax, LG_UG['pole1_MC_plon'], LG_UG['pole1_MC_plat'], [Svalbard_Euler], 1, '#55a0d4')
rotated_point_plot(ax, LG_UG['pole2_MC_plon'], LG_UG['pole2_MC_plat'], [Svalbard_Euler], 1, '#c0ccd4')

# South China
ipmag.plot_vgp(ax, BX_MY['pole1_MC_plon'], BX_MY['pole1_MC_plat'], color='#008d3c', edge='none', markersize=1)
ipmag.plot_vgp(ax, BX_MY['pole2_MC_plon'], BX_MY['pole2_MC_plat'], color='#99ccaf', edge='none', markersize=1)

ax.gridlines(xlocs=lon_grid, ylocs=lat_grid, linewidth=0.5,
             color='C7', linestyle='dotted', zorder=-1)

#plt.savefig('../Output/TPW_MC_SChina_Svalbard.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Missing Link

# %%
# fixed Eulers
Greenland_Laur_Euler = [67.5,-118.5,-13.8]
Svalbard_Laur_Euler = [-81.0,125.0,68.0]
Siberia_Laur_Euler = [77.0,98.0,137.0]
SChina_India_Euler = [6.7224,77.6921,67.9571]
SAus_Laur_Euler = [-30.2638,-19.1192,-131.7445]
NAus_SAus_Euler = [-20.0,135.0,-40.0]
Antarctica_SAus_Euler = [-3.91,37.9,30.86]
Rayner_India_Euler = [1.8434,-165.1696,-91.8395]

Scotland_Laur_Euler = [78.64,161.9,-32.0]
Amazonia_Laur_Euler = [11.97,-47.01,-110.66]
Parana_Amazonia_Euler = [0.67,103.22,-30.82]
RDLP_Amazonia_Euler = [0.67,103.22,-30.82]
Baltica_Laur_Euler = [75.8,-95.8,-59.2]
NChina_Laur_Euler = [52.9462,27.2366,61.9218]
Kalahari_Laur_Euler = [15.102,-25.2783,-157.5464]

# %%
# time varying Eulers
Laur_Euler_755 = [43.4821,151.0109,-167.5558]
India_Euler_755 = [45.99,93.1407,-10.4661]
TPW_Euler_755 = [-7.6,-178.33,-16.15]

SChina_India_Euler_ML = [-19.7576,14.8061,-29.49]

# %%
ax = ipmag.make_orthographic_map(add_land=False, central_longitude=110, central_latitude=40,
                                 figsize=(8,8), grid_lines=False)

cratons_lw = 0.5
cratons_alpha = 1.0

# Laurentia
craton_plot(ax, [101], [Laur_Euler_755, TPW_Euler_755],
            'k', Laurentia_color, cratons_alpha, cratons_lw)

# Greenland
craton_plot(ax, [102], [Greenland_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Svalbard_color, cratons_alpha, cratons_lw)

# Svalbard
craton_plot(ax, [311], [Svalbard_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Svalbard_color, cratons_alpha, cratons_lw)

# Australia
craton_plot(ax, [801], [SAus_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Australia_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [8011], [NAus_SAus_Euler, SAus_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Australia_color, cratons_alpha, cratons_lw, reverse_draw=True)

# Antarctica
craton_plot(ax, [802], [Antarctica_SAus_Euler, SAus_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Antarctica_color, cratons_alpha, cratons_lw)

# India
craton_plot(ax, [501], [India_Euler_755, TPW_Euler_755],
            'k', India_color, cratons_alpha, cratons_lw)

# Rayner
craton_plot(ax, [803], [Rayner_India_Euler, India_Euler_755, TPW_Euler_755],
            'k', Rayner_color, cratons_alpha, cratons_lw)

# Siberia
craton_plot(ax, [401], [Siberia_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Siberia_color, cratons_alpha, cratons_lw, reverse_draw=True)

# South China
craton_plot(ax, [6024], [SChina_India_Euler_ML, India_Euler_755, TPW_Euler_755],
            'k', SChina_color, cratons_alpha, cratons_lw)
craton_plot(ax, [6023], [SChina_India_Euler_ML, India_Euler_755, TPW_Euler_755],
            'k', SChina_color, cratons_alpha, cratons_lw)
craton_plot(ax, [602], [SChina_India_Euler_ML, India_Euler_755, TPW_Euler_755],
            'k', SChina_color, cratons_alpha, cratons_lw)

# etcetera blocks
craton_plot(ax, [303], [Scotland_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [201], [Amazonia_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [202], [Parana_Amazonia_Euler, Amazonia_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [203], [RDLP_Amazonia_Euler, Amazonia_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [302], [Baltica_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [601], [NChina_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [7011], [Kalahari_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)

### POLES

poles_alpha = 0.75

# Australia
df_slice = Australia[Australia['name']=='Mundine Well Dykes Combined']
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [SAus_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
                  'o', 20, 'C7', Australia_color, poles_alpha)

# India
df_slice = India[India['name']=='Malani Igneous Suite -Comb']
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [India_Euler_755, TPW_Euler_755],
                  'o', 20, 'C7', India_color, poles_alpha)

# Siberia
df_slice = Siberia[Siberia['name']=='Kitoi Cryogenian dykes']
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [Siberia_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
                  'o', 20, 'C7', Siberia_color, poles_alpha)

# Laurentia
df_slice = Laurentia[Laurentia['name']=='Gunbarrel dykes']
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [Laur_Euler_755, TPW_Euler_755],
                  'o', 20, 'C7', Laurentia_color, 0.2)

df_slice = Laurentia[Laurentia['name']=='Carbon Canyon']
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [Laur_Euler_755, TPW_Euler_755],
                  'o', 20, 'C7', Laurentia_color, poles_alpha)

# South China
df_slice = SChina_site_06[SChina_site_06['name']=='Liantuo Formation - Jing et al. (2021) site mean (f=0.6)']
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [SChina_India_Euler_ML, India_Euler_755, TPW_Euler_755],
                  'o', 20, 'C7', SChina_color, poles_alpha)
df_slice = SChina_site_06[SChina_site_06['name']=='Liantuo Formation - site mean (f=0.6)']
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [SChina_India_Euler_ML, India_Euler_755, TPW_Euler_755],
                  'o', 20, 'C7', SChina_color, poles_alpha)
#df_slice = SChina_site_06[SChina_site_06['name']=='Banxi Group - site mean (f=0.6)']
#rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
#                  [SChina_India_Euler, India_Euler_755, TPW_Euler_755],
#                  'o', 20, 'C7', SChina_color, 0.2)

ax.gridlines(xlocs=lon_grid, ylocs=lat_grid, linewidth=0.5,
             color='C7', linestyle='dotted', zorder=-1)

#plt.savefig('../Output/Missing_Link_model.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Periphery

# %%
# time varying Eulers
Laur_Euler_755 = [43.4821,151.0109,-167.5558]
India_Euler_755 = [45.99,93.1407,-10.4661]
TPW_Euler_755 = [-7.6,-178.33,-16.15]

# %%
ax = ipmag.make_orthographic_map(add_land=False, central_longitude=110, central_latitude=40,
                                 figsize=(8,8), grid_lines=False)

cratons_lw = 0.5
cratons_alpha = 1.0

# Laurentia
craton_plot(ax, [101], [Laur_Euler_755, TPW_Euler_755],
            'k', Laurentia_color, cratons_alpha, cratons_lw)

# Greenland
craton_plot(ax, [102], [Greenland_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Svalbard_color, cratons_alpha, cratons_lw)

# Svalbard
craton_plot(ax, [311], [Svalbard_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Svalbard_color, cratons_alpha, cratons_lw)

# Australia
craton_plot(ax, [801], [SAus_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Australia_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [8011], [NAus_SAus_Euler, SAus_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Australia_color, cratons_alpha, cratons_lw, reverse_draw=True)

# Antarctica
craton_plot(ax, [802], [Antarctica_SAus_Euler, SAus_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Antarctica_color, cratons_alpha, cratons_lw)

# India
craton_plot(ax, [501], [India_Euler_755, TPW_Euler_755],
            'k', India_color, cratons_alpha, cratons_lw)

# Rayner
craton_plot(ax, [803], [Rayner_India_Euler, India_Euler_755, TPW_Euler_755],
            'k', Rayner_color, cratons_alpha, cratons_lw)

# Siberia
craton_plot(ax, [401], [Siberia_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Siberia_color, cratons_alpha, cratons_lw, reverse_draw=True)

# South China
craton_plot(ax, [6024], [SChina_India_Euler, India_Euler_755, TPW_Euler_755],
            'k', SChina_color, cratons_alpha, cratons_lw)
craton_plot(ax, [6023], [SChina_India_Euler, India_Euler_755, TPW_Euler_755],
            'k', SChina_color, cratons_alpha, cratons_lw)
craton_plot(ax, [602], [SChina_India_Euler, India_Euler_755, TPW_Euler_755],
            'k', SChina_color, cratons_alpha, cratons_lw)

# etcetera blocks
craton_plot(ax, [303], [Scotland_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [201], [Amazonia_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [202], [Parana_Amazonia_Euler, Amazonia_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [203], [RDLP_Amazonia_Euler, Amazonia_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [302], [Baltica_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [601], [NChina_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [7011], [Kalahari_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)

### POLES

poles_alpha = 0.75

# Australia
df_slice = Australia[Australia['name']=='Mundine Well Dykes Combined']
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [SAus_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
                  'o', 20, 'C7', Australia_color, poles_alpha)

# India
df_slice = India[India['name']=='Malani Igneous Suite -Comb']
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [India_Euler_755, TPW_Euler_755],
                  'o', 20, 'C7', India_color, poles_alpha)

# Siberia
df_slice = Siberia[Siberia['name']=='Kitoi Cryogenian dykes']
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [Siberia_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
                  'o', 20, 'C7', Siberia_color, poles_alpha)

# Laurentia
df_slice = Laurentia[Laurentia['name']=='Gunbarrel dykes']
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [Laur_Euler_755, TPW_Euler_755],
                  'o', 20, 'C7', Laurentia_color, 0.2)

df_slice = Laurentia[Laurentia['name']=='Carbon Canyon']
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [Laur_Euler_755, TPW_Euler_755],
                  'o', 20, 'C7', Laurentia_color, poles_alpha)

# South China
df_slice = SChina_site_06[SChina_site_06['name']=='Liantuo Formation - Jing et al. (2021) site mean (f=0.6)']
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [SChina_India_Euler, India_Euler_755, TPW_Euler_755],
                  'o', 20, 'C7', SChina_color, poles_alpha)
df_slice = SChina_site_06[SChina_site_06['name']=='Liantuo Formation - site mean (f=0.6)']
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [SChina_India_Euler, India_Euler_755, TPW_Euler_755],
                  'o', 20, 'C7', SChina_color, poles_alpha)
df_slice = SChina_site_06[SChina_site_06['name']=='Banxi Group - site mean (f=0.6)']
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [SChina_India_Euler, India_Euler_755, TPW_Euler_755],
                  'o', 20, 'C7', SChina_color, 0.2)

ax.gridlines(xlocs=lon_grid, ylocs=lat_grid, linewidth=0.5,
             color='C7', linestyle='dotted', zorder=-1)

#plt.savefig('../Output/periphery_model.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Separate

# %%
# time varying Eulers
Laur_Euler_755 = [43.4821,151.0109,-167.5558]
India_Euler_755 = [65.4126,103.9231,-29.3572]
TPW_Euler_755 = [-7.6,-178.33,-16.15]

# %%
ax = ipmag.make_orthographic_map(add_land=False, central_longitude=110, central_latitude=40,
                                 figsize=(8,8), grid_lines=False)

cratons_lw = 0.5
cratons_alpha = 1.0

# Laurentia
craton_plot(ax, [101], [Laur_Euler_755, TPW_Euler_755],
            'k', Laurentia_color, cratons_alpha, cratons_lw)

# Greenland
craton_plot(ax, [102], [Greenland_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Svalbard_color, cratons_alpha, cratons_lw)

# Svalbard
craton_plot(ax, [311], [Svalbard_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Svalbard_color, cratons_alpha, cratons_lw)

# Australia
craton_plot(ax, [801], [SAus_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Australia_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [8011], [NAus_SAus_Euler, SAus_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Australia_color, cratons_alpha, cratons_lw, reverse_draw=True)

# Antarctica
craton_plot(ax, [802], [Antarctica_SAus_Euler, SAus_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Antarctica_color, cratons_alpha, cratons_lw)

# India
craton_plot(ax, [501], [India_Euler_755, TPW_Euler_755],
            'k', India_color, cratons_alpha, cratons_lw)

# Rayner
craton_plot(ax, [803], [Rayner_India_Euler, India_Euler_755, TPW_Euler_755],
            'k', Rayner_color, cratons_alpha, cratons_lw)

# Siberia
craton_plot(ax, [401], [Siberia_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Siberia_color, cratons_alpha, cratons_lw, reverse_draw=True)

# South China
craton_plot(ax, [6024], [SChina_India_Euler, India_Euler_755, TPW_Euler_755],
            'k', SChina_color, cratons_alpha, cratons_lw)
craton_plot(ax, [6023], [SChina_India_Euler, India_Euler_755, TPW_Euler_755],
            'k', SChina_color, cratons_alpha, cratons_lw)
craton_plot(ax, [602], [SChina_India_Euler, India_Euler_755, TPW_Euler_755],
            'k', SChina_color, cratons_alpha, cratons_lw)

# etcetera blocks
craton_plot(ax, [303], [Scotland_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [201], [Amazonia_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [202], [Parana_Amazonia_Euler, Amazonia_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [203], [RDLP_Amazonia_Euler, Amazonia_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [302], [Baltica_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [601], [NChina_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [7011], [Kalahari_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)

### POLES

poles_alpha = 0.75

# Australia
df_slice = Australia[Australia['name']=='Mundine Well Dykes Combined']
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [SAus_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
                  'o', 20, 'C7', Australia_color, poles_alpha)

# India
df_slice = India[India['name']=='Malani Igneous Suite -Comb']
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [India_Euler_755, TPW_Euler_755],
                  'o', 20, 'C7', India_color, poles_alpha)

# Siberia
df_slice = Siberia[Siberia['name']=='Kitoi Cryogenian dykes']
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [Siberia_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
                  'o', 20, 'C7', Siberia_color, poles_alpha)

# Laurentia
df_slice = Laurentia[Laurentia['name']=='Gunbarrel dykes']
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [Laur_Euler_755, TPW_Euler_755],
                  'o', 20, 'C7', Laurentia_color, 0.2)

df_slice = Laurentia[Laurentia['name']=='Carbon Canyon']
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [Laur_Euler_755, TPW_Euler_755],
                  'o', 20, 'C7', Laurentia_color, poles_alpha)

# South China
df_slice = SChina_site_06[SChina_site_06['name']=='Liantuo Formation - Jing et al. (2021) site mean (f=0.6)']
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [SChina_India_Euler, India_Euler_755, TPW_Euler_755],
                  'o', 20, 'C7', SChina_color, poles_alpha)
df_slice = SChina_site_06[SChina_site_06['name']=='Liantuo Formation - site mean (f=0.6)']
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [SChina_India_Euler, India_Euler_755, TPW_Euler_755],
                  'o', 20, 'C7', SChina_color, poles_alpha)
df_slice = SChina_site_06[SChina_site_06['name']=='Banxi Group - site mean (f=0.6)']
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [SChina_India_Euler, India_Euler_755, TPW_Euler_755],
                  'o', 20, 'C7', SChina_color, 0.2)

ax.gridlines(xlocs=lon_grid, ylocs=lat_grid, linewidth=0.5,
             color='C7', linestyle='dotted', zorder=-1)

#plt.savefig('../Output/separate_model.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### TPW

# %% [markdown]
# #### APWP

# %%
# time varying Eulers
Laur_Euler_813 = [57.7447,147.6911,-175.862]
India_Euler_813 = [22.7984,126.729,-57.8883]
TPW_Euler_813 = [90.0,0.0,0.0]

# %%
ax = ipmag.make_orthographic_map(add_land=False, central_longitude=110, central_latitude=40,
                                 figsize=(8,8), grid_lines=False)

cratons_lw = 0.5
cratons_alpha = 1.0

# Laurentia
craton_plot(ax, [101], [Laur_Euler_813, TPW_Euler_813],
            'k', Laurentia_color, cratons_alpha, cratons_lw)

# Greenland
craton_plot(ax, [102], [Greenland_Laur_Euler, Laur_Euler_813, TPW_Euler_813],
            'k', Svalbard_color, cratons_alpha, cratons_lw)

# Svalbard
craton_plot(ax, [311], [Svalbard_Laur_Euler, Laur_Euler_813, TPW_Euler_813],
            'k', Svalbard_color, cratons_alpha, cratons_lw)

# Australia
craton_plot(ax, [801], [SAus_Laur_Euler, Laur_Euler_813, TPW_Euler_813],
            'k', Australia_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [8011], [NAus_SAus_Euler, SAus_Laur_Euler, Laur_Euler_813, TPW_Euler_813],
            'k', Australia_color, cratons_alpha, cratons_lw, reverse_draw=True)

# Antarctica
craton_plot(ax, [802], [Antarctica_SAus_Euler, SAus_Laur_Euler, Laur_Euler_813, TPW_Euler_813],
            'k', Antarctica_color, cratons_alpha, cratons_lw)

# India
craton_plot(ax, [501], [India_Euler_813, TPW_Euler_813],
            'k', India_color, cratons_alpha, cratons_lw)

# Rayner
craton_plot(ax, [803], [Rayner_India_Euler, India_Euler_813, TPW_Euler_813],
            'k', Rayner_color, cratons_alpha, cratons_lw)

# Siberia
craton_plot(ax, [401], [Siberia_Laur_Euler, Laur_Euler_813, TPW_Euler_813],
            'k', Siberia_color, cratons_alpha, cratons_lw, reverse_draw=True)

# South China
craton_plot(ax, [6024], [SChina_India_Euler, India_Euler_813, TPW_Euler_813],
            'k', SChina_color, cratons_alpha, cratons_lw)
craton_plot(ax, [6023], [SChina_India_Euler, India_Euler_813, TPW_Euler_813],
            'k', SChina_color, cratons_alpha, cratons_lw)
craton_plot(ax, [602], [SChina_India_Euler, India_Euler_813, TPW_Euler_813],
            'k', SChina_color, cratons_alpha, cratons_lw)

# etcetera blocks
craton_plot(ax, [303], [Scotland_Laur_Euler, Laur_Euler_813, TPW_Euler_813],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [201], [Amazonia_Laur_Euler, Laur_Euler_813, TPW_Euler_813],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [202], [Parana_Amazonia_Euler, Amazonia_Laur_Euler, Laur_Euler_813, TPW_Euler_813],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [203], [RDLP_Amazonia_Euler, Amazonia_Laur_Euler, Laur_Euler_813, TPW_Euler_813],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [302], [Baltica_Laur_Euler, Laur_Euler_813, TPW_Euler_813],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [601], [NChina_Laur_Euler, Laur_Euler_813, TPW_Euler_813],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [7011], [Kalahari_Laur_Euler, Laur_Euler_813, TPW_Euler_813],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)

### POLES

poles_alpha = 0.5
poles_markersize = 70

color_mapping = plt.cm.ScalarMappable(cmap='viridis',
                                      norm=plt.Normalize(vmin=755, vmax=821))

# some South China
SChina_pole_colors = color_mapping.to_rgba(SChina_site_06['age'].tolist()).tolist()
for i in range(len(SChina_site_06)):
    rotated_pole_plot(ax, SChina_site_06['plon'][i], SChina_site_06['plat'][i], SChina_site_06['a95'][i],
                      [SChina_India_Euler, India_Euler_813, TPW_Euler_813],
                      'o', poles_markersize, SChina_pole_colors[i], SChina_color, poles_alpha)
    
# Svalbard
Laurentia_Svalbard = Laurentia[Laurentia['plateID']==311].copy()
Laurentia_Svalbard.reset_index(drop=True, inplace=True)
Laurentia_Svalbard_pole_colors = color_mapping.to_rgba([815,800,780]).tolist()
for i in range(len(Laurentia_Svalbard)):
    rotated_pole_plot(ax, Laurentia_Svalbard['plon'][i], Laurentia_Svalbard['plat'][i], Laurentia_Svalbard['a95'][i],
                      [Svalbard_Laur_Euler, Laur_Euler_813, TPW_Euler_813],
                      '^', poles_markersize, Laurentia_Svalbard_pole_colors[i], Svalbard_color, poles_alpha)
    
# great circles
plt.plot([58, 60], [72, 90], color='k', linewidth=3, transform=ccrs.Geodetic())
plt.plot([45, 60], [53, 90], color='r', linewidth=3, transform=ccrs.Geodetic())
plt.plot([45, 184], [53, 65], color='r', linewidth=3, transform=ccrs.Geodetic())

ax.gridlines(xlocs=lon_grid, ylocs=lat_grid, linewidth=0.5,
             color='C7', linestyle='dotted', zorder=-1)

color_mapping._A = []
cbar = plt.colorbar(color_mapping, orientation='horizontal', shrink=0.8,
                    pad=0.05, label='age [Ma]')
cbar.ax.invert_xaxis()

#plt.savefig('../Output/TPW_model.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# #### 821

# %%
# time varying Eulers
Laur_Euler_821 = [57.7447,147.6911,-175.862]
India_Euler_821 = [21.5338,130.446,-67.842]
TPW_Euler_821 = [90.0,0.0,0.0]

# %%
ax = ipmag.make_orthographic_map(add_land=False, central_longitude=110, central_latitude=40,
                                 figsize=(8,8), grid_lines=False)

cratons_lw = 0.5
cratons_alpha = 1.0

# Laurentia
craton_plot(ax, [101], [Laur_Euler_821, TPW_Euler_821],
            'k', Laurentia_color, cratons_alpha, cratons_lw)

# Greenland
craton_plot(ax, [102], [Greenland_Laur_Euler, Laur_Euler_821, TPW_Euler_821],
            'k', Svalbard_color, cratons_alpha, cratons_lw)

# Svalbard
craton_plot(ax, [311], [Svalbard_Laur_Euler, Laur_Euler_821, TPW_Euler_821],
            'k', Svalbard_color, cratons_alpha, cratons_lw)

# Australia
craton_plot(ax, [801], [SAus_Laur_Euler, Laur_Euler_821, TPW_Euler_821],
            'k', Australia_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [8011], [NAus_SAus_Euler, SAus_Laur_Euler, Laur_Euler_821, TPW_Euler_821],
            'k', Australia_color, cratons_alpha, cratons_lw, reverse_draw=True)

# Antarctica
craton_plot(ax, [802], [Antarctica_SAus_Euler, SAus_Laur_Euler, Laur_Euler_821, TPW_Euler_821],
            'k', Antarctica_color, cratons_alpha, cratons_lw)

# India
craton_plot(ax, [501], [India_Euler_821, TPW_Euler_821],
            'k', India_color, cratons_alpha, cratons_lw)

# Rayner
craton_plot(ax, [803], [Rayner_India_Euler, India_Euler_821, TPW_Euler_821],
            'k', Rayner_color, cratons_alpha, cratons_lw)

# Siberia
craton_plot(ax, [401], [Siberia_Laur_Euler, Laur_Euler_821, TPW_Euler_821],
            'k', Siberia_color, cratons_alpha, cratons_lw, reverse_draw=True)

# South China
craton_plot(ax, [6024], [SChina_India_Euler, India_Euler_821, TPW_Euler_821],
            'k', SChina_color, cratons_alpha, cratons_lw)
craton_plot(ax, [6023], [SChina_India_Euler, India_Euler_821, TPW_Euler_821],
            'k', SChina_color, cratons_alpha, cratons_lw)
craton_plot(ax, [602], [SChina_India_Euler, India_Euler_821, TPW_Euler_821],
            'k', SChina_color, cratons_alpha, cratons_lw)

# etcetera blocks
craton_plot(ax, [303], [Scotland_Laur_Euler, Laur_Euler_821, TPW_Euler_821],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [201], [Amazonia_Laur_Euler, Laur_Euler_821, TPW_Euler_821],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [202], [Parana_Amazonia_Euler, Amazonia_Laur_Euler, Laur_Euler_821, TPW_Euler_821],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [203], [RDLP_Amazonia_Euler, Amazonia_Laur_Euler, Laur_Euler_821, TPW_Euler_821],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [302], [Baltica_Laur_Euler, Laur_Euler_821, TPW_Euler_821],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [601], [NChina_Laur_Euler, Laur_Euler_821, TPW_Euler_821],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [7011], [Kalahari_Laur_Euler, Laur_Euler_821, TPW_Euler_821],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)

### POLES

poles_alpha = 0.5
poles_markersize = 70

# South China
pole_color = color_mapping.to_rgba([821]).tolist()
df_slice = SChina_site_06[SChina_site_06['name']=='Xiaofeng Dikes - Jing et al. (2019)']
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [SChina_India_Euler, India_Euler_821, TPW_Euler_821],
                  'o', poles_markersize, pole_color, SChina_color, poles_alpha)

ax.gridlines(xlocs=lon_grid, ylocs=lat_grid, linewidth=0.5,
             color='C7', linestyle='dotted', zorder=-1)

#plt.savefig('../Output/TPW_model_821.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# #### 813

# %%
# time varying Eulers
Laur_Euler_813 = [57.7447,147.6911,-175.862]
India_Euler_813 = [23.0032,126.096,-56.4853]
TPW_Euler_813 = [90.0,0.0,0.0]

# %%
ax = ipmag.make_orthographic_map(add_land=False, central_longitude=110, central_latitude=40,
                                 figsize=(8,8), grid_lines=False)

cratons_lw = 0.5
cratons_alpha = 1.0

# Laurentia
craton_plot(ax, [101], [Laur_Euler_813, TPW_Euler_813],
            'k', Laurentia_color, cratons_alpha, cratons_lw)

# Greenland
craton_plot(ax, [102], [Greenland_Laur_Euler, Laur_Euler_813, TPW_Euler_813],
            'k', Svalbard_color, cratons_alpha, cratons_lw)

# Svalbard
craton_plot(ax, [311], [Svalbard_Laur_Euler, Laur_Euler_813, TPW_Euler_813],
            'k', Svalbard_color, cratons_alpha, cratons_lw)

# Australia
craton_plot(ax, [801], [SAus_Laur_Euler, Laur_Euler_813, TPW_Euler_813],
            'k', Australia_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [8011], [NAus_SAus_Euler, SAus_Laur_Euler, Laur_Euler_813, TPW_Euler_813],
            'k', Australia_color, cratons_alpha, cratons_lw, reverse_draw=True)

# Antarctica
craton_plot(ax, [802], [Antarctica_SAus_Euler, SAus_Laur_Euler, Laur_Euler_813, TPW_Euler_813],
            'k', Antarctica_color, cratons_alpha, cratons_lw)

# India
craton_plot(ax, [501], [India_Euler_813, TPW_Euler_813],
            'k', India_color, cratons_alpha, cratons_lw)

# Rayner
craton_plot(ax, [803], [Rayner_India_Euler, India_Euler_813, TPW_Euler_813],
            'k', Rayner_color, cratons_alpha, cratons_lw)

# Siberia
craton_plot(ax, [401], [Siberia_Laur_Euler, Laur_Euler_813, TPW_Euler_813],
            'k', Siberia_color, cratons_alpha, cratons_lw, reverse_draw=True)

# South China
craton_plot(ax, [6024], [SChina_India_Euler, India_Euler_813, TPW_Euler_813],
            'k', SChina_color, cratons_alpha, cratons_lw)
craton_plot(ax, [6023], [SChina_India_Euler, India_Euler_813, TPW_Euler_813],
            'k', SChina_color, cratons_alpha, cratons_lw)
craton_plot(ax, [602], [SChina_India_Euler, India_Euler_813, TPW_Euler_813],
            'k', SChina_color, cratons_alpha, cratons_lw)

# etcetera blocks
craton_plot(ax, [303], [Scotland_Laur_Euler, Laur_Euler_813, TPW_Euler_813],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [201], [Amazonia_Laur_Euler, Laur_Euler_813, TPW_Euler_813],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [202], [Parana_Amazonia_Euler, Amazonia_Laur_Euler, Laur_Euler_813, TPW_Euler_813],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [203], [RDLP_Amazonia_Euler, Amazonia_Laur_Euler, Laur_Euler_813, TPW_Euler_813],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [302], [Baltica_Laur_Euler, Laur_Euler_813, TPW_Euler_813],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [601], [NChina_Laur_Euler, Laur_Euler_813, TPW_Euler_813],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [7011], [Kalahari_Laur_Euler, Laur_Euler_813, TPW_Euler_813],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)

### POLES

# South China
pole_color = color_mapping.to_rgba([813]).tolist()
df_slice = SChina_site_06[SChina_site_06['name']=='Banxi Group - site mean (f=0.6)']
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [SChina_India_Euler, India_Euler_813, TPW_Euler_813],
                  'o', poles_markersize, pole_color, SChina_color, poles_alpha)

ax.gridlines(xlocs=lon_grid, ylocs=lat_grid, linewidth=0.5,
             color='C7', linestyle='dotted', zorder=-1)

#plt.savefig('../Output/TPW_model_813.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# #### 811

# %%
# time varying Eulers
Laur_Euler_811 = [57.7447,147.6911,-175.862]
India_Euler_811 = [23.4335,124.732,-53.6971]
TPW_Euler_811 = [90.0,0.0,0.0]

# %%
ax = ipmag.make_orthographic_map(add_land=False, central_longitude=110, central_latitude=40,
                                 figsize=(8,8), grid_lines=False)

cratons_lw = 0.5
cratons_alpha = 1.0

# Laurentia
craton_plot(ax, [101], [Laur_Euler_811, TPW_Euler_811],
            'k', Laurentia_color, cratons_alpha, cratons_lw)

# Greenland
craton_plot(ax, [102], [Greenland_Laur_Euler, Laur_Euler_811, TPW_Euler_811],
            'k', Svalbard_color, cratons_alpha, cratons_lw)

# Svalbard
craton_plot(ax, [311], [Svalbard_Laur_Euler, Laur_Euler_811, TPW_Euler_811],
            'k', Svalbard_color, cratons_alpha, cratons_lw)

# Australia
craton_plot(ax, [801], [SAus_Laur_Euler, Laur_Euler_811, TPW_Euler_811],
            'k', Australia_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [8011], [NAus_SAus_Euler, SAus_Laur_Euler, Laur_Euler_811, TPW_Euler_811],
            'k', Australia_color, cratons_alpha, cratons_lw, reverse_draw=True)

# Antarctica
craton_plot(ax, [802], [Antarctica_SAus_Euler, SAus_Laur_Euler, Laur_Euler_811, TPW_Euler_811],
            'k', Antarctica_color, cratons_alpha, cratons_lw)

# India
craton_plot(ax, [501], [India_Euler_811, TPW_Euler_811],
            'k', India_color, cratons_alpha, cratons_lw)

# Rayner
craton_plot(ax, [803], [Rayner_India_Euler, India_Euler_811, TPW_Euler_811],
            'k', Rayner_color, cratons_alpha, cratons_lw)

# Siberia
craton_plot(ax, [401], [Siberia_Laur_Euler, Laur_Euler_811, TPW_Euler_811],
            'k', Siberia_color, cratons_alpha, cratons_lw, reverse_draw=True)

# South China
craton_plot(ax, [6024], [SChina_India_Euler, India_Euler_811, TPW_Euler_811],
            'k', SChina_color, cratons_alpha, cratons_lw)
craton_plot(ax, [6023], [SChina_India_Euler, India_Euler_811, TPW_Euler_811],
            'k', SChina_color, cratons_alpha, cratons_lw)
craton_plot(ax, [602], [SChina_India_Euler, India_Euler_811, TPW_Euler_811],
            'k', SChina_color, cratons_alpha, cratons_lw)

# etcetera blocks
craton_plot(ax, [303], [Scotland_Laur_Euler, Laur_Euler_811, TPW_Euler_811],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [201], [Amazonia_Laur_Euler, Laur_Euler_811, TPW_Euler_811],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [202], [Parana_Amazonia_Euler, Amazonia_Laur_Euler, Laur_Euler_811, TPW_Euler_811],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [203], [RDLP_Amazonia_Euler, Amazonia_Laur_Euler, Laur_Euler_811, TPW_Euler_811],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [302], [Baltica_Laur_Euler, Laur_Euler_811, TPW_Euler_811],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [601], [NChina_Laur_Euler, Laur_Euler_811, TPW_Euler_811],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [7011], [Kalahari_Laur_Euler, Laur_Euler_811, TPW_Euler_811],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)

### POLES

poles_alpha = 0.5
poles_markersize = 70

# Svalbard
pole_color = color_mapping.to_rgba([811]).tolist()
df_slice = Laurentia[Laurentia['name']=='Lower Grusdievbreen Formation']
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [Svalbard_Laur_Euler, Laur_Euler_811, TPW_Euler_811],
                  'o', poles_markersize, pole_color, Svalbard_color, poles_alpha)

ax.gridlines(xlocs=lon_grid, ylocs=lat_grid, linewidth=0.5,
             color='C7', linestyle='dotted', zorder=-1)

#plt.savefig('../Output/TPW_model_811.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# #### 809

# %%
# time varying Eulers
Laur_Euler_809 = [57.7447,147.6911,-175.862]
India_Euler_809 = [23.8932,123.222,-50.9361]
TPW_Euler_809 = [-0.57,133.44,-36.55]

# %%
ax = ipmag.make_orthographic_map(add_land=False, central_longitude=110, central_latitude=40,
                                 figsize=(8,8), grid_lines=False)

cratons_lw = 0.5
cratons_alpha = 1.0

# Laurentia
craton_plot(ax, [101], [Laur_Euler_809, TPW_Euler_809],
            'k', Laurentia_color, cratons_alpha, cratons_lw)

# Greenland
craton_plot(ax, [102], [Greenland_Laur_Euler, Laur_Euler_809, TPW_Euler_809],
            'k', Svalbard_color, cratons_alpha, cratons_lw)

# Svalbard
craton_plot(ax, [311], [Svalbard_Laur_Euler, Laur_Euler_809, TPW_Euler_809],
            'k', Svalbard_color, cratons_alpha, cratons_lw)

# Australia
craton_plot(ax, [801], [SAus_Laur_Euler, Laur_Euler_809, TPW_Euler_809],
            'k', Australia_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [8011], [NAus_SAus_Euler, SAus_Laur_Euler, Laur_Euler_809, TPW_Euler_809],
            'k', Australia_color, cratons_alpha, cratons_lw, reverse_draw=True)

# Antarctica
craton_plot(ax, [802], [Antarctica_SAus_Euler, SAus_Laur_Euler, Laur_Euler_809, TPW_Euler_809],
            'k', Antarctica_color, cratons_alpha, cratons_lw)

# India
craton_plot(ax, [501], [India_Euler_809, TPW_Euler_809],
            'k', India_color, cratons_alpha, cratons_lw)

# Rayner
craton_plot(ax, [803], [Rayner_India_Euler, India_Euler_809, TPW_Euler_809],
            'k', Rayner_color, cratons_alpha, cratons_lw)

# Siberia
craton_plot(ax, [401], [Siberia_Laur_Euler, Laur_Euler_809, TPW_Euler_809],
            'k', Siberia_color, cratons_alpha, cratons_lw, reverse_draw=True)

# South China
craton_plot(ax, [6024], [SChina_India_Euler, India_Euler_809, TPW_Euler_809],
            'k', SChina_color, cratons_alpha, cratons_lw)
craton_plot(ax, [6023], [SChina_India_Euler, India_Euler_809, TPW_Euler_809],
            'k', SChina_color, cratons_alpha, cratons_lw)
craton_plot(ax, [602], [SChina_India_Euler, India_Euler_809, TPW_Euler_809],
            'k', SChina_color, cratons_alpha, cratons_lw)

# etcetera blocks
craton_plot(ax, [303], [Scotland_Laur_Euler, Laur_Euler_809, TPW_Euler_809],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [201], [Amazonia_Laur_Euler, Laur_Euler_809, TPW_Euler_809],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [202], [Parana_Amazonia_Euler, Amazonia_Laur_Euler, Laur_Euler_809, TPW_Euler_809],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [203], [RDLP_Amazonia_Euler, Amazonia_Laur_Euler, Laur_Euler_809, TPW_Euler_809],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [302], [Baltica_Laur_Euler, Laur_Euler_809, TPW_Euler_809],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [601], [NChina_Laur_Euler, Laur_Euler_809, TPW_Euler_809],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [7011], [Kalahari_Laur_Euler, Laur_Euler_809, TPW_Euler_809],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)

### POLES

poles_alpha = 0.5
poles_markersize = 70

# Svalbard
pole_color = color_mapping.to_rgba([809]).tolist()
df_slice = Laurentia[Laurentia['name']=='Upper Grusdievbreen Formation']
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [Svalbard_Laur_Euler, Laur_Euler_809, TPW_Euler_809],
                  'o', poles_markersize, pole_color, Svalbard_color, poles_alpha)

ax.gridlines(xlocs=lon_grid, ylocs=lat_grid, linewidth=0.5,
             color='C7', linestyle='dotted', zorder=-1)

#plt.savefig('../Output/TPW_model_809.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# #### 805

# %%
# time varying Eulers
Laur_Euler_805 = [57.7447,147.6911,-175.862]
India_Euler_805 = [24.9082,119.652,-45.5154]
TPW_Euler_805 = [-0.57,133.44,-36.55]

# %%
ax = ipmag.make_orthographic_map(add_land=False, central_longitude=110, central_latitude=40,
                                 figsize=(8,8), grid_lines=False)

cratons_lw = 0.5
cratons_alpha = 1.0

# Laurentia
craton_plot(ax, [101], [Laur_Euler_805, TPW_Euler_805],
            'k', Laurentia_color, cratons_alpha, cratons_lw)

# Greenland
craton_plot(ax, [102], [Greenland_Laur_Euler, Laur_Euler_805, TPW_Euler_805],
            'k', Svalbard_color, cratons_alpha, cratons_lw)

# Svalbard
craton_plot(ax, [311], [Svalbard_Laur_Euler, Laur_Euler_805, TPW_Euler_805],
            'k', Svalbard_color, cratons_alpha, cratons_lw)

# Australia
craton_plot(ax, [801], [SAus_Laur_Euler, Laur_Euler_805, TPW_Euler_805],
            'k', Australia_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [8011], [NAus_SAus_Euler, SAus_Laur_Euler, Laur_Euler_805, TPW_Euler_805],
            'k', Australia_color, cratons_alpha, cratons_lw, reverse_draw=True)

# Antarctica
craton_plot(ax, [802], [Antarctica_SAus_Euler, SAus_Laur_Euler, Laur_Euler_805, TPW_Euler_805],
            'k', Antarctica_color, cratons_alpha, cratons_lw)

# India
craton_plot(ax, [501], [India_Euler_805, TPW_Euler_805],
            'k', India_color, cratons_alpha, cratons_lw)

# Rayner
craton_plot(ax, [803], [Rayner_India_Euler, India_Euler_805, TPW_Euler_805],
            'k', Rayner_color, cratons_alpha, cratons_lw)

# Siberia
craton_plot(ax, [401], [Siberia_Laur_Euler, Laur_Euler_805, TPW_Euler_805],
            'k', Siberia_color, cratons_alpha, cratons_lw, reverse_draw=True)

# South China
craton_plot(ax, [6024], [SChina_India_Euler, India_Euler_805, TPW_Euler_805],
            'k', SChina_color, cratons_alpha, cratons_lw)
craton_plot(ax, [6023], [SChina_India_Euler, India_Euler_805, TPW_Euler_805],
            'k', SChina_color, cratons_alpha, cratons_lw)
craton_plot(ax, [602], [SChina_India_Euler, India_Euler_805, TPW_Euler_805],
            'k', SChina_color, cratons_alpha, cratons_lw)

# etcetera blocks
craton_plot(ax, [303], [Scotland_Laur_Euler, Laur_Euler_805, TPW_Euler_805],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [201], [Amazonia_Laur_Euler, Laur_Euler_805, TPW_Euler_805],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [202], [Parana_Amazonia_Euler, Amazonia_Laur_Euler, Laur_Euler_805, TPW_Euler_805],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [203], [RDLP_Amazonia_Euler, Amazonia_Laur_Euler, Laur_Euler_805, TPW_Euler_805],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [302], [Baltica_Laur_Euler, Laur_Euler_805, TPW_Euler_805],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [601], [NChina_Laur_Euler, Laur_Euler_805, TPW_Euler_805],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [7011], [Kalahari_Laur_Euler, Laur_Euler_805, TPW_Euler_805],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)

### POLES

poles_alpha = 0.5
poles_markersize = 70

# South China
pole_color = color_mapping.to_rgba([805]).tolist()
df_slice = SChina_site_06[SChina_site_06['name']=='Madiyi Formation - site mean (f=0.6)']
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [SChina_India_Euler, India_Euler_805, TPW_Euler_805],
                  'o', poles_markersize, pole_color, SChina_color, poles_alpha)

ax.gridlines(xlocs=lon_grid, ylocs=lat_grid, linewidth=0.5,
             color='C7', linestyle='dotted', zorder=-1)

#plt.savefig('../Output/TPW_model_805.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# #### 794

# %%
# time varying Eulers
Laur_Euler_794 = [57.7447,147.6911,-175.862]
India_Euler_794 = [24.9082,119.652,-45.5154]
TPW_Euler_794 = [-7.6,-178.33,-16.15]

# %%
ax = ipmag.make_orthographic_map(add_land=False, central_longitude=110, central_latitude=40,
                                 figsize=(8,8), grid_lines=False)

cratons_lw = 0.5
cratons_alpha = 1.0

# Laurentia
craton_plot(ax, [101], [Laur_Euler_794, TPW_Euler_794],
            'k', Laurentia_color, cratons_alpha, cratons_lw)

# Greenland
craton_plot(ax, [102], [Greenland_Laur_Euler, Laur_Euler_794, TPW_Euler_794],
            'k', Svalbard_color, cratons_alpha, cratons_lw)

# Svalbard
craton_plot(ax, [311], [Svalbard_Laur_Euler, Laur_Euler_794, TPW_Euler_794],
            'k', Svalbard_color, cratons_alpha, cratons_lw)

# Australia
craton_plot(ax, [801], [SAus_Laur_Euler, Laur_Euler_794, TPW_Euler_794],
            'k', Australia_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [8011], [NAus_SAus_Euler, SAus_Laur_Euler, Laur_Euler_794, TPW_Euler_794],
            'k', Australia_color, cratons_alpha, cratons_lw, reverse_draw=True)

# Antarctica
craton_plot(ax, [802], [Antarctica_SAus_Euler, SAus_Laur_Euler, Laur_Euler_794, TPW_Euler_794],
            'k', Antarctica_color, cratons_alpha, cratons_lw)

# India
craton_plot(ax, [501], [India_Euler_794, TPW_Euler_794],
            'k', India_color, cratons_alpha, cratons_lw)

# Rayner
craton_plot(ax, [803], [Rayner_India_Euler, India_Euler_794, TPW_Euler_794],
            'k', Rayner_color, cratons_alpha, cratons_lw)

# Siberia
craton_plot(ax, [401], [Siberia_Laur_Euler, Laur_Euler_794, TPW_Euler_794],
            'k', Siberia_color, cratons_alpha, cratons_lw, reverse_draw=True)

# South China
craton_plot(ax, [6024], [SChina_India_Euler, India_Euler_794, TPW_Euler_794],
            'k', SChina_color, cratons_alpha, cratons_lw)
craton_plot(ax, [6023], [SChina_India_Euler, India_Euler_794, TPW_Euler_794],
            'k', SChina_color, cratons_alpha, cratons_lw)
craton_plot(ax, [602], [SChina_India_Euler, India_Euler_794, TPW_Euler_794],
            'k', SChina_color, cratons_alpha, cratons_lw)

# etcetera blocks
craton_plot(ax, [303], [Scotland_Laur_Euler, Laur_Euler_794, TPW_Euler_794],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [201], [Amazonia_Laur_Euler, Laur_Euler_794, TPW_Euler_794],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [202], [Parana_Amazonia_Euler, Amazonia_Laur_Euler, Laur_Euler_794, TPW_Euler_794],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [203], [RDLP_Amazonia_Euler, Amazonia_Laur_Euler, Laur_Euler_794, TPW_Euler_794],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [302], [Baltica_Laur_Euler, Laur_Euler_794, TPW_Euler_794],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [601], [NChina_Laur_Euler, Laur_Euler_794, TPW_Euler_794],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [7011], [Kalahari_Laur_Euler, Laur_Euler_794, TPW_Euler_794],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)

### POLES

poles_alpha = 0.5
poles_markersize = 70

# Svalbard
pole_color = color_mapping.to_rgba([794]).tolist()
df_slice = Laurentia[Laurentia['name']=='Svanbergfjellet Formation']
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [Svalbard_Laur_Euler, Laur_Euler_794, TPW_Euler_794],
                  'o', poles_markersize, pole_color, Svalbard_color, poles_alpha)

ax.gridlines(xlocs=lon_grid, ylocs=lat_grid, linewidth=0.5,
             color='C7', linestyle='dotted', zorder=-1)

#plt.savefig('../Output/TPW_model_794.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# #### 755

# %%
# time varying Eulers
Laur_Euler_755 = [43.4821,151.0109,-167.5558]
India_Euler_755 = [65.4126,103.9231,-29.3572]
TPW_Euler_755 = [-7.6,-178.33,-16.15]

# %%
ax = ipmag.make_orthographic_map(add_land=False, central_longitude=110, central_latitude=40,
                                 figsize=(8,8), grid_lines=False)

cratons_lw = 0.5
cratons_alpha = 1.0

# Laurentia
craton_plot(ax, [101], [Laur_Euler_755, TPW_Euler_755],
            'k', Laurentia_color, cratons_alpha, cratons_lw)

# Greenland
craton_plot(ax, [102], [Greenland_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Svalbard_color, cratons_alpha, cratons_lw)

# Svalbard
craton_plot(ax, [311], [Svalbard_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Svalbard_color, cratons_alpha, cratons_lw)

# Australia
craton_plot(ax, [801], [SAus_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Australia_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [8011], [NAus_SAus_Euler, SAus_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Australia_color, cratons_alpha, cratons_lw, reverse_draw=True)

# Antarctica
craton_plot(ax, [802], [Antarctica_SAus_Euler, SAus_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Antarctica_color, cratons_alpha, cratons_lw)

# India
craton_plot(ax, [501], [India_Euler_755, TPW_Euler_755],
            'k', India_color, cratons_alpha, cratons_lw)

# Rayner
craton_plot(ax, [803], [Rayner_India_Euler, India_Euler_755, TPW_Euler_755],
            'k', Rayner_color, cratons_alpha, cratons_lw)

# Siberia
craton_plot(ax, [401], [Siberia_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Siberia_color, cratons_alpha, cratons_lw, reverse_draw=True)

# South China
craton_plot(ax, [6024], [SChina_India_Euler, India_Euler_755, TPW_Euler_755],
            'k', SChina_color, cratons_alpha, cratons_lw)
craton_plot(ax, [6023], [SChina_India_Euler, India_Euler_755, TPW_Euler_755],
            'k', SChina_color, cratons_alpha, cratons_lw)
craton_plot(ax, [602], [SChina_India_Euler, India_Euler_755, TPW_Euler_755],
            'k', SChina_color, cratons_alpha, cratons_lw)

# etcetera blocks
craton_plot(ax, [303], [Scotland_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [201], [Amazonia_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [202], [Parana_Amazonia_Euler, Amazonia_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [203], [RDLP_Amazonia_Euler, Amazonia_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [302], [Baltica_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [601], [NChina_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [7011], [Kalahari_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)

### POLES

poles_alpha = 0.5
poles_markersize = 70

# Australia
df_slice = Australia[Australia['name']=='Mundine Well Dykes Combined']
pole_color = color_mapping.to_rgba([df_slice['age'].iloc[0]]).tolist()
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [SAus_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
                  'o', poles_markersize, pole_color, Australia_color, poles_alpha)

# India
df_slice = India[India['name']=='Malani Igneous Suite -Comb']
pole_color = color_mapping.to_rgba([df_slice['age'].iloc[0]]).tolist()
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [India_Euler_755, TPW_Euler_755],
                  'o', poles_markersize, pole_color, India_color, poles_alpha)

# Siberia
df_slice = Siberia[Siberia['name']=='Kitoi Cryogenian dykes']
pole_color = color_mapping.to_rgba([df_slice['age'].iloc[0]]).tolist()
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [Siberia_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
                  'o', poles_markersize, pole_color, Siberia_color, poles_alpha)

# Laurentia
df_slice = Laurentia[Laurentia['name']=='Carbon Canyon']
pole_color = color_mapping.to_rgba([df_slice['age'].iloc[0]]).tolist()
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [Laur_Euler_755, TPW_Euler_755],
                  'o', poles_markersize, pole_color, Laurentia_color, poles_alpha)

# South China
df_slice = SChina_site_06[SChina_site_06['name']=='Liantuo Formation - Jing et al. (2021) site mean (f=0.6)']
pole_color = color_mapping.to_rgba([df_slice['age'].iloc[0]]).tolist()
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [SChina_India_Euler, India_Euler_755, TPW_Euler_755],
                  'o', poles_markersize, pole_color, SChina_color, poles_alpha)
df_slice = SChina_site_06[SChina_site_06['name']=='Liantuo Formation - site mean (f=0.6)']
pole_color = color_mapping.to_rgba([df_slice['age'].iloc[0]]).tolist()
rotated_pole_plot(ax, df_slice['plon'].iloc[0], df_slice['plat'].iloc[0], df_slice['a95'].iloc[0],
                  [SChina_India_Euler, India_Euler_755, TPW_Euler_755],
                  'o', poles_markersize, pole_color, SChina_color, poles_alpha)

ax.gridlines(xlocs=lon_grid, ylocs=lat_grid, linewidth=0.5,
             color='C7', linestyle='dotted', zorder=-1)

#plt.savefig('../Output/TPW_model_755.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# #### fixed Laurentia

# %%
ax = ipmag.make_orthographic_map(add_land=False, central_longitude=110, central_latitude=40,
                                 figsize=(8,8), grid_lines=False)

cratons_lw = 0.5
cratons_alpha = 1.0

# Laurentia
craton_plot(ax, [101], [Laur_Euler_755, TPW_Euler_755],
            'k', Laurentia_color, cratons_alpha, cratons_lw)

# Greenland
craton_plot(ax, [102], [Greenland_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Svalbard_color, cratons_alpha, cratons_lw)

# Svalbard
craton_plot(ax, [311], [Svalbard_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Svalbard_color, cratons_alpha, cratons_lw)

# Australia
craton_plot(ax, [801], [SAus_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Australia_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [8011], [NAus_SAus_Euler, SAus_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Australia_color, cratons_alpha, cratons_lw, reverse_draw=True)

# Antarctica
craton_plot(ax, [802], [Antarctica_SAus_Euler, SAus_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Antarctica_color, cratons_alpha, cratons_lw)

# Siberia
craton_plot(ax, [401], [Siberia_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Siberia_color, cratons_alpha, cratons_lw, reverse_draw=True)

# etcetera blocks
craton_plot(ax, [303], [Scotland_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [201], [Amazonia_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [202], [Parana_Amazonia_Euler, Amazonia_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [203], [RDLP_Amazonia_Euler, Amazonia_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [302], [Baltica_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [601], [NChina_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [7011], [Kalahari_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)

# moving India, SChina, Rayner
drift_ages = [821,813,811,809,805,755]
drift_India_Eulers = [[61.3777,101.776,124.258],
                      [63.8665,109.825,131.304],
                      [64.1719,111.045,132.331],
                      [65.2659,116.086,136.49],
                      [66.154,121.364,140.716],
                      [46.8383,162.151,143.369]]

color_mapping = plt.cm.ScalarMappable(cmap='viridis',
                                      norm=plt.Normalize(vmin=755, vmax=821))
SChina_drift_colors = color_mapping.to_rgba(drift_ages).tolist()

for i in range(len(drift_ages)):

    # India
    craton_plot(ax, [501], [drift_India_Eulers[i], Laur_Euler_755, TPW_Euler_755],
                'k', SChina_drift_colors[i], cratons_alpha, cratons_lw)

    # Rayner
    craton_plot(ax, [803], [Rayner_India_Euler, drift_India_Eulers[i], Laur_Euler_755, TPW_Euler_755],
                'k', SChina_drift_colors[i], cratons_alpha, cratons_lw)

    # South China
    craton_plot(ax, [6024], [SChina_India_Euler, drift_India_Eulers[i], Laur_Euler_755, TPW_Euler_755],
                'k', SChina_drift_colors[i], cratons_alpha, cratons_lw)
    craton_plot(ax, [6023], [SChina_India_Euler, drift_India_Eulers[i], Laur_Euler_755, TPW_Euler_755],
                'k', SChina_drift_colors[i], cratons_alpha, cratons_lw)
    craton_plot(ax, [602], [SChina_India_Euler, drift_India_Eulers[i], Laur_Euler_755, TPW_Euler_755],
                'k', SChina_drift_colors[i], cratons_alpha, cratons_lw)

ax.gridlines(xlocs=lon_grid, ylocs=lat_grid, linewidth=0.5,
             color='C7', linestyle='dotted', zorder=-1)

color_mapping._A = []
cbar = plt.colorbar(color_mapping, orientation='horizontal', shrink=0.8,
                    pad=0.05, label='age [Ma]')
cbar.ax.invert_xaxis()

#plt.savefig('../Output/TPW_model_fix_Laur.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Running Mean
#
# Time step of 10 m.y., with window of 20 m.y.

# %%
running_mean_ages = []
running_mean_n = []
running_mean_poles = []
running_mean_means = []
running_mean_slats = []
running_mean_slons = []

# 815 mean - 825-805 poles
# Xiaofeng
# Banxi
# Madiyi
running_mean_poles_815 = ['Xiaofeng Dikes - Jing et al. (2019)',
                          'Banxi Group - site mean (f=0.6)',
                          'Madiyi Formation - site mean (f=0.6)']
this_slice = SChina_site_06[SChina_site_06['name'].isin(running_mean_poles_815)].copy()
this_slice.reset_index(drop=True, inplace=True)
running_mean_ages.append(815)
running_mean_n.append(len(running_mean_poles_815))
running_mean_poles.append(running_mean_poles_815)
running_mean_means.append(ipmag.fisher_mean(this_slice['plon'],this_slice['plat']))
running_mean_slats.append(np.mean(this_slice['slat']))
running_mean_slons.append(np.mean(this_slice['slon']))

# 805 mean - 815-795 poles
# Banxi
# Madiyi
# Chengjiang
running_mean_poles_805 = ['Banxi Group - site mean (f=0.6)',
                          'Madiyi Formation - site mean (f=0.6)',
                          'Chengjiang Formation - site mean (f=0.6)']
this_slice = SChina_site_06[SChina_site_06['name'].isin(running_mean_poles_805)].copy()
this_slice.reset_index(drop=True, inplace=True)
running_mean_ages.append(805)
running_mean_n.append(len(running_mean_poles_805))
running_mean_poles.append(running_mean_poles_805)
running_mean_means.append(ipmag.fisher_mean(this_slice['plon'],this_slice['plat']))
running_mean_slats.append(np.mean(this_slice['slat']))
running_mean_slons.append(np.mean(this_slice['slon']))

# 795 mean - 805-785 poles
# Madiyi
# Chengjiang
running_mean_poles_795 = ['Madiyi Formation - site mean (f=0.6)',
                          'Chengjiang Formation - site mean (f=0.6)']
this_slice = SChina_site_06[SChina_site_06['name'].isin(running_mean_poles_795)].copy()
this_slice.reset_index(drop=True, inplace=True)
running_mean_ages.append(795)
running_mean_n.append(len(running_mean_poles_795))
running_mean_poles.append(running_mean_poles_795)
running_mean_means.append(ipmag.fisher_mean(this_slice['plon'],this_slice['plat']))
running_mean_slats.append(np.mean(this_slice['slat']))
running_mean_slons.append(np.mean(this_slice['slon']))

# 775 mean - 785-765 poles
# Liantuo - Jing et al. (2021)
# Liantuo - Jing et al. (2015)
running_mean_poles_785 = ['Liantuo Formation - Jing et al. (2021) site mean (f=0.6)',
                          'Liantuo Formation - site mean (f=0.6)']
this_slice = SChina_site_06[SChina_site_06['name'].isin(running_mean_poles_785)].copy()
this_slice.reset_index(drop=True, inplace=True)
running_mean_ages.append(775)
running_mean_n.append(len(running_mean_poles_785))
running_mean_poles.append(running_mean_poles_785)
running_mean_means.append(ipmag.fisher_mean(this_slice['plon'],this_slice['plat']))
running_mean_slats.append(np.mean(this_slice['slat']))
running_mean_slons.append(np.mean(this_slice['slon']))

running_mean_df = pd.DataFrame({'age':running_mean_ages,
                                'n':running_mean_n,
                                'poles':running_mean_poles,
                                'slat':running_mean_slats,
                                'slon':running_mean_slons})
for i in range(len(running_mean_df)):
    running_mean_df.loc[i,'plon'] = running_mean_means[i]['dec']
    running_mean_df.loc[i,'plat'] = running_mean_means[i]['inc']
    running_mean_df.loc[i,'a95'] = running_mean_means[i]['alpha95']
    running_mean_df.loc[i,'k'] = running_mean_means[i]['k']
    
running_mean_df
# Out:
#    age  n                                              poles       slat  \
# 0  815  3  [Xiaofeng Dikes - Jing et al. (2019), Banxi Gr...  28.790000
# 1  805  3  [Banxi Group - site mean (f=0.6), Madiyi Forma...  26.851667
# 2  795  2  [Madiyi Formation - site mean (f=0.6), Chengji...  26.322500
# 3  775  2  [Liantuo Formation - Jing et al. (2021) site m...  30.810000
#
#          slon        plon       plat        a95           k
# 0  109.883333   88.583156  34.906407  20.126119   38.574664
# 1  106.943667   86.071190  36.404003  21.014165   35.470756
# 2  106.005500   78.356145  32.384008  16.723798  225.102519
# 3  110.994500  140.458656  22.321417  19.943891  158.904899

# %%
running_mean_df.to_csv('../Output/running-mean-poles.csv',index=False)

poleLat = []
poleLon = []
poleName = []
poleSiteLat = []
poleSiteLon = []
poleNominalAge = []
poleA95 = []
plateID = []

count = 0

compilation = running_mean_df

for i in range(len(compilation)):

    poleLat.append(compilation['plat'][i])
    poleLon.append(compilation['plon'][i])

    poleName.append(str(compilation['age'][i]) + ' mean')
    poleSiteLat.append(compilation['slat'][i])
    poleSiteLon.append(compilation['slon'][i])
    poleNominalAge.append(compilation['age'][i])
    poleA95.append(compilation['a95'][i])

    plateID.append(602)

    count = count + 1

# Create new GPlates Feature Collection
vpgFeatureCollection = pgp.FeatureCollection()

# Create new GPlates feature 'VirtualGeomagneticPole'.
# Pole lat, pole lon, pole name, and reconstruction plate ID added within PointOnSphere method.
# Inc, Dec, A95, Age and Sample site lat/lon values to added within 'other_properties' method.

for j in range(count):

    vgpFeature = pgp.Feature.create_reconstructable_feature(
                 pgp.FeatureType.create_gpml('VirtualGeomagneticPole'),
                 pgp.PointOnSphere([np.float(poleLat[j]), np.float(poleLon[j])]),
                 name = poleName[j],
                 reconstruction_plate_id = int(plateID[j]),
                 other_properties = [(pgp.PropertyName.create_gpml('poleA95'),
                                      pgp.XsDouble(np.float64(poleA95[j]))),
                                     (pgp.PropertyName.create_gpml('averageAge'),
                                      pgp.XsDouble(np.float64(poleNominalAge[j]))),
                                     (pgp.PropertyName.create_gpml('averageSampleSitePosition'),
                                      pgp.GmlPoint(pgp.PointOnSphere([np.float(poleSiteLat[j]), 
                                                                      np.float(poleSiteLon[j])])))])

    # Add newly created feature to existing Feature Collection
    vpgFeatureCollection.add(vgpFeature)

running_mean_vpgFeatureCollection = vpgFeatureCollection
create_vgp_gpml(running_mean_vpgFeatureCollection, '../Output/running-mean-poles.gpml')
# Out:
# Palaeomagnetic pole data successfully exported in GPML format.

# %%
# fixed Eulers
Greenland_Laur_Euler = [67.5,-118.5,-13.8]
Svalbard_Laur_Euler = [-81.0,125.0,68.0]
Siberia_Laur_Euler = [77.0,98.0,137.0]
SChina_India_Euler = [6.7224,77.6921,67.9571]
SAus_Laur_Euler = [-30.2638,-19.1192,-131.7445]
NAus_SAus_Euler = [-20.0,135.0,-40.0]
Antarctica_SAus_Euler = [-3.91,37.9,30.86]
Rayner_India_Euler = [1.8434,-165.1696,-91.8395]

Scotland_Laur_Euler = [78.64,161.9,-32.0]
Amazonia_Laur_Euler = [11.97,-47.01,-110.66]
Parana_Amazonia_Euler = [0.67,103.22,-30.82]
RDLP_Amazonia_Euler = [0.67,103.22,-30.82]
Baltica_Laur_Euler = [75.8,-95.8,-59.2]
NChina_Laur_Euler = [52.9462,27.2366,61.9218]
Kalahari_Laur_Euler = [15.102,-25.2783,-157.5464]

# %%
# time varying Eulers
Laur_Euler_815 = [43.4821,151.0109,-167.5558]
India_Euler_815 = [15.0311,117.3646,-61.3807]
TPW_Euler_815 = [-7.6,-178.33,-16.15]

Laur_Euler_805 = [43.4821,151.0109,-167.5558]
India_Euler_805 = [13.2444,116.3074,-62.7808]
TPW_Euler_805 = [-7.6,-178.33,-16.15]

Laur_Euler_795 = [43.4821,151.0109,-167.5558]
India_Euler_795 = [12.0059,119.5824,-69.3008]
TPW_Euler_795 = [-7.6,-178.33,-16.15]

Laur_Euler_755 = [43.4821,151.0109,-167.5558]
India_Euler_755 = [64.3637,102.8927,-34.5445]
TPW_Euler_755 = [-7.6,-178.33,-16.15]

# %%
ax = ipmag.make_orthographic_map(add_land=False, central_longitude=110, central_latitude=40,
                                 figsize=(8,8), grid_lines=False)

cratons_lw = 0.5
cratons_alpha = 1.0

# Laurentia
craton_plot(ax, [101], [Laur_Euler_815, TPW_Euler_815],
            'k', Laurentia_color, cratons_alpha, cratons_lw)

# Greenland
craton_plot(ax, [102], [Greenland_Laur_Euler, Laur_Euler_815, TPW_Euler_815],
            'k', Svalbard_color, cratons_alpha, cratons_lw)

# Svalbard
craton_plot(ax, [311], [Svalbard_Laur_Euler, Laur_Euler_815, TPW_Euler_815],
            'k', Svalbard_color, cratons_alpha, cratons_lw)

# Australia
craton_plot(ax, [801], [SAus_Laur_Euler, Laur_Euler_815, TPW_Euler_815],
            'k', Australia_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [8011], [NAus_SAus_Euler, SAus_Laur_Euler, Laur_Euler_815, TPW_Euler_815],
            'k', Australia_color, cratons_alpha, cratons_lw, reverse_draw=True)

# Antarctica
craton_plot(ax, [802], [Antarctica_SAus_Euler, SAus_Laur_Euler, Laur_Euler_815, TPW_Euler_815],
            'k', Antarctica_color, cratons_alpha, cratons_lw)

# India
craton_plot(ax, [501], [India_Euler_815, TPW_Euler_815],
            'k', India_color, cratons_alpha, cratons_lw)

# Rayner
craton_plot(ax, [803], [Rayner_India_Euler, India_Euler_815, TPW_Euler_815],
            'k', Rayner_color, cratons_alpha, cratons_lw)

# Siberia
craton_plot(ax, [401], [Siberia_Laur_Euler, Laur_Euler_815, TPW_Euler_815],
            'k', Siberia_color, cratons_alpha, cratons_lw, reverse_draw=True)

# South China
craton_plot(ax, [6024], [SChina_India_Euler, India_Euler_815, TPW_Euler_815],
            'k', SChina_color, cratons_alpha, cratons_lw)
craton_plot(ax, [6023], [SChina_India_Euler, India_Euler_815, TPW_Euler_815],
            'k', SChina_color, cratons_alpha, cratons_lw)
craton_plot(ax, [602], [SChina_India_Euler, India_Euler_815, TPW_Euler_815],
            'k', SChina_color, cratons_alpha, cratons_lw)

# etcetera blocks
craton_plot(ax, [303], [Scotland_Laur_Euler, Laur_Euler_815, TPW_Euler_815],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [201], [Amazonia_Laur_Euler, Laur_Euler_815, TPW_Euler_815],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [202], [Parana_Amazonia_Euler, Amazonia_Laur_Euler, Laur_Euler_815, TPW_Euler_815],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [203], [RDLP_Amazonia_Euler, Amazonia_Laur_Euler, Laur_Euler_815, TPW_Euler_815],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [302], [Baltica_Laur_Euler, Laur_Euler_815, TPW_Euler_815],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [601], [NChina_Laur_Euler, Laur_Euler_815, TPW_Euler_815],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [7011], [Kalahari_Laur_Euler, Laur_Euler_815, TPW_Euler_815],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)

### POLES

poles_alpha = 0.5
poles_markersize = 70

color_mapping = plt.cm.ScalarMappable(cmap='viridis',
                                      norm=plt.Normalize(vmin=755, vmax=821))

# South China
SChina_pole_colors = color_mapping.to_rgba(running_mean_df['age'].tolist()).tolist()
for i in range(len(running_mean_df)):
    rotated_pole_plot(ax, running_mean_df['plon'][i], running_mean_df['plat'][i], running_mean_df['a95'][i],
                      [SChina_India_Euler, India_Euler_815, TPW_Euler_815],
                      'o', poles_markersize, SChina_pole_colors[i], SChina_color, poles_alpha)
    
# great circles
plt.plot([195, 195], [47, 87], color='k', linewidth=3, transform=ccrs.Geodetic())

ax.gridlines(xlocs=lon_grid, ylocs=lat_grid, linewidth=0.5,
             color='C7', linestyle='dotted', zorder=-1)

color_mapping._A = []
cbar = plt.colorbar(color_mapping, orientation='horizontal', shrink=0.8,
                    pad=0.05, label='age [Ma]')
cbar.ax.invert_xaxis()

#plt.savefig('../Output/running_mean_model_APWP.pdf', bbox_inches='tight')
plt.show()

# %%
ax = ipmag.make_orthographic_map(add_land=False, central_longitude=110, central_latitude=40,
                                 figsize=(8,8), grid_lines=False)

cratons_lw = 0.5
cratons_alpha = 1.0

# Laurentia
craton_plot(ax, [101], [Laur_Euler_755, TPW_Euler_755],
            'k', Laurentia_color, cratons_alpha, cratons_lw)

# Greenland
craton_plot(ax, [102], [Greenland_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Svalbard_color, cratons_alpha, cratons_lw)

# Svalbard
craton_plot(ax, [311], [Svalbard_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Svalbard_color, cratons_alpha, cratons_lw)

# Australia
craton_plot(ax, [801], [SAus_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Australia_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [8011], [NAus_SAus_Euler, SAus_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Australia_color, cratons_alpha, cratons_lw, reverse_draw=True)

# Antarctica
craton_plot(ax, [802], [Antarctica_SAus_Euler, SAus_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Antarctica_color, cratons_alpha, cratons_lw)

# Siberia
craton_plot(ax, [401], [Siberia_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', Siberia_color, cratons_alpha, cratons_lw, reverse_draw=True)

# etcetera blocks
craton_plot(ax, [303], [Scotland_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [201], [Amazonia_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [202], [Parana_Amazonia_Euler, Amazonia_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [203], [RDLP_Amazonia_Euler, Amazonia_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw)
craton_plot(ax, [302], [Baltica_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [601], [NChina_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)
craton_plot(ax, [7011], [Kalahari_Laur_Euler, Laur_Euler_755, TPW_Euler_755],
            'k', etcetera_color, cratons_alpha, cratons_lw, reverse_draw=True)

# moving India, SChina, Rayner
drift_ages = [815,805,795,755]
drift_India_Eulers = [India_Euler_815,
                      India_Euler_805,
                      India_Euler_795,
                      India_Euler_755]

color_mapping = plt.cm.ScalarMappable(cmap='viridis',
                                      norm=plt.Normalize(vmin=755, vmax=821))
SChina_drift_colors = color_mapping.to_rgba(drift_ages).tolist()

for i in range(len(drift_ages)):

    # India
    craton_plot(ax, [501], [drift_India_Eulers[i], TPW_Euler_755],
                'k', SChina_drift_colors[i], cratons_alpha, cratons_lw)

    # Rayner
    craton_plot(ax, [803], [Rayner_India_Euler, drift_India_Eulers[i], TPW_Euler_755],
                'k', SChina_drift_colors[i], cratons_alpha, cratons_lw)

    # South China
    craton_plot(ax, [6024], [SChina_India_Euler, drift_India_Eulers[i], TPW_Euler_755],
                'k', SChina_drift_colors[i], cratons_alpha, cratons_lw)
    craton_plot(ax, [6023], [SChina_India_Euler, drift_India_Eulers[i], TPW_Euler_755],
                'k', SChina_drift_colors[i], cratons_alpha, cratons_lw)
    craton_plot(ax, [602], [SChina_India_Euler, drift_India_Eulers[i], TPW_Euler_755],
                'k', SChina_drift_colors[i], cratons_alpha, cratons_lw)
    
### POLES

poles_alpha = 0.25
poles_markersize = 70

# South China
SChina_pole_colors = color_mapping.to_rgba(running_mean_df['age'].tolist()).tolist()
for i in range(len(running_mean_df)):
    rotated_pole_plot(ax, running_mean_df['plon'][i], running_mean_df['plat'][i], running_mean_df['a95'][i],
                      [SChina_India_Euler, drift_India_Eulers[i], TPW_Euler_755],
                      'o', poles_markersize, SChina_pole_colors[i], SChina_color, poles_alpha)

ax.gridlines(xlocs=lon_grid, ylocs=lat_grid, linewidth=0.5,
             color='C7', linestyle='dotted', zorder=-1)

color_mapping._A = []
cbar = plt.colorbar(color_mapping, orientation='horizontal', shrink=0.8,
                    pad=0.05, label='age [Ma]')
cbar.ax.invert_xaxis()

#plt.savefig('../Output/running_mean_model.pdf', bbox_inches='tight')
plt.show()
